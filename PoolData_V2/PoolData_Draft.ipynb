# %% [markdown]
# # Notebook Description

# %% [markdown]
# This notebook is used to fetch on chain data by The Graph API of UNISWAP V2. This is a draft so that something is useful and something is also useless. The formal version please refer to the PoolData_V2.
# <br>Terminology, definition, and example please refer to https://docs.uniswap.org/protocol/V2/reference/API/entities#

# %% [markdown]
# # Config Environment

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir("/content/gdrive/My Drive/DefiEconResearch/V2Data")

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Query Function

# %%
import requests
from pprint import pprint

def run_query(q):

    # endpoint where you are making the request
    request = requests.post('https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v2'
                            '',
                            json={'query': q})
    if request.status_code == 200:
        return request.json()
    else:
        raise Exception('Query failed. return code is {}.      {}'.format(request.status_code, q))

def run_query_var(q, var):

    # endpoint where you are making the request
    request = requests.post('https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v2'
                            '',
                            json={'query': q, 'variables': var})
    if request.status_code == 200:
        return request.json()
    else:
        raise Exception('Query failed. return code is {}.      {}'.format(request.status_code, q))

def run_query_ether(q):

    # endpoint where you are making the request
    request = requests.post('https://api.thegraph.com/subgraphs/name/blocklytics/ethereum-blocks'
                            '',
                            json={'query': q})
    if request.status_code == 200:
        return request.json()
    else:
        raise Exception('Query failed. return code is {}.      {}'.format(request.status_code, q))

# %% [markdown]
# # Query the INSTANT overview of Uniswap V2: total liquidity, total volume (USD)

# %%
v2_overview_query = """
{
 uniswapFactory(id: "0x5C69bEe701ef814a2B6a3EDD4B1652CB9cc5aA6f"){
   totalVolumeUSD
   totalLiquidityUSD
   totalVolumeETH
   totalLiquidityETH
   pairCount
   txCount
 }
}
"""
v2_overview = run_query(v2_overview_query)

pprint(v2_overview)
# Out:
# {'data': {'uniswapFactory': {'pairCount': 76439,
#                              'totalLiquidityETH': '888302.4119904871118387331274559368',
#                              'totalLiquidityUSD': '1635313051.682547404490780429959447',
#                              'totalVolumeETH': '281571647.9369482253806664227052093',
#                              'totalVolumeUSD': '413633328255.9816370214666716687079',
#                              'txCount': '80453962'}}}

# %% [markdown]
# # (Delete)Query the HISTORICAL SNAPSHOT overview of Uniswap V2: total liquidity, total volume (USD)

# %%
# unix timestamp: GMT 2022/05/30 0:00:00  1653865200
# unix timestamp: GMT 2022/05/31 0:00:00  1653951600
timestamp_to_block_query = """
{
  blocks(first: 1, orderBy: timestamp, orderDirection: asc, where: {timestamp_gt: "1653951600"}) {
    id
    number
    timestamp
  }
}
"""
timestamp_to_block = run_query_ether(timestamp_to_block_query)
pprint(timestamp_to_block)
# Out:
# {'data': {'blocks': [{'id': '0x15a2e4c8ba92eb4cfa9f793d3ab15891ae5fe5c049f77abf8ca15df063cb9008',
#                       'number': '14875301',
#                       'timestamp': '1653951612'}]}}

# %% [markdown]
# # Get All Pairs

# %%
# # totalSupply: total supply of liquidity token distributed to LPs   unit as ETH
# get_paris_query_2 = """
# {
#   pairs(first: 10, orderBy: createdAtTimestamp, orderDirection: asc) 
#   { 
#      token0 {
#         id
#         symbol
#       }
#       token1 {
#         id
#         symbol
#       }
#      id
#      createdAtBlockNumber
#      createdAtTimestamp
#      totalSupply
#      txCount
#     }
# }
# """

# get_pairs_batch2 = run_query(get_paris_query_2)
# pprint(get_pairs_batch2)
# Out:
# {'data': {'pairs': [{'createdAtBlockNumber': '10008355',
#                      'createdAtTimestamp': '1588710145',
#                      'id': '0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc',
#                      'token0': {'id': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#                                 'symbol': 'USDC'},
#                      'token1': {'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#                                 'symbol': 'WETH'},
#                      'totalSupply': '0.952643944936983285',
#                      'txCount': '3543792'},
#                     {'createdAtBlockNumber': '10008500',
#                      'createdAtTimestamp': '1588712092',
#                      'id': '0x3139ffc91b99aa94da8a2dc13f1fc36f9bdc98ee',
#                      'token0': {'id': '0x8e870d67f660d95d5be530380d0ec0bd388289e1',
#                                 'symbol': 'PAX'},
#                      'token1': {'id': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#                                 'symbol': 'USDC'},
#                      'totalSupply': '0.000000006379783',
#                      'txCount': '28'},
#                     {'createdAtBlockNumber': '10014178',
#                      'createdAtTimestamp': '1588788074',
#                      'id': '0x12ede161c702d1494612d19f05992f43aa6a26fb',
#                      'token0': {'id': '0x06af07097c9eeb7fd685c692751d5c66db49c215',
#                                 'symbol': 'CHAI'},
#                      'token1': {'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#                                 'symbol': 'WETH'},
#                      'totalSupply': '14.429278541823799433',
#                      'txCount': '825'},
#                     {'createdAtBlockNumber': '10042267',
#                      'createdAtTimestamp': '1589164213',
#                      'id': '0xa478c2975ab1ea89e8196811f51a7b7ade33eb11',
#                      'token0': {'id': '0x6b175474e89094c44da98b954eedeac495271d0f',
#                                 'symbol': 'DAI'},
#                      'token1': {'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#                                 'symbol': 'WETH'},
#                      'totalSupply': '120134.434231707494879581',
#                      'txCount': '1383630'},
#                     {'createdAtBlockNumber': '10060679',
#                      'createdAtTimestamp': '1589411030',
#                      'id': '0x07f068ca326a469fc1d87d85d448990c8cba7df9',
#                      'token0': {'id': '0x408e41876cccdc0f92210600ef50372656052a38',
#                                 'symbol': 'REN'},
#                      'token1': {'id': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#                                 'symbol': 'USDC'},
#                      'totalSupply': '0.000360555127545398',
#                      'txCount': '1450'},
#                     {'createdAtBlockNumber': '10060832',
#                      'createdAtTimestamp': '1589413139',
#                      'id': '0xae461ca67b15dc8dc81ce7615e0320da1a9ab8d5',
#                      'token0': {'id': '0x6b175474e89094c44da98b954eedeac495271d0f',
#                                 'symbol': 'DAI'},
#                      'token1': {'id': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#                                 'symbol': 'USDC'},
#                      'totalSupply': '57.288226123900678998',
#                      'txCount': '159002'},
#                     {'createdAtBlockNumber': '10061003',
#                      'createdAtTimestamp': '1589415541',
#                      'id': '0xce407cd7b95b39d3b4d53065e711e713dd5c5999',
#                      'token0': {'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#                                 'symbol': 'WETH'},
#                      'token1': {'id': '0xfa3e941d1f6b7b10ed84a0c211bfa8aee907965e',
#                                 'symbol': 'HAY'},
#                      'totalSupply': '0',
#                      'txCount': '3'},
#                     {'createdAtBlockNumber': '10061271',
#                      'createdAtTimestamp': '1589419121',
#                      'id': '0x33c2d48bc95fb7d0199c5c693e7a9f527145a9af',
#                      'token0': {'id': '0x1f573d6fb3f13d689ff844b4ce37794d79a7ff1c',
#                                 'symbol': 'BNT'},
#                      'token1': {'id': '0x6b175474e89094c44da98b954eedeac495271d0f',
#                                 'symbol': 'DAI'},
#                      'totalSupply': '7.497656982193064667',
#                      'txCount': '114'},
#                     {'createdAtBlockNumber': '10061933',
#                      'createdAtTimestamp': '1589427894',
#                      'id': '0xb6909b960dbbe7392d405429eb2b3649752b4838',
#                      'token0': {'id': '0x0d8775f648430679a709e98d2b0cb6250d2887ef',
#                                 'symbol': 'BAT'},
#                      'token1': {'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#                                 'symbol': 'WETH'},
#                      'totalSupply': '4719.741049157000590869',
#                      'txCount': '70798'},
#                     {'createdAtBlockNumber': '10091031',
#                      'createdAtTimestamp': '1589818892',
#                      'id': '0x30eb5e15476e6a80f4f3cd8479749b4881dab1b8',
#                      'token0': {'id': '0x39aa39c021dfbae8fac545936693ac917d5e7563',
#                                 'symbol': 'cUSDC'},
#                      'token1': {'id': '0x5d3a536e4d6dbd6114cc1ead35777bab948e3643',
#                                 'symbol': 'cDAI'},
#                      'totalSupply': '0.000000006407712566',
#                      'txCount': '48'}]}}

# %%
# Start from fetching the initial Batch 0: Query 1000 pairs on UNISWAP V2 order by created timestamp
get_paris_query_0 = """
{
  pairs(first: 1000, orderBy: createdAtTimestamp, orderDirection: asc) 
  { 
    token0 {
        id
        symbol
    }
    token1 {
        id
        symbol
    }
    id
    createdAtBlockNumber
    createdAtTimestamp
    totalSupply
    txCount
  }
}
"""

get_pairs_batch0 = run_query(get_paris_query_0)

# %%
# Create a dataframe to store the pairs info, initializa with the first 1000 pairs
df_all_pairs = pd.DataFrame.from_dict(get_pairs_batch0['data']['pairs'])

# %%
# Do iteration to fetch all the pairs, skip the first 1000 in batch 0
# Start from the last timestamp which is got by batch 0

iter_count = 0
pairs_iter = get_pairs_batch0['data']['pairs']  # Pair info list in each batch
total_pair_amount = len(pairs_iter)  # Initial the total pair amount by 1000 (in batch 0)

# Do loop until 
while len(pairs_iter) == 1000:
  # The last timestamp in the previous query batch
  last_gt = int(pairs_iter[-1]['createdAtTimestamp'])
  params_gt = {"createdAtTimestamp_gt": last_gt}

  # Query 1000 new pairs from the last timestamp
  query_iter = """
  query pairs($createdAtTimestamp_gt: Int!) {
    pairs(first: 1000, orderBy: createdAtTimestamp, orderDirection: asc
    where: {createdAtTimestamp_gt: $createdAtTimestamp_gt }) 
    { 
      token0 {
        id
        symbol
      }
      token1 {
        id
        symbol
      }
      id
      createdAtBlockNumber
      createdAtTimestamp
      totalSupply
      txCount
    }
  }
  """
  result_iter = run_query_var(query_iter, params_gt)

  # List of pair info for this batch
  pairs_iter = result_iter['data']['pairs']

  # Add list of this batch to the dataframe
  df_all_pairs = df_all_pairs.append(pairs_iter, ignore_index=True)

  # Summary for this batch, and update iterator
  iter_count = iter_count + 1
  total_pair_amount = total_pair_amount+len(pairs_iter)
  print('Batch: ', iter_count, '  Length of pair: ', len(pairs_iter), '  Total fected pairs: ', total_pair_amount)
  print('             Start from timestamp: ', last_gt)

print('---------------------------')
print('Amount of fetced pairs: ', total_pair_amount)
# Out:
# Batch:  1   Length of pair:  1000   Total fected pairs:  2000
#              Start from timestamp:  1592097373
# Batch:  2   Length of pair:  1000   Total fected pairs:  3000
#              Start from timestamp:  1594041143
# Batch:  3   Length of pair:  1000   Total fected pairs:  4000
#              Start from timestamp:  1595937431
# Batch:  4   Length of pair:  1000   Total fected pairs:  5000
#              Start from timestamp:  1596802583
# Batch:  5   Length of pair:  1000   Total fected pairs:  6000
#              Start from timestamp:  1597709234
# Batch:  6   Length of pair:  1000   Total fected pairs:  7000
#              Start from timestamp:  1598348473
# Batch:  7   Length of pair:  1000   Total fected pairs:  8000
#              Start from timestamp:  1599034094
# Batch:  8   Length of pair:  1000   Total fected pairs:  9000
#              Start from timestamp:  1599508406
# Batch:  9   Length of pair:  1000   Total fected pairs:  10000
#              Start from timestamp:  1600106758
# Batch:  10   Length of pair:  1000   Total fected pairs:  11000
#              Start from timestamp:  1600669731
# Batch:  11   Length of pair:  1000   Total fected pairs:  12000
#              Start from timestamp:  1601068988
# Batch:  12   Length of pair:  1000   Total fected pairs:  13000
#              Start from timestamp:  1601443436
# Batch:  13   Length of pair:  1000   Total fected pairs:  14000
#              Start from timestamp:  1601822130
# Batch:  14   Length of pair:  1000   Total fected pairs:  15000
#              Start from timestamp:  1602248413
# Batch:  15   Length of pair:  1000   Total fected pairs:  16000
#              Start from timestamp:  1602639604
# Batch:  16   Length of pair:  1000   Total fected pairs:  17000
#              Start from timestamp:  1603001399
# Batch:  17   Length of pair:  1000   Total fected pairs:  18000
#              Start from timestamp:  1603329383
# Batch:  18   Length of pair:  1000   Total fected pairs:  19000
#              Start from timestamp:  1603599259
# Batch:  19   Length of pair:  1000   Total fected pairs:  20000
#              Start from timestamp:  1603929054
# Batch:  20   Length of pair:  1000   Total fected pairs:  21000
#              Start from timestamp:  1604251121
# Batch:  21   Length of pair:  1000   Total fected pairs:  22000
#              Start from timestamp:  1604624634
# Batch:  22   Length of pair:  1000   Total fected pairs:  23000
#              Start from timestamp:  1605116196
# Batch:  23   Length of pair:  1000   Total fected pairs:  24000
#              Start from timestamp:  1605634559
# Batch:  24   Length of pair:  1000   Total fected pairs:  25000
#              Start from timestamp:  1606341334
# Batch:  25   Length of pair:  1000   Total fected pairs:  26000
#              Start from timestamp:  1607183920
# Batch:  26   Length of pair:  1000   Total fected pairs:  27000
#              Start from timestamp:  1607971101
# Batch:  27   Length of pair:  1000   Total fected pairs:  28000
#              Start from timestamp:  1608837863
# Batch:  28   Length of pair:  1000   Total fected pairs:  29000
#              Start from timestamp:  1610182196
# Batch:  29   Length of pair:  1000   Total fected pairs:  30000
#              Start from timestamp:  1611575443
# Batch:  30   Length of pair:  1000   Total fected pairs:  31000
#              Start from timestamp:  1613348902
# Batch:  31   Length of pair:  1000   Total fected pairs:  32000
#              Start from timestamp:  1616060601
# Batch:  32   Length of pair:  1000   Total fected pairs:  33000
#              Start from timestamp:  1617322676
# Batch:  33   Length of pair:  1000   Total fected pairs:  34000
#              Start from timestamp:  1618842657
# Batch:  34   Length of pair:  1000   Total fected pairs:  35000
#              Start from timestamp:  1619359847
# Batch:  35   Length of pair:  1000   Total fected pairs:  36000
#              Start from timestamp:  1619871041
# Batch:  36   Length of pair:  1000   Total fected pairs:  37000
#              Start from timestamp:  1620845838
# Batch:  37   Length of pair:  1000   Total fected pairs:  38000
#              Start from timestamp:  1621338102
# Batch:  38   Length of pair:  1000   Total fected pairs:  39000
#              Start from timestamp:  1621967468
# Batch:  39   Length of pair:  1000   Total fected pairs:  40000
#              Start from timestamp:  1622418194
# Batch:  40   Length of pair:  1000   Total fected pairs:  41000
#              Start from timestamp:  1622751557
# Batch:  41   Length of pair:  1000   Total fected pairs:  42000
#              Start from timestamp:  1623059920
# Batch:  42   Length of pair:  1000   Total fected pairs:  43000
#              Start from timestamp:  1623371759
# Batch:  43   Length of pair:  1000   Total fected pairs:  44000
#              Start from timestamp:  1623717125
# Batch:  44   Length of pair:  1000   Total fected pairs:  45000
#              Start from timestamp:  1624180361
# Batch:  45   Length of pair:  1000   Total fected pairs:  46000
#              Start from timestamp:  1624653996
# Batch:  46   Length of pair:  1000   Total fected pairs:  47000
#              Start from timestamp:  1625120662
# Batch:  47   Length of pair:  1000   Total fected pairs:  48000
#              Start from timestamp:  1625475218
# Batch:  48   Length of pair:  1000   Total fected pairs:  49000
#              Start from timestamp:  1626035456
# Batch:  49   Length of pair:  1000   Total fected pairs:  50000
#              Start from timestamp:  1626849897
# Batch:  50   Length of pair:  1000   Total fected pairs:  51000
#              Start from timestamp:  1628023316
# Batch:  51   Length of pair:  1000   Total fected pairs:  52000
#              Start from timestamp:  1629414238
# Batch:  52   Length of pair:  1000   Total fected pairs:  53000
#              Start from timestamp:  1631868401
# Batch:  53   Length of pair:  1000   Total fected pairs:  54000
#              Start from timestamp:  1633771208
# Batch:  54   Length of pair:  1000   Total fected pairs:  55000
#              Start from timestamp:  1635153128
# Batch:  55   Length of pair:  1000   Total fected pairs:  56000
#              Start from timestamp:  1635997901
# Batch:  56   Length of pair:  1000   Total fected pairs:  57000
#              Start from timestamp:  1636689097
# Batch:  57   Length of pair:  1000   Total fected pairs:  58000
#              Start from timestamp:  1637326515
# Batch:  58   Length of pair:  1000   Total fected pairs:  59000
#              Start from timestamp:  1638195379
# Batch:  59   Length of pair:  1000   Total fected pairs:  60000
#              Start from timestamp:  1639269806
# Batch:  60   Length of pair:  1000   Total fected pairs:  61000
#              Start from timestamp:  1640192763
# Batch:  61   Length of pair:  1000   Total fected pairs:  62000
#              Start from timestamp:  1641546066
# Batch:  62   Length of pair:  1000   Total fected pairs:  63000
#              Start from timestamp:  1643568555
# Batch:  63   Length of pair:  1000   Total fected pairs:  64000
#              Start from timestamp:  1644691972
# Batch:  64   Length of pair:  1000   Total fected pairs:  65000
#              Start from timestamp:  1645620248
# Batch:  65   Length of pair:  1000   Total fected pairs:  66000
#              Start from timestamp:  1646552583
# Batch:  66   Length of pair:  1000   Total fected pairs:  67000
#              Start from timestamp:  1647234972
# Batch:  67   Length of pair:  1000   Total fected pairs:  68000
#              Start from timestamp:  1647893654
# Batch:  68   Length of pair:  1000   Total fected pairs:  69000
#              Start from timestamp:  1648566579
# Batch:  69   Length of pair:  1000   Total fected pairs:  70000
#              Start from timestamp:  1649151597
# Batch:  70   Length of pair:  1000   Total fected pairs:  71000
#              Start from timestamp:  1649763039
# Batch:  71   Length of pair:  1000   Total fected pairs:  72000
#              Start from timestamp:  1650260447
# Batch:  72   Length of pair:  1000   Total fected pairs:  73000
#              Start from timestamp:  1650786555
# Batch:  73   Length of pair:  1000   Total fected pairs:  74000
#              Start from timestamp:  1651493896
# Batch:  74   Length of pair:  1000   Total fected pairs:  75000
#              Start from timestamp:  1652669173
# Batch:  75   Length of pair:  1000   Total fected pairs:  76000
#              Start from timestamp:  1653364307
# Batch:  76   Length of pair:  592   Total fected pairs:  76592
#              Start from timestamp:  1654127704
# ---------------------------
# Amount of fetced pairs:  76592

# %%
df_all_pairs
# Out:
#                                                    token0  \
# 0       {'id': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606...
# 1       {'id': '0x8e870d67f660d95d5be530380d0ec0bd3882...
# 2       {'id': '0x06af07097c9eeb7fd685c692751d5c66db49...
# 3       {'id': '0x6b175474e89094c44da98b954eedeac49527...
# 4       {'id': '0x408e41876cccdc0f92210600ef5037265605...
# ...                                                   ...
# 100587  {'id': '0x65ded4c951e9a20cdbbf4b8a6536e5027d39...
# 100588  {'id': '0x18d20a9fd597bf1bba87c26c3db6c24232ab...
# 100589  {'id': '0x3c3f0dd5846de6e6564722040a954aa89656...
# 100590  {'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c75...
# 100591  {'id': '0x04487444b2d3adf07f4b8f55dae9ff27c94a...
#
#                                                    token1  \
# 0       {'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c75...
# 1       {'id': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606...
# 2       {'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c75...
# 3       {'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c75...
# 4       {'id': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606...
# ...                                                   ...
# 100587  {'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c75...
# 100588  {'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c75...
# 100589  {'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c75...
# 100590  {'id': '0xedfb2f23233e4c7b02a87da7171319159938...
# 100591  {'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c75...
#
#                                                 id createdAtBlockNumber  \
# 0       0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc             10008355
# 1       0x3139ffc91b99aa94da8a2dc13f1fc36f9bdc98ee             10008500
# 2       0x12ede161c702d1494612d19f05992f43aa6a26fb             10014178
# 3       0xa478c2975ab1ea89e8196811f51a7b7ade33eb11             10042267
# 4       0x07f068ca326a469fc1d87d85d448990c8cba7df9             10060679
# ...                                            ...                  ...
# 100587  0x66bb48c0f79225d7b8fc612d81b8e54cb53f6ac8             14933384
# 100588  0x47a6df38e445a534674b942bb32fe4971150ac76             14933424
# 100589  0x4fc883848e6aa45c72428ed6515f32ccc8efe7f1             14933450
# 100590  0x456b759687aaf8ed4cfcf4d22efeb9b1545dc609             14933656
# 100591  0x997b1231acd479f672a9bdca7fa8fd8d3ff76624             14933749
#
#        createdAtTimestamp                totalSupply  txCount
# 0              1588710145       0.952645034840461313  3545177
# 1              1588712092          0.000000006379783       28
# 2              1588788074      14.429278541823799433      825
# 3              1589164213  120134.434231707494879581  1383828
# 4              1589411030       0.000360555127545398     1450
# ...                   ...                        ...      ...
# 100587         1654789350          0.000799999999999       41
# 100588         1654789860    7957.119709486762496381       55
# 100589         1654790190      37.549966711037174032       59
# 100590         1654793732       7632.553468499999999       43
# 100591         1654795089     944.105424827865850163       89
#
# [100592 rows x 7 columns]

# %%
# Write dataframe to csv
df_all_pairs.to_csv("All_Pairs_Info_V2_20220609_H19M11.csv")

# %% [markdown]
# # Get Mints/Burns Transactions

# %%
# # Mint: Add Liquidity to pool,  Burn: Remove Liquidity to the pool
# # See example of Add ETH and RND to pair: ETH/RND 0x5449bd1a97296125252db2d9cf23d5d6e30ca3c1
# mint_transaction_query = """
# {
#  mints(first: 30, where: { pair: "0x5449bd1a97296125252db2d9cf23d5d6e30ca3c1" }, orderBy: timestamp, orderDirection: desc) {
#    transaction {
#      id
#      timestamp
#    }
#    to
#    liquidity
#    amount0
#    amount1
#    amountUSD
#  }
# }
# """
# mint_transaction = run_query(mint_transaction_query)

# pprint(mint_transaction)

candidatePairs = [
 "0xa478c2975ab1ea89e8196811f51a7b7ade33eb11",
 "0xae461ca67b15dc8dc81ce7615e0320da1a9ab8d5"
]
params_candidate_pairs = {"candidatePairs": candidatePairs}
mint_transaction_query = """
query($candidatePairs: [String!]) {
 mints(first: 30, where: { pair_in: $candidatePairs }, orderBy: timestamp, orderDirection: desc) {
   transaction {
     id
     timestamp
   }
   to
   liquidity
   amount0
   amount1
   amountUSD
 }
}
"""
mint_transaction = run_query_var(mint_transaction_query, params_candidate_pairs)

pprint(mint_transaction)
# Out:
# {'data': {'mints': [{'amount0': '20917.612421378506229795',
#                      'amount1': '11.996883604053411427',
#                      'amountUSD': '42119.13928067889754061696505107397',
#                      'liquidity': '298.420730358101761339',
#                      'to': '0x6d9893fa101cd2b1f8d1a12de3189ff7b80fdc10',
#                      'transaction': {'id': '0xa1eaff753ecc8cb534032a8decabe9374f8ea62c6d247a7f4ceeb3daa0a33f14',
#                                      'timestamp': '1654583776'}},
#                     {'amount0': '1431086.920205154521392811',
#                      'amount1': '1432237.745324',
#                      'amountUSD': '2864417.136023481484046488768673554',
#                      'liquidity': '1.271718317255244619',
#                      'to': '0x0a827de54f4c6c2ae24bf52c5a278a045300e224',
#                      'transaction': {'id': '0x86fcd975478ab7a53e7b2f3b0a5afeb2be2ce2f107c3215590321e9d0c4dc617',
#                                      'timestamp': '1654560221'}},
#                     {'amount0': '4998055.013039',
#                      'amount1': '5001944.986961',
#                      'amountUSD': '10005427.49021486905702131645554425',
#                      'liquidity': '4.441405510308135286',
#                      'to': '0x6ff10de70db14ce0ea5e2454a4aebf5eacdfff26',
#                      'transaction': {'id': '0xe410fe6f8f7e34c7bc00d0f2fcd86ea0f5fd5aff25fce515dadac0019b8dbd91',
#                                      'timestamp': '1654549932'}},
#                     {'amount0': '5002665.734732',
#                      'amount1': '4997334.265268',
#                      'amountUSD': '9997613.96384780463711635916390198',
#                      'liquidity': '4.441424561804305134',
#                      'to': '0x6ff10de70db14ce0ea5e2454a4aebf5eacdfff26',
#                      'transaction': {'id': '0x92797ceecdb8a1225532a85953cd1dbdbbc72fed5f0fc0b1ea84b3ca0f9f41c4',
#                                      'timestamp': '1654520687'}},
#                     {'amount0': '100',
#                      'amount1': '0.052975717868102416',
#                      'amountUSD': '200.5472423589036588285022681668715',
#                      'liquidity': '1.371839582453224193',
#                      'to': '0x38abcf7e59adf3b918362ee455786d55bb7c1d88',
#                      'transaction': {'id': '0x8593ad1e7f7aa104b29a03f16d1dc5d0ef68fe202532327ec1e20a19c390e44a',
#                                      'timestamp': '1654502938'}},
#                     {'amount0': '995322.163108644',
#                      'amount1': '994233.372193',
#                      'amountUSD': '1991576.830049627506283833256251642',
#                      'liquidity': '0.883648381057490001',
#                      'to': '0xa20ef8a9a21cb318f0d396ba0134698e472e38dd',
#                      'transaction': {'id': '0xace23b5a9c14aa36aa186ac89cdd12419db10bff4078164c65f155610a7ff1ef',
#                                      'timestamp': '1654493680'}},
#                     {'amount0': '69.999676408782258825',
#                      'amount1': '70.080366',
#                      'amountUSD': '140.0328132567647820849546848708813',
#                      'liquidity': '0.000062217907485747',
#                      'to': '0x08555ed358364e1ca9c4f8a9fb45221566296ad7',
#                      'transaction': {'id': '0x01e8fbd414a814a7dc48510f2aaa3f95e33c2c047f929f9053934a4e8691f74e',
#                                      'timestamp': '1654462104'}},
#                     {'amount0': '845451.192196979566704408',
#                      'amount1': '846848.24364',
#                      'amountUSD': '1693556.552961084344367644651347416',
#                      'liquidity': '0.751651865891137597',
#                      'to': '0xcfab322f8665595dc7e0cb96a02131e8dffe80d9',
#                      'transaction': {'id': '0x3091d8312e43c82914bb049c19addbdfba00363c22c0ce23510bb9cb8afce82c',
#                                      'timestamp': '1654443727'}},
#                     {'amount0': '301.170609495183831766',
#                      'amount1': '0.17',
#                      'amountUSD': '603.5614654121709541586956331008701',
#                      'liquidity': '4.266448229803271369',
#                      'to': '0x4c8d9a0d37ec89a2378dd65ac2ded98d94287ee8',
#                      'transaction': {'id': '0x1d8d9e012982f00ce298ce1b92c334841cee6ce76e30b968771ed5b0a7d05e11',
#                                      'timestamp': '1654352951'}},
#                     {'amount0': '211.171539087378160847',
#                      'amount1': '0.119999999999999999',
#                      'amountUSD': '422.5435493314564009834660677739534',
#                      'liquidity': '3.001554476427803555',
#                      'to': '0x4c8d9a0d37ec89a2378dd65ac2ded98d94287ee8',
#                      'transaction': {'id': '0x1243d6b6624890573e939f065c0e69ed5064bf2babff0920f23104cbbe373da3',
#                                      'timestamp': '1654352355'}},
#                     {'amount0': '4920102.962845114685356062',
#                      'amount1': '4917432',
#                      'amountUSD': '9839352.024165631864519216686509881',
#                      'liquidity': '4.369508004328925644',
#                      'to': '0xbee1dee31365272bc6e5021c8ac66bede8bed641',
#                      'transaction': {'id': '0x37c2fa55fb928b8ca7da49d0cc7eb25d6f29d85fe80117b2196c14bd7bcbe904',
#                                      'timestamp': '1654316286'}},
#                     {'amount0': '90',
#                      'amount1': '0.045418440785520664',
#                      'amountUSD': '179.78779355766201226354040457441',
#                      'liquidity': '1.206784187278551754',
#                      'to': '0x9e7f1f2c3322bd291a336b5cb1f1e3bdb95eb2e9',
#                      'transaction': {'id': '0x7b315cd347a2ce8bc3bd902a59af9a28d34ffdcf4a937c1610a22393bd5903a9',
#                                      'timestamp': '1653976676'}},
#                     {'amount0': '107.546904969614619573',
#                      'amount1': '0.054273464586582196',
#                      'amountUSD': '215.3331821236740760998710601886103',
#                      'liquidity': '1.442162320852404796',
#                      'to': '0x0238d43e5dbc413554da397936b7c82d3a81d6b0',
#                      'transaction': {'id': '0xb02e240d054c64c308302d12ad10ad48698fa01bdd8a656dbba7efafb6f317cf',
#                                      'timestamp': '1653945705'}},
#                     {'amount0': '8.960763151651301668',
#                      'amount1': '0.004985005234455302',
#                      'amountUSD': '17.94989542552770229140461539860471',
#                      'liquidity': '0.12621425220023316',
#                      'to': '0x502c28f523636251beeff8bcd5023ecd1bbb8b3a',
#                      'transaction': {'id': '0x7e059b29c7223f3764731af83b402d3708bdeb41c3e054c7bcf89e3b91013c51',
#                                      'timestamp': '1653861881'}},
#                     {'amount0': '152.164728466090123356',
#                      'amount1': '0.085828699133967442',
#                      'amountUSD': '303.7014022911946057676688710095012',
#                      'liquidity': '2.158584016478085381',
#                      'to': '0x6794acf437ff25d0283bdeef026010cd1790875f',
#                      'transaction': {'id': '0x16d7ed3ee3e33f128eaffa9f06ed282e93774b90332168c121b2be81e2d140f2',
#                                      'timestamp': '1653721067'}},
#                     {'amount0': '68041.112504199239547214',
#                      'amount1': '67925.798859',
#                      'amountUSD': '136011.322548094679428064175779603',
#                      'liquidity': '0.060398306268259135',
#                      'to': '0x2d1f24c8837a94e28e0c2a5e723e190a333b00b9',
#                      'transaction': {'id': '0xb3876253048f6c9ac3bac1142007b6238acd6f4304dab31d2077f628332c3db5',
#                                      'timestamp': '1653700284'}},
#                     {'amount0': '35.73652785075630991',
#                      'amount1': '0.02059797116556912',
#                      'amountUSD': '71.50140481909732777810436333359016',
#                      'liquidity': '0.512538051530942795',
#                      'to': '0xd8dcbfca81aeb743e14b3c235df95abf56ff5f37',
#                      'transaction': {'id': '0x87ecba9685e3c8e08e9a35023b2f283308551094ed2cd692bad961ec6057f198',
#                                      'timestamp': '1653673029'}},
#                     {'amount0': '514.896996254579617174',
#                      'amount1': '0.294',
#                      'amountUSD': '1029.789243766614919046638341632623',
#                      'liquidity': '7.350206630335006897',
#                      'to': '0xcd8aa390e6eabbd2169b3580c1f7ce854675fd03',
#                      'transaction': {'id': '0x5ebdaefb5076bb99ded74d7d86d19d6f30d5559c584413457ef1f46f41b79e1d',
#                                      'timestamp': '1653669672'}},
#                     {'amount0': '15966.246338733778409392',
#                      'amount1': '15969.889068',
#                      'amountUSD': '31935.23511604852121369181197233388',
#                      'liquidity': '0.014186487364165593',
#                      'to': '0xd10fcd8e8085bf01896290f6cb097eefc1a95634',
#                      'transaction': {'id': '0xa04c5cd7e97de2450d552543223f92d3b9fd7a6abb9d7a6340504819d1d9238d',
#                                      'timestamp': '1653663593'}},
#                     {'amount0': '22416.313122634549740537',
#                      'amount1': '22414.979495',
#                      'amountUSD': '44866.79679675955777135684245340371',
#                      'liquidity': '0.019914856366633665',
#                      'to': '0xc1847f9c449293da64e4a87d969390511d49f724',
#                      'transaction': {'id': '0x4f95b913148dc944318993a0330def47dc98482edfb4a9a8cd1a003a93d52e43',
#                                      'timestamp': '1653518400'}},
#                     {'amount0': '10028.503113146830772231',
#                      'amount1': '10000',
#                      'amountUSD': '20031.1756813997102126352571964186',
#                      'liquidity': '0.008897150526070644',
#                      'to': '0x59daa74f2d15c87aac435ec18cb559f92490c100',
#                      'transaction': {'id': '0x344d17c6c82651acdc88d276666246f3b097d0926c2cebea2b1d99b4aa2c4aff',
#                                      'timestamp': '1653391809'}},
#                     {'amount0': '197.693124886360645028',
#                      'amount1': '0.099999999999999999',
#                      'amountUSD': '394.9339656948980405974129106668888',
#                      'liquidity': '2.66122570825122266',
#                      'to': '0xe7588398d9cf83fa8626ccce945f2d19dc91481e',
#                      'transaction': {'id': '0xb31ec7ce3b0b5f409a675a22447669599e7941dab97841a7db2cad4b1db6f983',
#                                      'timestamp': '1653207905'}},
#                     {'amount0': '39.61664227364994757',
#                      'amount1': '0.019999999999999999',
#                      'amountUSD': '79.28476707135761480750766355008656',
#                      'liquidity': '0.532780062737864984',
#                      'to': '0xa0f3bcc17f435fef64335c463f78d06c7d085cca',
#                      'transaction': {'id': '0x400cb4a6096ae7f380bdc35baace666dcd593a8516c80f481b6206fe92829d69',
#                                      'timestamp': '1653152148'}},
#                     {'amount0': '230.23385712547351298',
#                      'amount1': '0.116598713606595106',
#                      'amountUSD': '461.1615080830496717529835638072449',
#                      'liquidity': '3.101271193991726296',
#                      'to': '0xcd8aa390e6eabbd2169b3580c1f7ce854675fd03',
#                      'transaction': {'id': '0x6c80aaafa7ae1263c6d86bb62654eb3acb1319bd1357fad3a57e9c90d5ee8d28',
#                                      'timestamp': '1653120026'}},
#                     {'amount0': '19.297153702813783513',
#                      'amount1': '0.009841106134619619',
#                      'amountUSD': '38.61814377881776483146194258264234',
#                      'liquidity': '0.260843705762001019',
#                      'to': '0x4d59fbc8eabcc028bbc35064e20a1b60e8f0cd91',
#                      'transaction': {'id': '0xde53ce593d8b8daaafe491b5fa8785235128e57ebd9890392e188b31d269c7af',
#                                      'timestamp': '1653109987'}},
#                     {'amount0': '3050',
#                      'amount1': '1.564340796503793493',
#                      'amountUSD': '6116.277187044718571091196349181601',
#                      'liquidity': '41.372214535997274551',
#                      'to': '0x7c39d57b97c7e3ed305484f5513ccfc2089cde90',
#                      'transaction': {'id': '0x6c6e05e4db762d0701bb6bf357dd8cdf1537b0faa4988b3c4dbaac35e679666a',
#                                      'timestamp': '1652898025'}},
#                     {'amount0': '14.999841095010998056',
#                      'amount1': '0.007687845',
#                      'amountUSD': '30.01705900305720405763820190755566',
#                      'liquidity': '0.20340204300463166',
#                      'to': '0xd8dcbfca81aeb743e14b3c235df95abf56ff5f37',
#                      'transaction': {'id': '0xd46197a799c963eac6b285e9f42f6ed065062a7b6e308328fa10e9066d990279',
#                                      'timestamp': '1652889713'}},
#                     {'amount0': '76.409662805499877169',
#                      'amount1': '0.036918205711073531',
#                      'amountUSD': '152.779839856180840399253338025298',
#                      'liquidity': '1.006746209792079728',
#                      'to': '0x6794acf437ff25d0283bdeef026010cd1790875f',
#                      'transaction': {'id': '0xaae29d85093677b0d276ca2f208fd82076ee186ac0887f6ef16526041389b0f3',
#                                      'timestamp': '1652839323'}},
#                     {'amount0': '102.712416364284096312',
#                      'amount1': '0.049999999999999999',
#                      'amountUSD': '205.5828947107484828596246036472631',
#                      'liquidity': '1.358453301710225579',
#                      'to': '0x9064b136f2f04cd17f33ebb8d47a464701087df7',
#                      'transaction': {'id': '0x141d8fac48b33c4c967f5e052cf24b31cd8e6b508176ee8702a335feaa8c425d',
#                                      'timestamp': '1652820307'}},
#                     {'amount0': '20408.395600861297733795',
#                      'amount1': '9.811694140799406853',
#                      'amountUSD': '40884.07714955838624249111065227829',
#                      'liquidity': '268.410204569344282731',
#                      'to': '0xcd8aa390e6eabbd2169b3580c1f7ce854675fd03',
#                      'transaction': {'id': '0xf9cedf2cfd0bc312e0aa265c6dfb998edb1953b0cd30e08471e113ba9daa1510',
#                                      'timestamp': '1652786190'}}]}}

# %% [markdown]
# # Compute Volume

# %%
# query current USD price of ETH in Uniswap based on a weighted average of stablecoins.
eth_price_query = """
{
 bundle(id: "1") {
   ethPrice
 }
}
"""
eth_price = run_query(eth_price_query)

pprint(eth_price)
# Out:
# {'data': {'bundle': {'ethPrice': '1794.997177138197787236690233247948'}}}

# %%
# query current USD price of ETH in Uniswap based on a weighted average of stablecoins.
eth_price_pairs = [
 "0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc"
]
params_eth_price_pairs = {"eth_price_pairs": eth_price_pairs}
eth_price_byvolume_query = """
query($eth_price_pairs: [String!]) {
 swaps(first: 1, 
  where: { pair_in: $eth_price_pairs, timestamp_gt: 1654503528 }, orderBy: timestamp, orderDirection: asc) {
   transaction {
     id
     timestamp
   }
   amount0In
   amount1In
   amount0Out
   amount1Out
   amountUSD
 }
}
"""
eth_price_byvolume = run_query_var(eth_price_byvolume_query, params_eth_price_pairs)

pprint(eth_price_byvolume)

if float(eth_price_byvolume['data']['swaps'][0]['amount0In']) != 0:
  eth_price_byvolume_result = float(eth_price_byvolume['data']['swaps'][0]['amount0In'])/float(eth_price_byvolume['data']['swaps'][0]['amount1Out'])
else:
  eth_price_byvolume_result = float(eth_price_byvolume['data']['swaps'][0]['amount0Out'])/float(eth_price_byvolume['data']['swaps'][0]['amount1In'])

print('ETH PRICE IS: ', eth_price_byvolume_result)
# Out:
# {'data': {'swaps': [{'amount0In': '539.626088',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.284165115514204348',
#                      'amountUSD': '538.676591762887036143561404921746',
#                      'transaction': {'id': '0xea9d52361194f848356746a2182965d0419138ff170e67fea13a2803fc464fef',
#                                      'timestamp': '1654503529'}}]}}
# ETH PRICE IS:  1898.9878015939155

# %%
print(2634.665349/1.472669921217362735)
print(167.37499/0.093561282132463456)

print(1898.9878015939155*0.016)
# Out:
# 1789.0399681838337
# 1788.9343346431656
# 30.383804825502647

# %%
# Type 1: trade against WETH
pair_daily_volume_query = """
{
swaps(orderBy: timestamp, orderDirection: desc, where:
 { pair: "0xc9919a9eb691f571e41db417f911135b4ac46fe7" }
) {
     transaction {
        id
        timestamp
      }
     pair {
       token0 {
         symbol
       }
       token1 {
         symbol
       }
     }
     id
     transaction
     amount0In
     amount0Out
     amount1In
     amount1Out
     amountUSD
     to
 }
}
"""
pair_daily_volume = run_query(pair_daily_volume_query)

pprint(pair_daily_volume)
# Out:
# {'data': {'swaps': [{'amount0In': '0',
#                      'amount0Out': '954.10490882867114783',
#                      'amount1In': '0.087109307299713778',
#                      'amount1Out': '0',
#                      'amountUSD': '162.3017323177359330773202940380697',
#                      'id': '0xe976f2ebd70135153e8522c3aaa3c9d489717ef621d69b9e00a9f215d0474918-8',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x62e3c242b5e903071458ad90a160493d84911c77',
#                      'transaction': {'id': '0xe976f2ebd70135153e8522c3aaa3c9d489717ef621d69b9e00a9f215d0474918',
#                                      'timestamp': '1654768688'}},
#                     {'amount0In': '649.3506494',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.057907220009412727',
#                      'amountUSD': '102.5315103855514293805263468787294',
#                      'id': '0x812b27ebe764b8d599ae92e65b0e125b4a3c8efd7645d0330ab2673e5ef61e3d-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#                      'transaction': {'id': '0x812b27ebe764b8d599ae92e65b0e125b4a3c8efd7645d0330ab2673e5ef61e3d',
#                                      'timestamp': '1654755831'}},
#                     {'amount0In': '0',
#                      'amount0Out': '494.41978556179542839',
#                      'amount1In': '0.04483130355662775',
#                      'amount1Out': '0',
#                      'amountUSD': '82.13605599611898386855610954376218',
#                      'id': '0xd569062b05080e43f943090bbc2543d45c13755277be6483b0188987512aa2a4-1',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0xd569062b05080e43f943090bbc2543d45c13755277be6483b0188987512aa2a4',
#                                      'timestamp': '1654668383'}},
#                     {'amount0In': '0',
#                      'amount0Out': '182.70045888568811605',
#                      'amount1In': '0.016',
#                      'amount1Out': '0',
#                      'amountUSD': '30.38030441659072739208787732415776',
#                      'id': '0xedd667aeaeb8c682cd13aec146261a6074c467193876a4e406fc62f3a5e19155-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xf98cc4b710944e3c72c8f206a09421ec102dca08',
#                      'transaction': {'id': '0xedd667aeaeb8c682cd13aec146261a6074c467193876a4e406fc62f3a5e19155',
#                                      'timestamp': '1654503529'}},
#                     {'amount0In': '0',
#                      'amount0Out': '967.114166263594600874',
#                      'amount1In': '0.08',
#                      'amount1Out': '0',
#                      'amountUSD': '154.535053911155236598054656800558',
#                      'id': '0xc74ad91c874359bce3270c06ea26460b174ef4082a72f4ba2b00c676c6eade62-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x62e3c242b5e903071458ad90a160493d84911c77',
#                      'transaction': {'id': '0xc74ad91c874359bce3270c06ea26460b174ef4082a72f4ba2b00c676c6eade62',
#                                      'timestamp': '1654499251'}},
#                     {'amount0In': '1298.7012988',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.108601907364179194',
#                      'amountUSD': '197.2975293986977797244059632304813',
#                      'id': '0xf39d57e6cce5ff8df55cb803c2de426cdb90d50832b8df936055a660309ce985-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x1111111254fb6c44bac0bed2854e76f90643097d',
#                      'transaction': {'id': '0xf39d57e6cce5ff8df55cb803c2de426cdb90d50832b8df936055a660309ce985',
#                                      'timestamp': '1654496274'}},
#                     {'amount0In': '19463.370736369887785458',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '1157.675179861647564381',
#                      'amountUSD': '1035732.883693670619952829921900157',
#                      'id': '0x9da5620c7803123849f8f65029a6e73dfd5e7922bf8815bbbc495f7313865880-1',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x000000000035b5e5ad9019092c665357240f594e',
#                      'transaction': {'id': '0x9da5620c7803123849f8f65029a6e73dfd5e7922bf8815bbbc495f7313865880',
#                                      'timestamp': '1654432756'}},
#                     {'amount0In': '0',
#                      'amount0Out': '19167.809153296665628187',
#                      'amount1In': '1157.658926297668445986',
#                      'amount1Out': '0',
#                      'amountUSD': '2068207.090312683960461532632688075',
#                      'id': '0x7702696cb62039a295ad77b6e5a9684c64c9f2c5cc3cf447c713313f9bf54181-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x62e3c242b5e903071458ad90a160493d84911c77',
#                      'transaction': {'id': '0x7702696cb62039a295ad77b6e5a9684c64c9f2c5cc3cf447c713313f9bf54181',
#                                      'timestamp': '1654432756'}},
#                     {'amount0In': '0',
#                      'amount0Out': '384.915147460101858337',
#                      'amount1In': '0.03469375',
#                      'amount1Out': '0',
#                      'amountUSD': '62.32797447381097606245121727947374',
#                      'id': '0xa3a509d48b4c9c6432ffd0c46cac6e6d1fad5395a4cf1dcaa0fb6dd98d1a7b82-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0xa3a509d48b4c9c6432ffd0c46cac6e6d1fad5395a4cf1dcaa0fb6dd98d1a7b82',
#                                      'timestamp': '1654426696'}},
#                     {'amount0In': '874.358028061008428415',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.080380204908462933',
#                      'amountUSD': '140.9912911183920638860407598128405',
#                      'id': '0x6a8031402df1401112a7b5a17654673c708d111912946ac1beb169a13d506f59-5',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xf6465aa892574e159dd1b4ab92ce12a3dbe47774',
#                      'transaction': {'id': '0x6a8031402df1401112a7b5a17654673c708d111912946ac1beb169a13d506f59',
#                                      'timestamp': '1654417560'}},
#                     {'amount0In': '0',
#                      'amount0Out': '1423.835841740742334025',
#                      'amount1In': '0.128050033997107593',
#                      'amount1Out': '0',
#                      'amountUSD': '235.927223254465913385978437799856',
#                      'id': '0xd4cb845cfc3515e7a1c2f2ddfc816a710bff9070e4956a105b536d6a5410a10e-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x62e3c242b5e903071458ad90a160493d84911c77',
#                      'transaction': {'id': '0xd4cb845cfc3515e7a1c2f2ddfc816a710bff9070e4956a105b536d6a5410a10e',
#                                      'timestamp': '1654368221'}},
#                     {'amount0In': '649.3506494',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.055744419541839009',
#                      'amountUSD': '97.74343227385096792009322612203958',
#                      'id': '0xdab8a338685086f3a649c806f143d714bb57bcfdb4bba65714a3792d4d1ff61f-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x1111111254fb6c44bac0bed2854e76f90643097d',
#                      'transaction': {'id': '0xdab8a338685086f3a649c806f143d714bb57bcfdb4bba65714a3792d4d1ff61f',
#                                      'timestamp': '1654355955'}},
#                     {'amount0In': '649.3506494',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.059576286529611879',
#                      'amountUSD': '103.9266376047320051222919560688396',
#                      'id': '0xf9151901ab58da0e8785f5ddd6cff1330300ef3295e5b16289ed7d3697ed7bb8-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0xf9151901ab58da0e8785f5ddd6cff1330300ef3295e5b16289ed7d3697ed7bb8',
#                                      'timestamp': '1654331694'}},
#                     {'amount0In': '795.971169044984265937',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.078862053404149897',
#                      'amountUSD': '136.3305398378179535983766948651003',
#                      'id': '0x63cebc89e8574f8c96339779bb31068979cbcb4f4366c21631c014375415a239-1',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xdfee68a9adb981cd08699891a11cabe10f25ec44',
#                      'transaction': {'id': '0x63cebc89e8574f8c96339779bb31068979cbcb4f4366c21631c014375415a239',
#                                      'timestamp': '1654320314'}},
#                     {'amount0In': '0',
#                      'amount0Out': '660.630532492903679132',
#                      'amount1In': '0.06630785691288',
#                      'amount1Out': '0',
#                      'amountUSD': '118.8908060508276740601290076538775',
#                      'id': '0x53e33f42a7ced90c83cede83b7ea9bbf202acebbdb8ca3ad66fce8a2ab895bdb-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x1111111254fb6c44bac0bed2854e76f90643097d',
#                      'transaction': {'id': '0x53e33f42a7ced90c83cede83b7ea9bbf202acebbdb8ca3ad66fce8a2ab895bdb',
#                                      'timestamp': '1654319503'}},
#                     {'amount0In': '649.3506494',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.064744802358038793',
#                      'amountUSD': '112.1308276472676306164493837938778',
#                      'id': '0xbed174bf7dc6c709589ed72a42f18a8b00b3d6352e98a384d8b0a0245fa4a6cd-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x0d4a11d5eeaac28ec3f61d100daf4d40471f1852',
#                      'transaction': {'id': '0xbed174bf7dc6c709589ed72a42f18a8b00b3d6352e98a384d8b0a0245fa4a6cd',
#                                      'timestamp': '1654315850'}},
#                     {'amount0In': '0',
#                      'amount0Out': '796.981149662969058611',
#                      'amount1In': '0.0793',
#                      'amount1Out': '0',
#                      'amountUSD': '156.4588332495983036468669903795499',
#                      'id': '0x31e9a0957a1ecb151db8020690479b505604da7dd87edb7372514b9972cfa89f-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0x31e9a0957a1ecb151db8020690479b505604da7dd87edb7372514b9972cfa89f',
#                                      'timestamp': '1654093228'}},
#                     {'amount0In': '71',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.006751125431928191',
#                      'amountUSD': '13.35254543361124762806648622181167',
#                      'id': '0xe90025e58f52c651efbb3065aac615e4fd2e73027ac78fda2c0134842488217d-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xdef1c0ded9bec7f1a1670819833240f027b25eff',
#                      'transaction': {'id': '0xe90025e58f52c651efbb3065aac615e4fd2e73027ac78fda2c0134842488217d',
#                                      'timestamp': '1653998122'}},
#                     {'amount0In': '101.092963215313855836',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.009700883586962019',
#                      'amountUSD': '19.15961668481354238347161927548402',
#                      'id': '0x81cf42d0fe00e5ae8b0623c212180daa3fb4f097296cdd93617593983a164c5e-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xb154256024041e3011c8024874e698b69a2081b3',
#                      'transaction': {'id': '0x81cf42d0fe00e5ae8b0623c212180daa3fb4f097296cdd93617593983a164c5e',
#                                      'timestamp': '1653947473'}},
#                     {'amount0In': '223.9882349613959754',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.021871646346402171',
#                      'amountUSD': '41.29240151776651434062848762870909',
#                      'id': '0xe5a14f2506f39d1491be6bbff76aa6d9b011e829850e875af341ac652e15aa83-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x819f3450da6f110ba6ea52195b3beafa246062de',
#                      'transaction': {'id': '0xe5a14f2506f39d1491be6bbff76aa6d9b011e829850e875af341ac652e15aa83',
#                                      'timestamp': '1653906554'}},
#                     {'amount0In': '0',
#                      'amount0Out': '150.775743998681667518',
#                      'amount1In': '0.01486875',
#                      'amount1Out': '0',
#                      'amountUSD': '26.61577370979348202031932776566078',
#                      'id': '0x23039564064839251d932df1ff66c8f39c27d28e2452813e5e09a1032b1edb7e-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0x23039564064839251d932df1ff66c8f39c27d28e2452813e5e09a1032b1edb7e',
#                                      'timestamp': '1653743440'}},
#                     {'amount0In': '500',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.049956097060730434',
#                      'amountUSD': '86.86245729672972480444830868981839',
#                      'id': '0xbe0b34e7843270a47c10f69ada1dcbfce9cce1defbae08785b4500385253d57e-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x68b3465833fb72a70ecdf485e0e4c7bd8665fc45',
#                      'transaction': {'id': '0xbe0b34e7843270a47c10f69ada1dcbfce9cce1defbae08785b4500385253d57e',
#                                      'timestamp': '1653715524'}},
#                     {'amount0In': '0',
#                      'amount0Out': '54.715846844171226931',
#                      'amount1In': '0.005633882968885601',
#                      'amount1Out': '0',
#                      'amountUSD': '9.90789953078218290559802966516132',
#                      'id': '0xf7964edc00f1f646a62471f564eb3a72fca63c7cd1cbaae04402a0939793bb6f-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xe66b31678d6c16e9ebf358268a790b763c133750',
#                      'transaction': {'id': '0xf7964edc00f1f646a62471f564eb3a72fca63c7cd1cbaae04402a0939793bb6f',
#                                      'timestamp': '1653711224'}},
#                     {'amount0In': '0',
#                      'amount0Out': '598.482964540643444813',
#                      'amount1In': '0.059475',
#                      'amount1Out': '0',
#                      'amountUSD': '104.4741263914959095834138361822416',
#                      'id': '0xab20091427be1590b1dd7a914e1c67edd8f76403494a6e9ccdc6d11487f1a612-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0xab20091427be1590b1dd7a914e1c67edd8f76403494a6e9ccdc6d11487f1a612',
#                                      'timestamp': '1653674349'}},
#                     {'amount0In': '703.17899180649277243',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.069862843054163821',
#                      'amountUSD': '120.3826242302718475094707230400238',
#                      'id': '0x768643e907ff1de780fcd772e9017db4a4195d47f0cce716ccc3d42bc92bb0d7-3',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xf6465aa892574e159dd1b4ab92ce12a3dbe47774',
#                      'transaction': {'id': '0x768643e907ff1de780fcd772e9017db4a4195d47f0cce716ccc3d42bc92bb0d7',
#                                      'timestamp': '1653618664'}},
#                     {'amount0In': '0',
#                      'amount0Out': '900.000000000000004801',
#                      'amount1In': '0.089001046044215919',
#                      'amount1Out': '0',
#                      'amountUSD': '165.3071079891740611363967643834836',
#                      'id': '0xb20ba309a5ac6d41e185ee8dce96f2006202f0b97459370a476a7eb448036ea0-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x01ebd1d4329a976069bc05307fce9829b7b563bb',
#                      'transaction': {'id': '0xb20ba309a5ac6d41e185ee8dce96f2006202f0b97459370a476a7eb448036ea0',
#                                      'timestamp': '1653566298'}},
#                     {'amount0In': '0',
#                      'amount0Out': '151.693275750750221856',
#                      'amount1In': '0.014176066657326759',
#                      'amount1Out': '0',
#                      'amountUSD': '27.70854344606504728447939803219594',
#                      'id': '0x914ba1fea118b2c8dabb46a5d09af54c2c0bf717c6b4fa8f9c07e5ee08b1dddf-1',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xe66b31678d6c16e9ebf358268a790b763c133750',
#                      'transaction': {'id': '0x914ba1fea118b2c8dabb46a5d09af54c2c0bf717c6b4fa8f9c07e5ee08b1dddf',
#                                      'timestamp': '1653534018'}},
#                     {'amount0In': '418.873312728538298099',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.039465613604327486',
#                      'amountUSD': '76.75636328953282346800539064014253',
#                      'id': '0x5b62825667c0a0df08c0a9e6e731f2b25c1305cd4226cc1ad7e59734e1ab06b0-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x55d5c232d921b9eaa6b37b5845e439acd04b4dba',
#                      'transaction': {'id': '0x5b62825667c0a0df08c0a9e6e731f2b25c1305cd4226cc1ad7e59734e1ab06b0',
#                                      'timestamp': '1653508196'}},
#                     {'amount0In': '0',
#                      'amount0Out': '97.275419748220968481',
#                      'amount1In': '0.009377249264915275',
#                      'amount1Out': '0',
#                      'amountUSD': '18.46310679725671039832136281218507',
#                      'id': '0xd922555722b72a5dc3cd3c93de3c8b7d2067b13ebb572182d4920fe64c7d62f3-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x4ade08995a53f1dc34c83e5b1fcf5e4482c56c52',
#                      'transaction': {'id': '0xd922555722b72a5dc3cd3c93de3c8b7d2067b13ebb572182d4920fe64c7d62f3',
#                                      'timestamp': '1653393766'}},
#                     {'amount0In': '0',
#                      'amount0Out': '389.791325814514170169',
#                      'amount1In': '0.0366201',
#                      'amount1Out': '0',
#                      'amountUSD': '72.64839058718377630798711262532944',
#                      'id': '0x7a9c1bec0d1a291063ec1ee35ee510504e0e29d5bb7e86c55fc00718642dced3-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xe66b31678d6c16e9ebf358268a790b763c133750',
#                      'transaction': {'id': '0x7a9c1bec0d1a291063ec1ee35ee510504e0e29d5bb7e86c55fc00718642dced3',
#                                      'timestamp': '1653386577'}},
#                     {'amount0In': '556.21655059015302902',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.052405977924032618',
#                      'amountUSD': '102.7380272814817697386993905341531',
#                      'id': '0xd7d25938d8c9fae73082bf722093ddecbc9d81c099a4b92fc076606dcaa7ec4a-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x1111111254fb6c44bac0bed2854e76f90643097d',
#                      'transaction': {'id': '0xd7d25938d8c9fae73082bf722093ddecbc9d81c099a4b92fc076606dcaa7ec4a',
#                                      'timestamp': '1653368329'}},
#                     {'amount0In': '0',
#                      'amount0Out': '205.357009764956948526',
#                      'amount1In': '0.019825',
#                      'amount1Out': '0',
#                      'amountUSD': '39.97875220677179423994164465268367',
#                      'id': '0x76c24f8c36f561b6837ef2804e06ffdc17a95fc38c9b72e754f7bd5964986d89-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0x76c24f8c36f561b6837ef2804e06ffdc17a95fc38c9b72e754f7bd5964986d89',
#                                      'timestamp': '1653253704'}},
#                     {'amount0In': '0',
#                      'amount0Out': '59.589248573242921344',
#                      'amount1In': '0.005672044741446481',
#                      'amount1Out': '0',
#                      'amountUSD': '11.46369991987454336002841329534455',
#                      'id': '0xb81b2a7078484a6f7d990f6f9cead650caa2b8f7f9f52cb45b4dd27fc42ceb33-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0xb81b2a7078484a6f7d990f6f9cead650caa2b8f7f9f52cb45b4dd27fc42ceb33',
#                                      'timestamp': '1653230952'}},
#                     {'amount0In': '0',
#                      'amount0Out': '318.700972138232260149',
#                      'amount1In': '0.0297375',
#                      'amount1Out': '0',
#                      'amountUSD': '60.80112631516524084772941276387626',
#                      'id': '0x7fab2fc7db3479e8785ad98ab575270cb5175d7e00b42eccdc70ea3b2f6e0114-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0x7fab2fc7db3479e8785ad98ab575270cb5175d7e00b42eccdc70ea3b2f6e0114',
#                                      'timestamp': '1653218193'}},
#                     {'amount0In': '649.3506494',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.061298742444851194',
#                      'amountUSD': '119.2952097314607460778951414175391',
#                      'id': '0x76ada75f8b6cbbd418fd9cefb72d0c45292a66502cc871a4d9a8dec3b68eae1b-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#                      'transaction': {'id': '0x76ada75f8b6cbbd418fd9cefb72d0c45292a66502cc871a4d9a8dec3b68eae1b',
#                                      'timestamp': '1653181504'}},
#                     {'amount0In': '0',
#                      'amount0Out': '25.607531942939440449',
#                      'amount1In': '0.002513187889988374',
#                      'amount1Out': '0',
#                      'amountUSD': '4.948225177421160701789194637112181',
#                      'id': '0x9102df1e85901b0e017e9ebb51e034e9877c044eb5e7febf9a53569112f34f88-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xe66b31678d6c16e9ebf358268a790b763c133750',
#                      'transaction': {'id': '0x9102df1e85901b0e017e9ebb51e034e9877c044eb5e7febf9a53569112f34f88',
#                                      'timestamp': '1653172001'}},
#                     {'amount0In': '0',
#                      'amount0Out': '42.285050046616232002',
#                      'amount1In': '0.004134824089633718',
#                      'amount1Out': '0',
#                      'amountUSD': '8.1460452032564680119049027756164',
#                      'id': '0x2b2b50ae4398a9797d6a33c987d0053e848e7f89eaf6561079998278174a9fa2-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xe66b31678d6c16e9ebf358268a790b763c133750',
#                      'transaction': {'id': '0x2b2b50ae4398a9797d6a33c987d0053e848e7f89eaf6561079998278174a9fa2',
#                                      'timestamp': '1653126408'}},
#                     {'amount0In': '0',
#                      'amount0Out': '207.281714235711557169',
#                      'amount1In': '0.02',
#                      'amount1Out': '0',
#                      'amountUSD': '39.34238836694502153678662459749689',
#                      'id': '0xce6647fbdd918de4492f3c156ba1211f6fd639b6729059c6a853cab0903de7d1-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xd27c58742093bc66b7cc2525d6a4cb0bd51e4e9a',
#                      'transaction': {'id': '0xce6647fbdd918de4492f3c156ba1211f6fd639b6729059c6a853cab0903de7d1',
#                                      'timestamp': '1653091556'}},
#                     {'amount0In': '515.898144177136454023',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.050311933873345891',
#                      'amountUSD': '97.49796824769974128529797537221046',
#                      'id': '0xd5fd44b3116296f85c6c06e12465cdb3438a671e5e871b166151b21372b4d8b7-3',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xf6465aa892574e159dd1b4ab92ce12a3dbe47774',
#                      'transaction': {'id': '0xd5fd44b3116296f85c6c06e12465cdb3438a671e5e871b166151b21372b4d8b7',
#                                      'timestamp': '1653085104'}},
#                     {'amount0In': '0',
#                      'amount0Out': '370.603981263082818552',
#                      'amount1In': '0.036637420676258145',
#                      'amount1Out': '0',
#                      'amountUSD': '74.30850609833499209582744714867835',
#                      'id': '0x10ad8a2f51ad8d9666312e6d0b769c49b282485f4f2c8794659ae678fa6f47b3-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x61e9f3f3491dfd96e12798bdccee8d5ed5fbdf82',
#                      'transaction': {'id': '0x10ad8a2f51ad8d9666312e6d0b769c49b282485f4f2c8794659ae678fa6f47b3',
#                                      'timestamp': '1652986248'}},
#                     {'amount0In': '0',
#                      'amount0Out': '104.634469113938430328',
#                      'amount1In': '0.010082570138788106',
#                      'amount1Out': '0',
#                      'amountUSD': '19.82806608172378186140267997758479',
#                      'id': '0x7e0f95d59368651aebd2be04c6c6b22e512e5af4f0c66653b4cb58212e9210c5-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xe66b31678d6c16e9ebf358268a790b763c133750',
#                      'transaction': {'id': '0x7e0f95d59368651aebd2be04c6c6b22e512e5af4f0c66653b4cb58212e9210c5',
#                                      'timestamp': '1652944570'}},
#                     {'amount0In': '126.75994189882278656',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.012155776795158677',
#                      'amountUSD': '23.23050349599830136628082854992079',
#                      'id': '0x5dbff96761cfdc9ede6a862f8fddd57d8c2b9f8f0da9d8f7fba126af2ae62727-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x1ffc57cada109985ad896a69fbcebd565db4290e',
#                      'transaction': {'id': '0x5dbff96761cfdc9ede6a862f8fddd57d8c2b9f8f0da9d8f7fba126af2ae62727',
#                                      'timestamp': '1652927670'}},
#                     {'amount0In': '0',
#                      'amount0Out': '616.933230393575273764',
#                      'amount1In': '0.058',
#                      'amount1Out': '0',
#                      'amountUSD': '116.0844329547510405967665698122467',
#                      'id': '0x9456f3cd6a1c3544a5d9908d51a0952c409dcacd23cbc306f3d55d6e55922223-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xf98cc4b710944e3c72c8f206a09421ec102dca08',
#                      'transaction': {'id': '0x9456f3cd6a1c3544a5d9908d51a0952c409dcacd23cbc306f3d55d6e55922223',
#                                      'timestamp': '1652893203'}},
#                     {'amount0In': '0',
#                      'amount0Out': '18692.444878206688719986',
#                      'amount1In': '275.378678278361256229',
#                      'amount1Out': '0',
#                      'amountUSD': '542567.4691634595645457724714387508',
#                      'id': '0x3f56893c8054435f938a9a616e497e34abcf7cd112b502edca6aca6e8b705580-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x62e3c242b5e903071458ad90a160493d84911c77',
#                      'transaction': {'id': '0x3f56893c8054435f938a9a616e497e34abcf7cd112b502edca6aca6e8b705580',
#                                      'timestamp': '1652885941'}},
#                     {'amount0In': '19182.65694268854537956',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '275.413618359960249096',
#                      'amountUSD': '273032.8278084397591811986813123268',
#                      'id': '0x0a8d3374ea8e014d52cffe1787c70f111a7d01ae96a95c11f12a15940b8b413a-1',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x00000000726422a6fecb4759b44d47e48cf746aa',
#                      'transaction': {'id': '0x0a8d3374ea8e014d52cffe1787c70f111a7d01ae96a95c11f12a15940b8b413a',
#                                      'timestamp': '1652885941'}},
#                     {'amount0In': '627.205169610126771273',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.061426743567081832',
#                      'amountUSD': '123.4231188452494240621322613782524',
#                      'id': '0x038c1cc5f323c9d2773740d5c05ef6ebf542ffd719b56f496d8b4f423769f8ee-3',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xa1006d0051a35b0000f961a8000000009ea8d2db',
#                      'transaction': {'id': '0x038c1cc5f323c9d2773740d5c05ef6ebf542ffd719b56f496d8b4f423769f8ee',
#                                      'timestamp': '1652870419'}},
#                     {'amount0In': '0',
#                      'amount0Out': '288.678817230594819051',
#                      'amount1In': '0.02895970509528258',
#                      'amount1Out': '0',
#                      'amountUSD': '59.46862283771720439746519357363852',
#                      'id': '0x1cd79911798e261254be845fe2fb795e313bc2fffcdacc04d61edacb1f0535a3-1',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0x1cd79911798e261254be845fe2fb795e313bc2fffcdacc04d61edacb1f0535a3',
#                                      'timestamp': '1652870204'}},
#                     {'amount0In': '679.050895210267619277',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.069198275792168017',
#                      'amountUSD': '138.6338869571110569477045199189995',
#                      'id': '0xacc6357c73595c532b6d3559ea0eb86d48c22992a6d19bac892aefea6aedf941-3',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xf6465aa892574e159dd1b4ab92ce12a3dbe47774',
#                      'transaction': {'id': '0xacc6357c73595c532b6d3559ea0eb86d48c22992a6d19bac892aefea6aedf941',
#                                      'timestamp': '1652848559'}},
#                     {'amount0In': '168.35052291060731083',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.01797836526728861',
#                      'amountUSD': '37.08531881445753994342303271682596',
#                      'id': '0x43e22c5c32e17e5c00b10a3977ddf0f9f45f0fa045fd30c6975f0af6c85aef1c-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xdef1c0ded9bec7f1a1670819833240f027b25eff',
#                      'transaction': {'id': '0x43e22c5c32e17e5c00b10a3977ddf0f9f45f0fa045fd30c6975f0af6c85aef1c',
#                                      'timestamp': '1652839453'}},
#                     {'amount0In': '0',
#                      'amount0Out': '131.15283031947390349',
#                      'amount1In': '0.01411919068989123',
#                      'amount1Out': '0',
#                      'amountUSD': '29.72074769225896876706676739164722',
#                      'id': '0x13c9b792c3b991a01dd2368db2cb477ef4e67ee2b65ea07e7b9114862ea5eaf4-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xe66b31678d6c16e9ebf358268a790b763c133750',
#                      'transaction': {'id': '0x13c9b792c3b991a01dd2368db2cb477ef4e67ee2b65ea07e7b9114862ea5eaf4',
#                                      'timestamp': '1652834485'}},
#                     {'amount0In': '0',
#                      'amount0Out': '330.73157159793856884',
#                      'amount1In': '0.03469375',
#                      'amount1Out': '0',
#                      'amountUSD': '71.8333308304662989466495164010633',
#                      'id': '0x3ee87abedcb42edcffa6f7041dd17e94fe5f33b0889548b7e4dc6ebd4b550b54-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0x3ee87abedcb42edcffa6f7041dd17e94fe5f33b0889548b7e4dc6ebd4b550b54',
#                                      'timestamp': '1652807178'}},
#                     {'amount0In': '0',
#                      'amount0Out': '188.785579074807866185',
#                      'amount1In': '0.019240159460109465',
#                      'amount1Out': '0',
#                      'amountUSD': '39.65846373638904449569044206381727',
#                      'id': '0x3097556601a421da41d175f06277b0ffe0f251f102bdc7c1172529702a8e3f39-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xe66b31678d6c16e9ebf358268a790b763c133750',
#                      'transaction': {'id': '0x3097556601a421da41d175f06277b0ffe0f251f102bdc7c1172529702a8e3f39',
#                                      'timestamp': '1652806560'}},
#                     {'amount0In': '0',
#                      'amount0Out': '11.308874130298954117',
#                      'amount1In': '0.0011399375',
#                      'amount1Out': '0',
#                      'amountUSD': '2.373616817067755877457703867204902',
#                      'id': '0x5bc0a950c9fa46db52f9beaf6179e0a4b8e14698eb3c8fe6021714e5a8d1dad5-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0x5bc0a950c9fa46db52f9beaf6179e0a4b8e14698eb3c8fe6021714e5a8d1dad5',
#                                      'timestamp': '1652784357'}},
#                     {'amount0In': '0',
#                      'amount0Out': '25.520976703930518827',
#                      'amount1In': '0.0025673375',
#                      'amount1Out': '0',
#                      'amountUSD': '5.349068445802699981680005473848307',
#                      'id': '0xab7a066dd4b0841f250b22a3b435ca0b28c4db99a426b208131fc29b6309751f-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0xab7a066dd4b0841f250b22a3b435ca0b28c4db99a426b208131fc29b6309751f',
#                                      'timestamp': '1652784257'}},
#                     {'amount0In': '0',
#                      'amount0Out': '44.511572634686882482',
#                      'amount1In': '0.004460625',
#                      'amount1Out': '0',
#                      'amountUSD': '9.300427425712127567667836066857025',
#                      'id': '0x2b50848ca8349e330f56154311ca4346b568a520a584f47fa2ac8973a137500b-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0x2b50848ca8349e330f56154311ca4346b568a520a584f47fa2ac8973a137500b',
#                                      'timestamp': '1652784116'}},
#                     {'amount0In': '0',
#                      'amount0Out': '486.746034133416775165',
#                      'amount1In': '0.047399491532727194',
#                      'amount1Out': '0',
#                      'amountUSD': '100.1837720763021337472267533668592',
#                      'id': '0x6e950d1ba6c1d75892103aa1d1c033d6d12e352937ed71aa843f2b4ae39d6a9f-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xe66b31678d6c16e9ebf358268a790b763c133750',
#                      'transaction': {'id': '0x6e950d1ba6c1d75892103aa1d1c033d6d12e352937ed71aa843f2b4ae39d6a9f',
#                                      'timestamp': '1652779583'}},
#                     {'amount0In': '0',
#                      'amount0Out': '929.90059524904197795',
#                      'amount1In': '0.084055598069770157',
#                      'amount1Out': '0',
#                      'amountUSD': '178.2077150443207835198187607542576',
#                      'id': '0x3946c6536a5f675a801475bfcb2baeab6a4ea18e7d0b3cb4ed2e4db4f583eea0-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x62e3c242b5e903071458ad90a160493d84911c77',
#                      'transaction': {'id': '0x3946c6536a5f675a801475bfcb2baeab6a4ea18e7d0b3cb4ed2e4db4f583eea0',
#                                      'timestamp': '1652762826'}},
#                     {'amount0In': '533.617183172747171018',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.046958395580407852',
#                      'amountUSD': '93.99945580155159008928880776103574',
#                      'id': '0xb2b187dc7c3eaa1eeb74ef6c6a409107bdee8599b46f44c8a4ee8b18afd30b5a-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x1111111254fb6c44bac0bed2854e76f90643097d',
#                      'transaction': {'id': '0xb2b187dc7c3eaa1eeb74ef6c6a409107bdee8599b46f44c8a4ee8b18afd30b5a',
#                                      'timestamp': '1652744143'}},
#                     {'amount0In': '259.74',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.02381048052983233',
#                      'amountUSD': '47.90862019713482044970862144477098',
#                      'id': '0x0975b8a31d5bbd0c3407e168ac5b9376fc8a657e87e6391db55caa1cc473dc16-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#                      'transaction': {'id': '0x0975b8a31d5bbd0c3407e168ac5b9376fc8a657e87e6391db55caa1cc473dc16',
#                                      'timestamp': '1652702711'}},
#                     {'amount0In': '0',
#                      'amount0Out': '221.735868333528235098',
#                      'amount1In': '0.020488060013277892',
#                      'amount1Out': '0',
#                      'amountUSD': '43.04799777405848648412189031461974',
#                      'id': '0x76337069bda6288e3bd05b3f9ada22c68f4df2e2d0af331603cabdf803e3070f-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xd24f2adbf5c7c2450396e41c008653e526120b6e',
#                      'transaction': {'id': '0x76337069bda6288e3bd05b3f9ada22c68f4df2e2d0af331603cabdf803e3070f',
#                                      'timestamp': '1652666041'}},
#                     {'amount0In': '0',
#                      'amount0Out': '520.599202709585909149',
#                      'amount1In': '0.046288674478371661',
#                      'amount1Out': '0',
#                      'amountUSD': '99.94545185768196261961822288289048',
#                      'id': '0x694ee510b3addb8d5ce5364b7dd503f791b4bf76a4f9a2764db5e41fc9a260e1-1',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xe66b31678d6c16e9ebf358268a790b763c133750',
#                      'transaction': {'id': '0x694ee510b3addb8d5ce5364b7dd503f791b4bf76a4f9a2764db5e41fc9a260e1',
#                                      'timestamp': '1652655859'}},
#                     {'amount0In': '0',
#                      'amount0Out': '290.493045275557759896',
#                      'amount1In': '0.02478125',
#                      'amount1Out': '0',
#                      'amountUSD': '51.69366114052601919962908217829121',
#                      'id': '0x8375b602f2c4e60e1cbb4c0062ba603c7eb4fac18eda5c02eae2935acbefb3e3-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0x8375b602f2c4e60e1cbb4c0062ba603c7eb4fac18eda5c02eae2935acbefb3e3',
#                                      'timestamp': '1652627732'}},
#                     {'amount0In': '0',
#                      'amount0Out': '146.004399889359738109',
#                      'amount1In': '0.012185365253246354',
#                      'amount1Out': '0',
#                      'amountUSD': '24.78931453280784094602853375953707',
#                      'id': '0xf3d819dd141872cf1f6b7dc237f52407fc5fa88dbeadfc3d3ff59bd814a6e4b4-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xe66b31678d6c16e9ebf358268a790b763c133750',
#                      'transaction': {'id': '0xf3d819dd141872cf1f6b7dc237f52407fc5fa88dbeadfc3d3ff59bd814a6e4b4',
#                                      'timestamp': '1652581484'}},
#                     {'amount0In': '0',
#                      'amount0Out': '657.933559320217829066',
#                      'amount1In': '0.05278511210438',
#                      'amount1Out': '0',
#                      'amountUSD': '105.7806202044895236869040156194122',
#                      'id': '0x3545560236c4ba337f9b0adf60eb7ede51835bca08023169b05dc3009bf010f1-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x1111111254fb6c44bac0bed2854e76f90643097d',
#                      'transaction': {'id': '0x3545560236c4ba337f9b0adf60eb7ede51835bca08023169b05dc3009bf010f1',
#                                      'timestamp': '1652528924'}},
#                     {'amount0In': '1436.312628138937715658',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.119142624263596926',
#                      'amountUSD': '235.6305027523074933351440816310328',
#                      'id': '0x639b958d0aea2007919d27c83fb3c7adc1ccf4a57b0c28c9e59aa1f438d46e8f-3',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xa75af537fb853bb432f6a51d47d70e349fffc6ba',
#                      'transaction': {'id': '0x639b958d0aea2007919d27c83fb3c7adc1ccf4a57b0c28c9e59aa1f438d46e8f',
#                                      'timestamp': '1652499523'}},
#                     {'amount0In': '0',
# ...
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x62e3c242b5e903071458ad90a160493d84911c77',
#                      'transaction': {'id': '0x632826ff56368fd1e6dc9798eb20b56c2635f10a1f10a48c03980d0631f9532b',
#                                      'timestamp': '1652323544'}},
#                     {'amount0In': '11899.165351203049061935',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '1.967807535894888324',
#                      'amountUSD': '2915.521056782760169942922370095665',
#                      'id': '0x1a5b4ee08eb278c263273467eecbc736b5de289cf65992081046ab050390da14-1',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x000000000035b5e5ad9019092c665357240f594e',
#                      'transaction': {'id': '0x1a5b4ee08eb278c263273467eecbc736b5de289cf65992081046ab050390da14',
#                                      'timestamp': '1652323544'}},
#                     {'amount0In': '1425.577349061672531912',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.123965415776619219',
#                      'amountUSD': '252.6155641628274532593768463579549',
#                      'id': '0x0032345207d9677d346eaee3cc178bf2083701f10f84b745de962b69388c2dfc-1',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x5aa3393e361c2eb342408559309b3e873cd876d6',
#                      'transaction': {'id': '0x0032345207d9677d346eaee3cc178bf2083701f10f84b745de962b69388c2dfc',
#                                      'timestamp': '1652321913'}},
#                     {'amount0In': '0',
#                      'amount0Out': '509.455724060569642362',
#                      'amount1In': '0.04666100000000004',
#                      'amount1Out': '0',
#                      'amountUSD': '100.2019787559753634475101183436764',
#                      'id': '0x2bdd75c5ef5f326df46c78977b81e23605a7c061c053a9408bf3c2cd481d50b1-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xf058025c9c6b0a2318ec203062cd78bd4e538a6d',
#                      'transaction': {'id': '0x2bdd75c5ef5f326df46c78977b81e23605a7c061c053a9408bf3c2cd481d50b1',
#                                      'timestamp': '1652319029'}},
#                     {'amount0In': '1566.829356591870977118',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.151110858450463034',
#                      'amountUSD': '351.2618118810157393057061702267294',
#                      'id': '0xe83d9b0a5f8edffeb2d3476bbdf07aac33830f476a0f4f6354bd8066d8a46092-1',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xdfee68a9adb981cd08699891a11cabe10f25ec44',
#                      'transaction': {'id': '0xe83d9b0a5f8edffeb2d3476bbdf07aac33830f476a0f4f6354bd8066d8a46092',
#                                      'timestamp': '1652267237'}},
#                     {'amount0In': '1396.102429176982774731',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.158899662252646075',
#                      'amountUSD': '361.723419875179185273808399497013',
#                      'id': '0xd2a4647667d0b46e7a24767a46ff4f680f4c22a348249d8f3184a4bcfad26bee-1',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x5aa3393e361c2eb342408559309b3e873cd876d6',
#                      'transaction': {'id': '0xd2a4647667d0b46e7a24767a46ff4f680f4c22a348249d8f3184a4bcfad26bee',
#                                      'timestamp': '1652251042'}},
#                     {'amount0In': '0',
#                      'amount0Out': '170.051033243037687707',
#                      'amount1In': '0.020904510728870607',
#                      'amount1Out': '0',
#                      'amountUSD': '49.65292487883848938980732442551671',
#                      'id': '0xbc0164545663fe942323ceb03a8d55da68e445a58e1cbe5a02ccdc321c2ba53c-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xe66b31678d6c16e9ebf358268a790b763c133750',
#                      'transaction': {'id': '0xbc0164545663fe942323ceb03a8d55da68e445a58e1cbe5a02ccdc321c2ba53c',
#                                      'timestamp': '1652237374'}},
#                     {'amount0In': '0',
#                      'amount0Out': '460.909085742904791453',
#                      'amount1In': '0.054559105687285731',
#                      'amount1Out': '0',
#                      'amountUSD': '131.1322861842310729044209641526621',
#                      'id': '0x1c2da24e97dc2a8a911ef930d49b3ae0683f21b0d4fed1fe66278e91695cb93e-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xe66b31678d6c16e9ebf358268a790b763c133750',
#                      'transaction': {'id': '0x1c2da24e97dc2a8a911ef930d49b3ae0683f21b0d4fed1fe66278e91695cb93e',
#                                      'timestamp': '1652229340'}},
#                     {'amount0In': '680.000000050593446088',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.081081910008688226',
#                      'amountUSD': '185.5079129720953091399018031447727',
#                      'id': '0x2170d9c5fd6fb4fd7574ca6f7b73515d25e563bd4340953bac05608766887448-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x68b3465833fb72a70ecdf485e0e4c7bd8665fc45',
#                      'transaction': {'id': '0x2170d9c5fd6fb4fd7574ca6f7b73515d25e563bd4340953bac05608766887448',
#                                      'timestamp': '1652216556'}},
#                     {'amount0In': '0',
#                      'amount0Out': '273.558208422859930094',
#                      'amount1In': '0.033610675583761753',
#                      'amount1Out': '0',
#                      'amountUSD': '81.76485754472574781726258501324084',
#                      'id': '0x0f9bfcc27c49c58a0fd1540a18a248df739201164fc2d0fa1ca253d11ffb63e7-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xee3c1e1dad1381277b94e018df2685ae1d7a00f4',
#                      'transaction': {'id': '0x0f9bfcc27c49c58a0fd1540a18a248df739201164fc2d0fa1ca253d11ffb63e7',
#                                      'timestamp': '1652186086'}},
#                     {'amount0In': '397.800859782027741247',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.048954383107361595',
#                      'amountUSD': '115.6562099679722727390287785680349',
#                      'id': '0x6af258d44d2d3342697df703a9675711db2bfb85f30e75ca424d3c7788d29ecc-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xd12bcdfb9a39be79da3bdf02557efdcd5ca59e77',
#                      'transaction': {'id': '0x6af258d44d2d3342697df703a9675711db2bfb85f30e75ca424d3c7788d29ecc',
#                                      'timestamp': '1652173580'}},
#                     {'amount0In': '0',
#                      'amount0Out': '305.268858851477054608',
#                      'amount1In': '0.038',
#                      'amount1Out': '0',
#                      'amountUSD': '91.43935922009675463374258422594292',
#                      'id': '0x1c3bc35acee6a156e2eafed94615ab03b94490b8ba34057d73b3c1d41528f20e-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x9419708ff545d2bcd119f994c55824f230ee8790',
#                      'transaction': {'id': '0x1c3bc35acee6a156e2eafed94615ab03b94490b8ba34057d73b3c1d41528f20e',
#                                      'timestamp': '1652173522'}},
#                     {'amount0In': '0',
#                      'amount0Out': '331.016365601651872213',
#                      'amount1In': '0.03965',
#                      'amount1Out': '0',
#                      'amountUSD': '91.09863707152447482773847912219382',
#                      'id': '0x9e95c18d088723cb0b2e5367e7b1e4205b046a3d60036427a645ffb67af2cf02-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0x9e95c18d088723cb0b2e5367e7b1e4205b046a3d60036427a645ffb67af2cf02',
#                                      'timestamp': '1652138372'}},
#                     {'amount0In': '0',
#                      'amount0Out': '257.093681241380785462',
#                      'amount1In': '0.0297375',
#                      'amount1Out': '0',
#                      'amountUSD': '71.65268176610977406618686773106456',
#                      'id': '0xaf0b106054a4be948ad8f3399b2eb2b4f28ea2e46b568aa5b6bba1f9522a149e-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0xaf0b106054a4be948ad8f3399b2eb2b4f28ea2e46b568aa5b6bba1f9522a149e',
#                                      'timestamp': '1652106531'}},
#                     {'amount0In': '612.806515249387856091',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.071973648470196094',
#                      'amountUSD': '173.2728188655689151545900591032812',
#                      'id': '0x6904fc8aca95776c2c4cb044ab30fb74f8c53d5eba798a62170aeb9e53279f33-2',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x1891201d52f3ca63a5a9e771bd81477a65e01d7a',
#                      'transaction': {'id': '0x6904fc8aca95776c2c4cb044ab30fb74f8c53d5eba798a62170aeb9e53279f33',
#                                      'timestamp': '1652089630'}},
#                     {'amount0In': '7182.010934763535749292',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '1.546757152143000989',
#                      'amountUSD': '2967.22580453005691710137237350413',
#                      'id': '0xe76ef82586a0fbfe220fb06406b8185074b59d0d51136192f410a7dd2c4c0657-1',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x000000000035b5e5ad9019092c665357240f594e',
#                      'transaction': {'id': '0xe76ef82586a0fbfe220fb06406b8185074b59d0d51136192f410a7dd2c4c0657',
#                                      'timestamp': '1652084031'}},
#                     {'amount0In': '0',
#                      'amount0Out': '7032.798528828514937517',
#                      'amount1In': '1.533645323585409314',
#                      'amount1Out': '0',
#                      'amountUSD': '5161.305300558532036114819484067072',
#                      'id': '0x30b9a1b5a5e1e38cb22c4d49a5f87d3be07ef87031a14980415cba66abc57f86-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x62e3c242b5e903071458ad90a160493d84911c77',
#                      'transaction': {'id': '0x30b9a1b5a5e1e38cb22c4d49a5f87d3be07ef87031a14980415cba66abc57f86',
#                                      'timestamp': '1652084031'}},
#                     {'amount0In': '16336.648215393301557225',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '757.05916842088402764',
#                      'amountUSD': '933439.2270655026655884534438882541',
#                      'id': '0xe6322f57131a5dfdbfd797d0dd9d66617e09faf959b78971da6a7769085c746a-1',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xe8c060f8052e07423f71d445277c61ac5138a2e5',
#                      'transaction': {'id': '0xe6322f57131a5dfdbfd797d0dd9d66617e09faf959b78971da6a7769085c746a',
#                                      'timestamp': '1652069552'}},
#                     {'amount0In': '0',
#                      'amount0Out': '16070.875671491588732973',
#                      'amount1In': '757.037993358098694144',
#                      'amount1Out': '0',
#                      'amountUSD': '1861841.492953290588120826899917219',
#                      'id': '0xaeb49969b040120ace392755316c2c68676b240589f1c355005d710ba853fc47-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x62e3c242b5e903071458ad90a160493d84911c77',
#                      'transaction': {'id': '0xaeb49969b040120ace392755316c2c68676b240589f1c355005d710ba853fc47',
#                                      'timestamp': '1652069552'}},
#                     {'amount0In': '0',
#                      'amount0Out': '118.221794960791859458',
#                      'amount1In': '0.015',
#                      'amount1Out': '0',
#                      'amountUSD': '37.85338634403999955335925868873631',
#                      'id': '0xb61a8082d724d6f20110128a1e052e4b388a51d7820ff1a69ecd850432b7f6f0-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0xd27c58742093bc66b7cc2525d6a4cb0bd51e4e9a',
#                      'transaction': {'id': '0xb61a8082d724d6f20110128a1e052e4b388a51d7820ff1a69ecd850432b7f6f0',
#                                      'timestamp': '1652060411'}},
#                     {'amount0In': '456.940652094707774775',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.058866705136819562',
#                      'amountUSD': '147.5064961694887395702870907595362',
#                      'id': '0xd04367f48a4be6678a20d3a47c6b487f99e62e55639358a9d0fc73407f7e38ff-2',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x5f62593c70069abb35dfe2b63db969e8906609d6',
#                      'transaction': {'id': '0xd04367f48a4be6678a20d3a47c6b487f99e62e55639358a9d0fc73407f7e38ff',
#                                      'timestamp': '1652034438'}},
#                     {'amount0In': '0',
#                      'amount0Out': '226.215763882132372434',
#                      'amount1In': '0.0297375',
#                      'amount1Out': '0',
#                      'amountUSD': '75.85572266567433400495074241900324',
#                      'id': '0x5e976f9b9123f990f3d61e08b450d5a03fa8acedba97c395def7aa80cbcbf273-0',
#                      'pair': {'token0': {'symbol': 'LSS'},
#                               'token1': {'symbol': 'WETH'}},
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0x5e976f9b9123f990f3d61e08b450d5a03fa8acedba97c395def7aa80cbcbf273',
#                                      'timestamp': '1651989321'}}]}}

# %% [markdown]
# # Get Popular Pools (We need order by volume)

# %% [markdown]
# ## Top 50 Most liquidity pairs (order by liquidity) (Delete)

# %%
most_liquid_pairs_query = """
{
 pairs(first: 50, orderBy: reserveUSD, orderDirection: desc) {
   id
 }
}
"""
most_liquid_pairs = run_query(most_liquid_pairs_query)

pprint(most_liquid_pairs)
# Out:
# {'data': {'pairs': [{'id': '0xe6c78983b07a07e0523b57e18aa23d3ae2519e05'},
#                     {'id': '0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc'},
#                     {'id': '0x21b8065d10f73ee2e260e5b47d3344d3ced7596e'},
#                     {'id': '0x9928e4046d7c6513326ccea028cd3e7a91c7590a'},
#                     {'id': '0xae461ca67b15dc8dc81ce7615e0320da1a9ab8d5'},
#                     {'id': '0x0d4a11d5eeaac28ec3f61d100daf4d40471f1852'},
#                     {'id': '0xe1573b9d29e2183b1af0e743dc2754979a40d237'},
#                     {'id': '0x7d7e813082ef6c143277c71786e5be626ec77b20'},
#                     {'id': '0x61b62c5d56ccd158a38367ef2f539668a06356ab'},
#                     {'id': '0xccb63225a7b19dcf66717e4d40c9a72b39331d61'},
#                     {'id': '0x0617d5ffb29c03ac35f1863b8a50ce1b52d446f6'},
#                     {'id': '0x9816f26f43c4c02df0daae1a0ba6a4dcd30b8ab7'},
#                     {'id': '0x9c4fe5ffd9a9fc5678cfbd93aa2d4fd684b67c4c'},
#                     {'id': '0x3c92befe32cdf5564ff2f3092edacb9f9e40d508'},
#                     {'id': '0x48918f57fa7210ea7b20f23da8420e68df3578fe'},
#                     {'id': '0xd3d2e2692501a5c9ca623199d38826e513033a17'},
#                     {'id': '0x93512394a82d278b9961e3891a59c6dc1c2e4f98'},
#                     {'id': '0xe2f95dae6c5763c357447fe1ffb3f2a884bdc0b5'},
#                     {'id': '0xbb2b8038a1640196fbe3e38816f3e67cba72d940'},
#                     {'id': '0x3041cbd36888becc7bbcbc0045e3b1f144466f5f'},
#                     {'id': '0xa478c2975ab1ea89e8196811f51a7b7ade33eb11'},
#                     {'id': '0xc86881ef494b049fe3e624ae6fdf542f58ab1931'},
#                     {'id': '0x11181bd3baf5ce2a478e98361985d42625de35d1'},
#                     {'id': '0x7b73644935b8e68019ac6356c40661e1bc315860'},
#                     {'id': '0x7a809081f991ecfe0ab2727c7e90d2ad7c2e411e'},
#                     {'id': '0xab400c46c830a2f87939dcfdcbfaaadf76f35721'},
#                     {'id': '0x0af81cd5d9c124b4859d65697a4cd10ee223746a'},
#                     {'id': '0x9bca245cf99812e67a79900cc77e4b73f45e1df6'},
#                     {'id': '0x470e8de2ebaef52014a47cb5e6af86884947f08c'},
#                     {'id': '0x9fae36a18ef8ac2b43186ade5e2b07403dc742b1'},
#                     {'id': '0xf89ce5ed65737da8440411544b0499c9fad323b2'},
#                     {'id': '0x63b61e73d3fa1fb96d51ce457cabe89fffa7a1f1'},
#                     {'id': '0x0ee0cb563a52ae1170ac34fbb94c50e89adde4bd'},
#                     {'id': '0x25647e01bd0967c1b9599fa3521939871d1d0888'},
#                     {'id': '0x149148acc3b06b8cc73af3a10e84189243a35925'},
#                     {'id': '0xd6f3768e62ef92a9798e5a8cedd2b78907cecef9'},
#                     {'id': '0x2b788a7b1a0ee0da8cb1d2769825198d9c95d19d'},
#                     {'id': '0x9ec96dcb54331626b79d8450a3daa9bcfa02e0b0'},
#                     {'id': '0x9cbfb60a09a9a33a10312da0f39977cbdb7fde23'},
#                     {'id': '0x2d0ba902badaa82592f0e1c04c71d66cea21d921'},
#                     {'id': '0xb20bd5d04be54f870d5c0d3ca85d82b34b836405'},
#                     {'id': '0x5f6fbe81171d0f52cc58d6a2ac6ee1a9e52d18d2'},
#                     {'id': '0x6591c4bcd6d7a1eb4e537da8b78676c1576ba244'},
#                     {'id': '0x6033368e4a402605294c91cf5c03d72bd96e7d8d'},
#                     {'id': '0x684b00a5773679f88598a19976fbeb25a68e9a5f'},
#                     {'id': '0x5281e311734869c64ca60ef047fd87759397efe6'},
#                     {'id': '0xf778c77ec3696879cb5ac814984655aefe66d716'},
#                     {'id': '0x0179d00549b44d3161b9c260815f8a5947a541b3'},
#                     {'id': '0x27fd0857f0ef224097001e87e61026e39e1b04d1'},
#                     {'id': '0x3854612b93b140726167cca5418b01e832515d42'}]}}

# %% [markdown]
# The result is consistent with: https://v2.info.uniswap.org/pairs
# <br>Note that it needs to cancel the click of `Hide untracked pairs`
# <br>Reasons refered from Uniswap: USD amounts may be inaccurate in low liquidity pairs or pairs without ETH or stable coins.
# <br>Example: the top liquid pair (UETH/ULCK: '0xe6c78983b07a07e0523b57e18aa23d3ae2519e05') is invisible if clicking the hide button.

# %% [markdown]
# ## Top 50 most volume pairs

# %%
# Take example of 2022/06/05 0:00:00 (GMT+0)  timestamp: 1654387200
most_volume_pairs_query = """
{
 pairDayDatas(first: 50, orderBy: dailyVolumeUSD, orderDirection: desc,
   where: {
     date: 1654387200
   }
 ) {
     pairAddress
     token0
     token1
     reserve0
     reserve1
     reserveUSD
     totalSupply
     dailyTxns
     dailyVolumeToken0
     dailyVolumeToken1
     dailyVolumeUSD
 }
}
"""
most_volume_pairs = run_query(most_volume_pairs_query)

pprint(most_volume_pairs)
# Out:
# {'data': {'pairDayDatas': [{'dailyTxns': '66',
#                             'dailyVolumeToken0': '75.590458431395684271',
#                             'dailyVolumeToken1': '20391.289551617179340048',
#                             'dailyVolumeUSD': '18044577.16616131095138411684391161',
#                             'pairAddress': '0x26b1c843b41ab3ac6146f859d31dcb2031f5992b',
#                             'reserve0': '1.767872165974808497',
#                             'reserve1': '0.103575127241738334',
#                             'reserveUSD': '185.007627282511291050410476253084',
#                             'totalSupply': '0.397489622506046319'},
#                            {'dailyTxns': '568',
#                             'dailyVolumeToken0': '1419137291173.507923209293317101',
#                             'dailyVolumeToken1': '13969.023979241586925419',
#                             'dailyVolumeUSD': '12330161.8603183632501027905931409',
#                             'pairAddress': '0x9112d1761124d4ec7aca02014d6e215970f87e33',
#                             'reserve0': '16350613868.3869050774532976',
#                             'reserve1': '0.519906171224847849',
#                             'reserveUSD': '939.5606044999527414057226528192348',
#                             'totalSupply': '76481.596984279553163924'},
#                            {'dailyTxns': '1130',
#                             'dailyVolumeToken0': '9352341.202544',
#                             'dailyVolumeToken1': '70352106872638.631096732439854899',
#                             'dailyVolumeUSD': '9356068.767914834418701521183459145',
#                             'pairAddress': '0x7a809081f991ecfe0ab2727c7e90d2ad7c2e411e',
#                             'reserve0': '7278284.442263',
#                             'reserve1': '53711361613298.579569450654648315',
#                             'reserveUSD': '14562523.79614463010296044124735658',
#                             'totalSupply': '17000.372001445604539439'},
#                            {'dailyTxns': '2352',
#                             'dailyVolumeToken0': '7944060.293021',
#                             'dailyVolumeToken1': '4416.753923820066502526',
#                             'dailyVolumeUSD': '7946290.543183526065581561379215337',
#                             'pairAddress': '0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc',
#                             'reserve0': '79053219.45668',
#                             'reserve1': '43762.070870754729340122',
#                             'reserveUSD': '158171118.2947124454132655087211276',
#                             'totalSupply': '0.949291097224270471'},
#                            {'dailyTxns': '988',
#                             'dailyVolumeToken0': '1985.069246836202839412',
#                             'dailyVolumeToken1': '3568632.914985',
#                             'dailyVolumeUSD': '3567514.616175831645067170006679848',
#                             'pairAddress': '0x0d4a11d5eeaac28ec3f61d100daf4d40471f1852',
#                             'reserve0': '17150.6216251843007197',
#                             'reserve1': '31025675.01265',
#                             'reserveUSD': '61986741.93124518014117041922362383',
#                             'totalSupply': '0.358735792422925442'},
#                            {'dailyTxns': '339',
#                             'dailyVolumeToken0': '13267781.010060489687022394',
#                             'dailyVolumeToken1': '1890.06115884505521772',
#                             'dailyVolumeUSD': '3406788.640697228554984176713442879',
#                             'pairAddress': '0x6033368e4a402605294c91cf5c03d72bd96e7d8d',
#                             'reserve0': '12923069.47957958366364951',
#                             'reserve1': '1700.778808333284489473',
#                             'reserveUSD': '6150046.731936887471116457848148126',
#                             'totalSupply': '122495.841175114799947429'},
#                            {'dailyTxns': '52',
#                             'dailyVolumeToken0': '2370.283509828503112744',
#                             'dailyVolumeToken1': '29395.18460405',
#                             'dailyVolumeUSD': '2117245.547362322563131098884959673',
#                             'pairAddress': '0x5fc5b2a2a84e577e8eb3ddd00d6b18cdfc976645',
#                             'reserve0': '1.405332611560299561',
#                             'reserve1': '4879.509395835',
#                             'reserveUSD': '2540.637390630996495380319988943423',
#                             'totalSupply': '0.000000001693876534'},
#                            {'dailyTxns': '5',
#                             'dailyVolumeToken0': '39890.453065187663700397',
#                             'dailyVolumeToken1': '2315.4491801142244733',
#                             'dailyVolumeUSD': '2068207.090312683960461532632688075',
#                             'pairAddress': '0xc9919a9eb691f571e41db417f911135b4ac46fe7',
#                             'reserve0': '19492.596085670694340666',
#                             'reserve1': '1.743545235299297085',
#                             'reserveUSD': '6230.195069012601572355339755270908',
#                             'totalSupply': '134.786530428602600527'},
#                            {'dailyTxns': '1084',
#                             'dailyVolumeToken0': '31687521.75123634',
#                             'dailyVolumeToken1': '921.849962520731810018',
#                             'dailyVolumeUSD': '1656077.459784708517237385640827616',
#                             'pairAddress': '0x55d5c232d921b9eaa6b37b5845e439acd04b4dba',
#                             'reserve0': '9561300.85832576',
#                             'reserve1': '262.860789083706771544',
#                             'reserveUSD': '950046.2579647230507226365979986013',
#                             'totalSupply': '0.141939588833336829'},
#                            {'dailyTxns': '354',
#                             'dailyVolumeToken0': '693.44156563152035369',
#                             'dailyVolumeToken1': '84402864787.057603459657130526',
#                             'dailyVolumeUSD': '1242412.424525914084718022581442596',
#                             'pairAddress': '0x5281e311734869c64ca60ef047fd87759397efe6',
#                             'reserve0': '1590.131078037393753415',
#                             'reserve1': '194274555743.182871721195811459',
#                             'reserveUSD': '5747440.852724872320382470833962709',
#                             'totalSupply': '13027895.889162734975983901'},
#                            {'dailyTxns': '283',
#                             'dailyVolumeToken0': '21761174.39386819',
#                             'dailyVolumeToken1': '1141723.997216',
#                             'dailyVolumeUSD': '1141946.302832015773314469740411698',
#                             'pairAddress': '0xf6dcdce0ac3001b2f67f750bc64ea5beb37b5824',
#                             'reserve0': '6580678.00712234',
#                             'reserve1': '328934.681051',
#                             'reserveUSD': '658294.8540617761718797970861978751',
#                             'totalSupply': '0.000007647112982819'},
#                            {'dailyTxns': '849',
#                             'dailyVolumeToken0': '205004098504744.69545259',
#                             'dailyVolumeToken1': '625.000632860529770145',
#                             'dailyVolumeUSD': '1127677.624600125186797023647220326',
#                             'pairAddress': '0x9cbfb60a09a9a33a10312da0f39977cbdb7fde23',
#                             'reserve0': '621396432191831.238906482',
#                             'reserve1': '1971.111819425798635669',
#                             'reserveUSD': '7124074.173003478151163110000239229',
#                             'totalSupply': '14313.458893646941440285'},
#                            {'dailyTxns': '466',
#                             'dailyVolumeToken0': '50451718.885052442779591628',
#                             'dailyVolumeToken1': '568.469556179638284252',
#                             'dailyVolumeUSD': '1020903.380253957921149317802689005',
#                             'pairAddress': '0x7ba9b94127d434182287de708643932ec036d365',
#                             'reserve0': '12265921.026925799452795658',
#                             'reserve1': '114.678912348143895411',
#                             'reserveUSD': '414488.9827418657326611333329020109',
#                             'totalSupply': '21179.822885938282064551'},
#                            {'dailyTxns': '165',
#                             'dailyVolumeToken0': '452539.384559022218196543',
#                             'dailyVolumeToken1': '1000185.20555',
#                             'dailyVolumeUSD': '1000414.578905017001373359548662319',
#                             'pairAddress': '0x8c1c499b1796d7f3c2521ac37186b52de024e58c',
#                             'reserve0': '939931.639182685426251764',
#                             'reserve1': '1995580.757769',
#                             'reserveUSD': '4117252.487900125806857966340931903',
#                             'totalSupply': '1.198797283990609674'},
#                            {'dailyTxns': '372',
#                             'dailyVolumeToken0': '92419897650656.793742528860750703',
#                             'dailyVolumeToken1': '972386.174524',
#                             'dailyVolumeUSD': '972807.8660929728883561858897073178',
#                             'pairAddress': '0xdd39323c337c33d0285c1d4228a1a46a8502c79f',
#                             'reserve0': '66440650727706.597227107208443003',
#                             'reserve1': '729831.256612',
#                             'reserveUSD': '1460602.248501550373469062332659775',
#                             'totalSupply': '6454.97224367901523102'},
#                            {'dailyTxns': '189',
#                             'dailyVolumeToken0': '84646754467.221376030947367188',
#                             'dailyVolumeToken1': '520.441181634235465487',
#                             'dailyVolumeUSD': '938455.3880912685442083272437158236',
#                             'pairAddress': '0x811beed0119b4afce20d2583eb608c6f7af1954f',
#                             'reserve0': '137381972568.773146419202652462',
#                             'reserve1': '822.136772437380008014',
#                             'reserveUSD': '2971496.62124627629670831423373769',
#                             'totalSupply': '1125625.850366704550157845'},
#                            {'dailyTxns': '177',
#                             'dailyVolumeToken0': '9561915390847.339276168274858309',
#                             'dailyVolumeToken1': '515.441684534327388364',
#                             'dailyVolumeUSD': '923244.5849077709315492435114446155',
#                             'pairAddress': '0x8ef79d6c328c25da633559c20c75f638a4863462',
#                             'reserve0': '21725602182353.934683799217710177',
#                             'reserve1': '1137.136209677640706871',
#                             'reserveUSD': '4111702.928814411972202289726909645',
#                             'totalSupply': '139647708.508189323870899468'},
#                            {'dailyTxns': '318',
#                             'dailyVolumeToken0': '794092.120520714100584656',
#                             'dailyVolumeToken1': '441.181810416300041517',
#                             'dailyVolumeUSD': '794589.9530639120679491447181043045',
#                             'pairAddress': '0xa478c2975ab1ea89e8196811f51a7b7ade33eb11',
#                             'reserve0': '8591150.320398136877379623',
#                             'reserve1': '4755.060737156789330057',
#                             'reserveUSD': '17192573.26610398253434779770749409',
#                             'totalSupply': '120489.530322838968077415'},
#                            {'dailyTxns': '10',
#                             'dailyVolumeToken0': '47353916932.972929711078731104',
#                             'dailyVolumeToken1': '800.698544354827209003',
#                             'dailyVolumeUSD': '717412.5609100488321279566232410223',
#                             'pairAddress': '0x5449bd1a97296125252db2d9cf23d5d6e30ca3c1',
#                             'reserve0': '19890659431.580916082411827834',
#                             'reserve1': '1.220377361665848388',
#                             'reserveUSD': '4442.016832213092521660059518703806',
#                             'totalSupply': '54507.190418790743185676'},
#                            {'dailyTxns': '295',
#                             'dailyVolumeToken0': '705256.279543',
#                             'dailyVolumeToken1': '707349.331073',
#                             'dailyVolumeUSD': '706022.1662539794276232565442365313',
#                             'pairAddress': '0x3041cbd36888becc7bbcbc0045e3b1f144466f5f',
#                             'reserve0': '9106086.793727',
#                             'reserve1': '9132369.990284',
#                             'reserveUSD': '18232737.66482572193503387894012748',
#                             'totalSupply': '0.000007420131494547'},
#                            {'dailyTxns': '172',
#                             'dailyVolumeToken0': '265201762695055.421318903211127996',
#                             'dailyVolumeToken1': '369.855778710977314265',
#                             'dailyVolumeUSD': '662910.1840669022149382039863127992',
#                             'pairAddress': '0x9af0f334f9f451ce9e650278e56fec212f35cec1',
#                             'reserve0': '536616583937593.558487380650563307',
#                             'reserve1': '653.86451536340931939',
#                             'reserveUSD': '2366934.978902323035295376884397494',
#                             'totalSupply': '566951006.881031847765641544'},
#                            {'dailyTxns': '36',
#                             'dailyVolumeToken0': '509919.986530725327347912',
#                             'dailyVolumeToken1': '287.275517169842785181',
#                             'dailyVolumeUSD': '521788.9388986266222824195211770962',
#                             'pairAddress': '0xccb63225a7b19dcf66717e4d40c9a72b39331d61',
#                             'reserve0': '13766263.614604763922039235',
#                             'reserve1': '7943.210870859215357369',
#                             'reserveUSD': '28785339.38354955009593616336191422',
#                             'totalSupply': '291284.195794547355478078'},
#                            {'dailyTxns': '139',
#                             'dailyVolumeToken0': '474309.102551927143326741',
#                             'dailyVolumeToken1': '14131364602.649493153802788569',
#                             'dailyVolumeUSD': '475123.3572190850248976189100219231',
#                             'pairAddress': '0xec54859519293b8784bc5bf28144166f313618af',
#                             'reserve0': '1924354.109783361057458964',
#                             'reserve1': '58295701886.65165421900029295',
#                             'reserveUSD': '3839822.27940769797571362708996319',
#                             'totalSupply': '325808749.640185294185952083'},
#                            {'dailyTxns': '84',
#                             'dailyVolumeToken0': '255.006873482091398925',
#                             'dailyVolumeToken1': '2236795.737443610251705446',
#                             'dailyVolumeUSD': '457092.6792283447659923741637482616',
#                             'pairAddress': '0x25647e01bd0967c1b9599fa3521939871d1d0888',
#                             'reserve0': '2284.890572088574137991',
#                             'reserve1': '20407126.311975629489047856',
#                             'reserveUSD': '8291338.796641625957808056278246011',
#                             'totalSupply': '121731.08924170948409475'},
#                            {'dailyTxns': '81',
#                             'dailyVolumeToken0': '2279121.040471189378786016',
#                             'dailyVolumeToken1': '223.705435118572743245',
#                             'dailyVolumeUSD': '401132.014982953442539759006945614',
#                             'pairAddress': '0xfe903a12359496b932e24c5e9b78f1b9060a6342',
#                             'reserve0': '5647121.410417897889275038',
#                             'reserve1': '513.685997006544624288',
#                             'reserveUSD': '1860850.392284447274426869340175987',
#                             'totalSupply': '39649.700799300767846856'},
#                            {'dailyTxns': '129',
#                             'dailyVolumeToken0': '197.558150497802706864',
#                             'dailyVolumeToken1': '1104909.804949734328581674',
#                             'dailyVolumeUSD': '355723.2199580434919554878277184594',
#                             'pairAddress': '0x80b4d4e9d88d9f78198c56c5a27f3bacb9a685c5',
#                             'reserve0': '198.708552432583439',
#                             'reserve1': '1137251.373527926393614571',
#                             'reserveUSD': '720076.0464424662924287152377555322',
#                             'totalSupply': '4183.981538330340248622'},
#                            {'dailyTxns': '54',
#                             'dailyVolumeToken0': '65274.41043465587675697',
#                             'dailyVolumeToken1': '183.497196130439292747',
#                             'dailyVolumeUSD': '330669.6431795926209296191489907534',
#                             'pairAddress': '0xd3d2e2692501a5c9ca623199d38826e513033a17',
#                             'reserve0': '2059475.388957455041170434',
#                             'reserve1': '5808.820902665764206961',
#                             'reserveUSD': '21051234.21344266850172887786952301',
#                             'totalSupply': '50333.469152680636372157'},
#                            {'dailyTxns': '35',
#                             'dailyVolumeToken0': '179.590396793646258473',
#                             'dailyVolumeToken1': '309542.351765391',
#                             'dailyVolumeUSD': '326027.5825562088718791411121399064',
#                             'pairAddress': '0xc5be99a02c6857f9eac67bbce58df5572498f40c',
#                             'reserve0': '1155.658011005733238112',
#                             'reserve1': '2009608.963082036',
#                             'reserveUSD': '4185594.101355138079295993726453647',
#                             'totalSupply': '0.590203775593088159'},
#                            {'dailyTxns': '86',
#                             'dailyVolumeToken0': '175333730486.137895991584185493',
#                             'dailyVolumeToken1': '172.333179235231648018',
#                             'dailyVolumeUSD': '309920.7920643432177160316935834347',
#                             'pairAddress': '0x97e1fcb93ae7267dbafad23f7b9afaa08264cfd8',
#                             'reserve0': '1320884908191.363025577282367675',
#                             'reserve1': '1283.352551768714664088',
#                             'reserveUSD': '4638549.031785302139046530126469253',
#                             'totalSupply': '30089863.56945984556809423'},
#                            {'dailyTxns': '92',
#                             'dailyVolumeToken0': '3176.699729313654723961',
#                             'dailyVolumeToken1': '163.946646514987831098',
#                             'dailyVolumeUSD': '295207.7698447054653156771004847922',
#                             'pairAddress': '0x4d5ef58aac27d99935e5b6b4a6778ff292059991',
#                             'reserve0': '10186.768546395581616137',
#                             'reserve1': '523.973942204222378448',
#                             'reserveUSD': '1893819.372541258790365693020749',
#                             'totalSupply': '1961.016490314040703401'},
#                            {'dailyTxns': '38',
#                             'dailyVolumeToken0': '76619.54822631853021057',
#                             'dailyVolumeToken1': '275068.789012',
#                             'dailyVolumeUSD': '275128.7817010708823908177053054361',
#                             'pairAddress': '0x6591c4bcd6d7a1eb4e537da8b78676c1576ba244',
#                             'reserve0': '896042.514845790218472498',
#                             'reserve1': '3159246.500619',
#                             'reserveUSD': '6310794.011512777604533924737375742',
#                             'totalSupply': '1.387052280056787128'},
#                            {'dailyTxns': '53',
#                             'dailyVolumeToken0': '2032287.659868379420015882',
#                             'dailyVolumeToken1': '144.383692210190203376',
#                             'dailyVolumeUSD': '262378.7414691136421676783671892933',
#                             'pairAddress': '0x4a7d4be868e0b811ea804faf0d3a325c3a29a9ad',
#                             'reserve0': '5640884.275107329944359084',
#                             'reserve1': '382.491227003902476866',
#                             'reserveUSD': '1382949.410618594943300222064139593',
#                             'totalSupply': '32637.643933661235050835'},
#                            {'dailyTxns': '62',
#                             'dailyVolumeToken0': '16717057.462484383845161707',
#                             'dailyVolumeToken1': '141.740383635366585659',
#                             'dailyVolumeUSD': '255884.5081831715751729480217166994',
#                             'pairAddress': '0x271544af1f703ac3deb3f12790de83b3b987aa2b',
#                             'reserve0': '42038340.798716851511800564',
#                             'reserve1': '362.978959426626748939',
#                             'reserveUSD': '1312511.089020321668621330165401321',
#                             'totalSupply': '117479.597850185334658016'},
#                            {'dailyTxns': '81',
#                             'dailyVolumeToken0': '140.586508671714227945',
#                             'dailyVolumeToken1': '135.584889522569013659',
#                             'dailyVolumeUSD': '244395.5344746080005968642410562708',
#                             'pairAddress': '0x4028daac072e492d34a3afdbef0ba7e35d8b55c4',
#                             'reserve0': '985.272383536476294022',
#                             'reserve1': '960.81590363530080552',
#                             'reserveUSD': '3472772.679174635800967311890497636',
#                             'totalSupply': '797.237011389308801073'},
#                            {'dailyTxns': '50',
#                             'dailyVolumeToken0': '770596.770739135111604134',
#                             'dailyVolumeToken1': '117.292184945805359515',
#                             'dailyVolumeUSD': '211160.2288236968330212216907907167',
#                             'pairAddress': '0xb05e19a28e4d13eeae507eaf6572e3a1c5d8f774',
#                             'reserve0': '2422196.153584783441388664',
#                             'reserve1': '436.9729765425902778',
#                             'reserveUSD': '1579373.080354244397046357129373731',
#                             'totalSupply': '32482.71776075702653633'},
#                            {'dailyTxns': '87',
#                             'dailyVolumeToken0': '209577.482992202191225354',
#                             'dailyVolumeToken1': '209957.190812',
#                             'dailyVolumeUSD': '209907.6074356897289749202551086153',
#                             'pairAddress': '0xae461ca67b15dc8dc81ce7615e0320da1a9ab8d5',
#                             'reserve0': '53460420.712851634524630025',
#                             'reserve1': '53532203.731937',
#                             'reserveUSD': '107058916.9739061487748686360449841',
#                             'totalSupply': '47.521747670730748577'},
#                            {'dailyTxns': '33',
#                             'dailyVolumeToken0': '111.298581479856248207',
#                             'dailyVolumeToken1': '114.950240905266233305',
#                             'dailyVolumeUSD': '206962.4742935042997756295892629887',
#                             'pairAddress': '0x9c4fe5ffd9a9fc5678cfbd93aa2d4fd684b67c4c',
#                             'reserve0': '5949.904126067210573583',
#                             'reserve1': '6106.234746650059278863',
#                             'reserveUSD': '22127990.35451998785660842686616232',
#                             'totalSupply': '4896.098444029230301699'},
#                            {'dailyTxns': '59',
#                             'dailyVolumeToken0': '2331481.500806029249536184',
#                             'dailyVolumeToken1': '109.247024137382690753',
#                             'dailyVolumeUSD': '195889.7028779762507562626441915362',
#                             'pairAddress': '0xb8a1a865e4405281311c5bc0f90c240498472d3e',
#                             'reserve0': '6010695.810669730844153646',
#                             'reserve1': '278.97623280714663192',
#                             'reserveUSD': '1012298.73448035192370141768706705',
#                             'totalSupply': '26810.259894858269386327'},
#                            {'dailyTxns': '46',
#                             'dailyVolumeToken0': '105.160871954260061968',
#                             'dailyVolumeToken1': '4812.836424832155435421',
#                             'dailyVolumeUSD': '188541.1277829450381931267738673621',
#                             'pairAddress': '0x70ec2fa6eccf4010eaf572d1c1a7bcbc72dec983',
#                             'reserve0': '423.216870970266691826',
#                             'reserve1': '19153.541049848769732509',
#                             'reserveUSD': '1533505.111369502821816661518875461',
#                             'totalSupply': '1480.452162741184050422'},
#                            {'dailyTxns': '23',
#                             'dailyVolumeToken0': '45425.990656548471140635',
#                             'dailyVolumeToken1': '182805.140212',
#                             'dailyVolumeUSD': '182839.8177374157031085069564548097',
#                             'pairAddress': '0x3fa5db0910afc2a1e6de45039ea217410fb8641d',
#                             'reserve0': '324353.613947102794474884',
#                             'reserve1': '1272249.866925',
#                             'reserveUSD': '2541372.574477516575657935596549619',
#                             'totalSupply': '0.028208416759788805'},
#                            {'dailyTxns': '51',
#                             'dailyVolumeToken0': '39593019392.965130448671374565',
#                             'dailyVolumeToken1': '99.612747021701430048',
#                             'dailyVolumeUSD': '180105.1666667467330620161780996688',
#                             'pairAddress': '0xa5e9c917b4b821e4e0a5bbefce078ab6540d6b5e',
#                             'reserve0': '510046919467.405569536019879768',
#                             'reserve1': '1291.093841262717008912',
#                             'reserveUSD': '4666508.245445877740434443746916002',
#                             'totalSupply': '12281269.04080623701388428'},
#                            {'dailyTxns': '45',
#                             'dailyVolumeToken0': '1082770.173670394274701724',
#                             'dailyVolumeToken1': '96.921731491229483868',
#                             'dailyVolumeUSD': '175295.3810698716444752551155679943',
#                             'pairAddress': '0x6ada49aeccf6e556bb7a35ef0119cc8ca795294a',
#                             'reserve0': '11204988.319447557520921235',
#                             'reserve1': '991.566156808712220401',
#                             'reserveUSD': '3589386.738844315786306397829727972',
#                             'totalSupply': '56662.652051908738153066'},
#                            {'dailyTxns': '437',
#                             'dailyVolumeToken0': '97.60687621322496461',
#                             'dailyVolumeToken1': '16566.521552488930155747',
#                             'dailyVolumeUSD': '175220.5483793780435738605593329132',
#                             'pairAddress': '0x453a43e2bf3080f7a23c9bb034ccdd869e306102',
#                             'reserve0': '302.982886155483129977',
#                             'reserve1': '53799.931550808911382281',
#                             'reserveUSD': '1095101.241889542410846527700628125',
#                             'totalSupply': '3549.575537270693627411'},
#                            {'dailyTxns': '33',
#                             'dailyVolumeToken0': '810146.159944736539325196',
#                             'dailyVolumeToken1': '172847.507224',
#                             'dailyVolumeUSD': '172912.2322407528369651810952570057',
#                             'pairAddress': '0x11181bd3baf5ce2a478e98361985d42625de35d1',
#                             'reserve0': '35049366.252223707538622867',
#                             'reserve1': '7457796.83135',
#                             'reserveUSD': '14929002.28126741251075667691783659',
#                             'totalSupply': '15.879723038799099906'},
#                            {'dailyTxns': '71',
#                             'dailyVolumeToken0': '1200983.066288076153094606',
#                             'dailyVolumeToken1': '94.662457587815452951',
#                             'dailyVolumeUSD': '169870.8323037426789500629277238685',
#                             'pairAddress': '0x1037fa1f40b69c9266c4aeb2abcedc7553614b4c',
#                             'reserve0': '2350863.342554866356863441',
#                             'reserve1': '174.442897585919112401',
#                             'reserveUSD': '631468.5410728325434044197947467048',
#                             'totalSupply': '6928.614924328693002263'},
#                            {'dailyTxns': '45',
#                             'dailyVolumeToken0': '133049.071918208033822172',
#                             'dailyVolumeToken1': '94.18150666637087389',
#                             'dailyVolumeUSD': '168856.2511661062512112983432971573',
#                             'pairAddress': '0xf66369997ae562bc9eec2ab9541581252f9ca383',
#                             'reserve0': '905377.131401824085082571',
#                             'reserve1': '602.304388703290434552',
#                             'reserveUSD': '2191524.841947554557436803318265626',
#                             'totalSupply': '17039.817924603670964262'},
#                            {'dailyTxns': '66',
#                             'dailyVolumeToken0': '1589632.785341448517043149',
#                             'dailyVolumeToken1': '92.830825718467465375',
#                             'dailyVolumeUSD': '168124.0163762535630664537872659459',
#                             'pairAddress': '0xcf4236db746dbc1855a4d095aaf58da9b030491e',
#                             'reserve0': '2268926.586300006986421068',
#                             'reserve1': '134.906787905287079111',
#                             'reserveUSD': '487600.2879182688873688597128700263',
#                             'totalSupply': '13797.070713936561934792'},
#                            {'dailyTxns': '88',
#                             'dailyVolumeToken0': '380978332182.012031118883591413',
#                             'dailyVolumeToken1': '92.497992294085849665',
#                             'dailyVolumeUSD': '166425.424300564791162929556883296',
#                             'pairAddress': '0x7b73644935b8e68019ac6356c40661e1bc315860',
#                             'reserve0': '16694673860421.965841184492236691',
#                             'reserve1': '4073.187323721388117374',
#                             'reserveUSD': '14722126.89388334418324871796576074',
#                             'totalSupply': '141957885.507612589027096652'},
#                            {'dailyTxns': '40',
#                             'dailyVolumeToken0': '5024182.695596332998829822',
#                             'dailyVolumeToken1': '160724.018251',
#                             'dailyVolumeUSD': '160789.5569784155895498163480883066',
#                             'pairAddress': '0x5083b16da538c5022744526122243cf3bddb3bf2',
#                             'reserve0': '39617613.623383835236199837',
#                             'reserve1': '1347623.135381',
#                             'reserveUSD': '2695991.987548403830042363986786818',
#                             'totalSupply': '6.70434875091940014'},
#                            {'dailyTxns': '44',
#                             'dailyVolumeToken0': '538425.982641995915073539',
#                             'dailyVolumeToken1': '87.385311323564152397',
#                             'dailyVolumeUSD': '157187.8946207021501732196641805131',
#                             'pairAddress': '0xdb44a4a457c87225b5ba45f27b7828a4cc03c112',
#                             'reserve0': '2362507.3193913073982316',
#                             'reserve1': '377.750492339415585069',
#                             'reserveUSD': '1370566.916556931344839941905982548',
#                             'totalSupply': '24931.082328533536770817'}]}}

# %%
# Create a dataframe to store the popular pairs by daily volume
df_most_volume_pairs = pd.DataFrame.from_dict(most_volume_pairs['data']['pairDayDatas'])
df_most_volume_pairs
# Out:
#                                    pairAddress  \
# 0   0x26b1c843b41ab3ac6146f859d31dcb2031f5992b
# 1   0x9112d1761124d4ec7aca02014d6e215970f87e33
# 2   0x7a809081f991ecfe0ab2727c7e90d2ad7c2e411e
# 3   0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc
# 4   0x0d4a11d5eeaac28ec3f61d100daf4d40471f1852
# 5   0x6033368e4a402605294c91cf5c03d72bd96e7d8d
# 6   0x5fc5b2a2a84e577e8eb3ddd00d6b18cdfc976645
# 7   0xc9919a9eb691f571e41db417f911135b4ac46fe7
# 8   0x55d5c232d921b9eaa6b37b5845e439acd04b4dba
# 9   0x5281e311734869c64ca60ef047fd87759397efe6
# 10  0xf6dcdce0ac3001b2f67f750bc64ea5beb37b5824
# 11  0x9cbfb60a09a9a33a10312da0f39977cbdb7fde23
# 12  0x7ba9b94127d434182287de708643932ec036d365
# 13  0x8c1c499b1796d7f3c2521ac37186b52de024e58c
# 14  0xdd39323c337c33d0285c1d4228a1a46a8502c79f
# 15  0x811beed0119b4afce20d2583eb608c6f7af1954f
# 16  0x8ef79d6c328c25da633559c20c75f638a4863462
# 17  0xa478c2975ab1ea89e8196811f51a7b7ade33eb11
# 18  0x5449bd1a97296125252db2d9cf23d5d6e30ca3c1
# 19  0x3041cbd36888becc7bbcbc0045e3b1f144466f5f
# 20  0x9af0f334f9f451ce9e650278e56fec212f35cec1
# 21  0xccb63225a7b19dcf66717e4d40c9a72b39331d61
# 22  0xec54859519293b8784bc5bf28144166f313618af
# 23  0x25647e01bd0967c1b9599fa3521939871d1d0888
# 24  0xfe903a12359496b932e24c5e9b78f1b9060a6342
# 25  0x80b4d4e9d88d9f78198c56c5a27f3bacb9a685c5
# 26  0xd3d2e2692501a5c9ca623199d38826e513033a17
# 27  0xc5be99a02c6857f9eac67bbce58df5572498f40c
# 28  0x97e1fcb93ae7267dbafad23f7b9afaa08264cfd8
# 29  0x4d5ef58aac27d99935e5b6b4a6778ff292059991
# 30  0x6591c4bcd6d7a1eb4e537da8b78676c1576ba244
# 31  0x4a7d4be868e0b811ea804faf0d3a325c3a29a9ad
# 32  0x271544af1f703ac3deb3f12790de83b3b987aa2b
# 33  0x4028daac072e492d34a3afdbef0ba7e35d8b55c4
# 34  0xb05e19a28e4d13eeae507eaf6572e3a1c5d8f774
# 35  0xae461ca67b15dc8dc81ce7615e0320da1a9ab8d5
# 36  0x9c4fe5ffd9a9fc5678cfbd93aa2d4fd684b67c4c
# 37  0xb8a1a865e4405281311c5bc0f90c240498472d3e
# 38  0x70ec2fa6eccf4010eaf572d1c1a7bcbc72dec983
# 39  0x3fa5db0910afc2a1e6de45039ea217410fb8641d
# 40  0xa5e9c917b4b821e4e0a5bbefce078ab6540d6b5e
# 41  0x6ada49aeccf6e556bb7a35ef0119cc8ca795294a
# 42  0x453a43e2bf3080f7a23c9bb034ccdd869e306102
# 43  0x11181bd3baf5ce2a478e98361985d42625de35d1
# 44  0x1037fa1f40b69c9266c4aeb2abcedc7553614b4c
# 45  0xf66369997ae562bc9eec2ab9541581252f9ca383
# 46  0xcf4236db746dbc1855a4d095aaf58da9b030491e
# 47  0x7b73644935b8e68019ac6356c40661e1bc315860
# 48  0x5083b16da538c5022744526122243cf3bddb3bf2
# 49  0xdb44a4a457c87225b5ba45f27b7828a4cc03c112
#
#                               reserve0                           reserve1  \
# 0                 1.767872165974808497               0.103575127241738334
# 1         16350613868.3869050774532976               0.519906171224847849
# 2                       7278284.442263  53711361613298.579569450654648315
# 3                       79053219.45668           43762.070870754729340122
# 4               17150.6216251843007197                     31025675.01265
# 5           12923069.47957958366364951            1700.778808333284489473
# 6                 1.405332611560299561                     4879.509395835
# 7             19492.596085670694340666               1.743545235299297085
# 8                     9561300.85832576             262.860789083706771544
# 9              1590.131078037393753415    194274555743.182871721195811459
# 10                    6580678.00712234                      328934.681051
# 11           621396432191831.238906482            1971.111819425798635669
# 12         12265921.026925799452795658             114.678912348143895411
# 13           939931.639182685426251764                     1995580.757769
# 14   66440650727706.597227107208443003                      729831.256612
# 15     137381972568.773146419202652462             822.136772437380008014
# 16   21725602182353.934683799217710177            1137.136209677640706871
# 17          8591150.320398136877379623            4755.060737156789330057
# 18      19890659431.580916082411827834               1.220377361665848388
# 19                      9106086.793727                     9132369.990284
# 20  536616583937593.558487380650563307              653.86451536340931939
# 21         13766263.614604763922039235            7943.210870859215357369
# 22          1924354.109783361057458964      58295701886.65165421900029295
# 23             2284.890572088574137991        20407126.311975629489047856
# 24          5647121.410417897889275038             513.685997006544624288
# 25                 198.708552432583439         1137251.373527926393614571
# 26          2059475.388957455041170434            5808.820902665764206961
# 27             1155.658011005733238112                  2009608.963082036
# 28    1320884908191.363025577282367675            1283.352551768714664088
# 29            10186.768546395581616137             523.973942204222378448
# 30           896042.514845790218472498                     3159246.500619
# 31          5640884.275107329944359084             382.491227003902476866
# 32         42038340.798716851511800564             362.978959426626748939
# 33              985.272383536476294022              960.81590363530080552
# 34          2422196.153584783441388664               436.9729765425902778
# 35         53460420.712851634524630025                    53532203.731937
# 36             5949.904126067210573583            6106.234746650059278863
# 37          6010695.810669730844153646              278.97623280714663192
# 38              423.216870970266691826           19153.541049848769732509
# 39           324353.613947102794474884                     1272249.866925
# 40     510046919467.405569536019879768            1291.093841262717008912
# 41         11204988.319447557520921235             991.566156808712220401
# 42              302.982886155483129977           53799.931550808911382281
# 43         35049366.252223707538622867                      7457796.83135
# 44          2350863.342554866356863441             174.442897585919112401
# 45           905377.131401824085082571             602.304388703290434552
# 46          2268926.586300006986421068             134.906787905287079111
# 47   16694673860421.965841184492236691            4073.187323721388117374
# 48         39617613.623383835236199837                     1347623.135381
# 49            2362507.3193913073982316             377.750492339415585069
#
#                              reserveUSD                   totalSupply  \
# 0    185.007627282511291050410476253084          0.397489622506046319
# 1   939.5606044999527414057226528192348      76481.596984279553163924
# 2   14562523.79614463010296044124735658      17000.372001445604539439
# 3   158171118.2947124454132655087211276          0.949291097224270471
# 4   61986741.93124518014117041922362383          0.358735792422925442
# 5   6150046.731936887471116457848148126     122495.841175114799947429
# 6   2540.637390630996495380319988943423          0.000000001693876534
# 7   6230.195069012601572355339755270908        134.786530428602600527
# 8   950046.2579647230507226365979986013          0.141939588833336829
# 9   5747440.852724872320382470833962709   13027895.889162734975983901
# 10  658294.8540617761718797970861978751          0.000007647112982819
# 11  7124074.173003478151163110000239229      14313.458893646941440285
# 12  414488.9827418657326611333329020109      21179.822885938282064551
# 13  4117252.487900125806857966340931903          1.198797283990609674
# 14  1460602.248501550373469062332659775        6454.97224367901523102
# 15   2971496.62124627629670831423373769    1125625.850366704550157845
# 16  4111702.928814411972202289726909645  139647708.508189323870899468
# 17  17192573.26610398253434779770749409     120489.530322838968077415
# 18  4442.016832213092521660059518703806      54507.190418790743185676
# 19  18232737.66482572193503387894012748          0.000007420131494547
# 20  2366934.978902323035295376884397494  566951006.881031847765641544
# 21  28785339.38354955009593616336191422     291284.195794547355478078
# 22   3839822.27940769797571362708996319  325808749.640185294185952083
# 23  8291338.796641625957808056278246011      121731.08924170948409475
# 24  1860850.392284447274426869340175987      39649.700799300767846856
# 25  720076.0464424662924287152377555322       4183.981538330340248622
# 26  21051234.21344266850172887786952301      50333.469152680636372157
# 27  4185594.101355138079295993726453647          0.590203775593088159
# 28  4638549.031785302139046530126469253    30089863.56945984556809423
# 29     1893819.372541258790365693020749       1961.016490314040703401
# 30  6310794.011512777604533924737375742          1.387052280056787128
# 31  1382949.410618594943300222064139593      32637.643933661235050835
# 32  1312511.089020321668621330165401321     117479.597850185334658016
# 33  3472772.679174635800967311890497636        797.237011389308801073
# 34  1579373.080354244397046357129373731       32482.71776075702653633
# 35  107058916.9739061487748686360449841         47.521747670730748577
# 36  22127990.35451998785660842686616232       4896.098444029230301699
# 37   1012298.73448035192370141768706705      26810.259894858269386327
# 38  1533505.111369502821816661518875461       1480.452162741184050422
# 39  2541372.574477516575657935596549619          0.028208416759788805
# 40  4666508.245445877740434443746916002    12281269.04080623701388428
# 41  3589386.738844315786306397829727972      56662.652051908738153066
# 42  1095101.241889542410846527700628125       3549.575537270693627411
# 43  14929002.28126741251075667691783659         15.879723038799099906
# 44  631468.5410728325434044197947467048       6928.614924328693002263
# 45  2191524.841947554557436803318265626      17039.817924603670964262
# 46  487600.2879182688873688597128700263      13797.070713936561934792
# 47  14722126.89388334418324871796576074  141957885.507612589027096652
# 48  2695991.987548403830042363986786818           6.70434875091940014
# 49  1370566.916556931344839941905982548      24931.082328533536770817
#
#    dailyTxns                   dailyVolumeToken0  \
# 0         66               75.590458431395684271
# 1        568    1419137291173.507923209293317101
# 2       1130                      9352341.202544
# 3       2352                      7944060.293021
# 4        988             1985.069246836202839412
# 5        339         13267781.010060489687022394
# 6         52             2370.283509828503112744
# 7          5            39890.453065187663700397
# 8       1084                   31687521.75123634
# 9        354               693.44156563152035369
# 10       283                   21761174.39386819
# 11       849            205004098504744.69545259
# 12       466         50451718.885052442779591628
# 13       165           452539.384559022218196543
# 14       372   92419897650656.793742528860750703
# 15       189      84646754467.221376030947367188
# 16       177    9561915390847.339276168274858309
# 17       318           794092.120520714100584656
# 18        10      47353916932.972929711078731104
# 19       295                       705256.279543
# 20       172  265201762695055.421318903211127996
# 21        36           509919.986530725327347912
# 22       139           474309.102551927143326741
# 23        84              255.006873482091398925
# 24        81          2279121.040471189378786016
# 25       129              197.558150497802706864
# 26        54             65274.41043465587675697
# 27        35              179.590396793646258473
# 28        86     175333730486.137895991584185493
# 29        92             3176.699729313654723961
# 30        38             76619.54822631853021057
# 31        53          2032287.659868379420015882
# 32        62         16717057.462484383845161707
# 33        81              140.586508671714227945
# 34        50           770596.770739135111604134
# 35        87           209577.482992202191225354
# 36        33              111.298581479856248207
# 37        59          2331481.500806029249536184
# 38        46              105.160871954260061968
# 39        23            45425.990656548471140635
# 40        51      39593019392.965130448671374565
# 41        45          1082770.173670394274701724
# 42       437                97.60687621322496461
# 43        33           810146.159944736539325196
# 44        71          1200983.066288076153094606
# 45        45           133049.071918208033822172
# 46        66          1589632.785341448517043149
# 47        88     380978332182.012031118883591413
# 48        40          5024182.695596332998829822
# 49        44           538425.982641995915073539
#
#                     dailyVolumeToken1                       dailyVolumeUSD
# 0            20391.289551617179340048  18044577.16616131095138411684391161
# 1            13969.023979241586925419   12330161.8603183632501027905931409
# 2   70352106872638.631096732439854899  9356068.767914834418701521183459145
# 3             4416.753923820066502526  7946290.543183526065581561379215337
# 4                      3568632.914985  3567514.616175831645067170006679848
# 5              1890.06115884505521772  3406788.640697228554984176713442879
# 6                      29395.18460405  2117245.547362322563131098884959673
# 7               2315.4491801142244733  2068207.090312683960461532632688075
# 8              921.849962520731810018  1656077.459784708517237385640827616
# 9      84402864787.057603459657130526  1242412.424525914084718022581442596
# 10                     1141723.997216  1141946.302832015773314469740411698
# 11             625.000632860529770145  1127677.624600125186797023647220326
# 12             568.469556179638284252  1020903.380253957921149317802689005
# 13                      1000185.20555  1000414.578905017001373359548662319
# 14                      972386.174524  972807.8660929728883561858897073178
# 15             520.441181634235465487  938455.3880912685442083272437158236
# 16             515.441684534327388364  923244.5849077709315492435114446155
# 17             441.181810416300041517  794589.9530639120679491447181043045
# 18             800.698544354827209003  717412.5609100488321279566232410223
# 19                      707349.331073  706022.1662539794276232565442365313
# 20             369.855778710977314265  662910.1840669022149382039863127992
# 21             287.275517169842785181  521788.9388986266222824195211770962
# 22     14131364602.649493153802788569  475123.3572190850248976189100219231
# 23         2236795.737443610251705446  457092.6792283447659923741637482616
# 24             223.705435118572743245   401132.014982953442539759006945614
# 25         1104909.804949734328581674  355723.2199580434919554878277184594
# 26             183.497196130439292747  330669.6431795926209296191489907534
# 27                   309542.351765391  326027.5825562088718791411121399064
# 28             172.333179235231648018  309920.7920643432177160316935834347
# 29             163.946646514987831098  295207.7698447054653156771004847922
# 30                      275068.789012  275128.7817010708823908177053054361
# 31             144.383692210190203376  262378.7414691136421676783671892933
# 32             141.740383635366585659  255884.5081831715751729480217166994
# 33             135.584889522569013659  244395.5344746080005968642410562708
# 34             117.292184945805359515  211160.2288236968330212216907907167
# 35                      209957.190812  209907.6074356897289749202551086153
# 36             114.950240905266233305  206962.4742935042997756295892629887
# 37             109.247024137382690753  195889.7028779762507562626441915362
# 38            4812.836424832155435421  188541.1277829450381931267738673621
# 39                      182805.140212  182839.8177374157031085069564548097
# 40              99.612747021701430048  180105.1666667467330620161780996688
# 41              96.921731491229483868  175295.3810698716444752551155679943
# 42           16566.521552488930155747  175220.5483793780435738605593329132
# 43                      172847.507224  172912.2322407528369651810952570057
# 44              94.662457587815452951  169870.8323037426789500629277238685
# 45               94.18150666637087389  168856.2511661062512112983432971573
# 46              92.830825718467465375  168124.0163762535630664537872659459
# 47              92.497992294085849665   166425.424300564791162929556883296
# 48                      160724.018251  160789.5569784155895498163480883066
# 49              87.385311323564152397  157187.8946207021501732196641805131

# %%
from tqdm import tqdm

# Create a data frame of orders
df_top50_pairs_info = pd.DataFrame({'pairAddress': df_most_volume_pairs['pairAddress'], 'dailyVolumeUSD': df_most_volume_pairs['dailyVolumeUSD'], 'token0_symbol': np.nan, 'token0_id': np.nan, 'dailyVolumeToken0': df_most_volume_pairs['dailyVolumeToken0'], 'reserve0': df_most_volume_pairs['reserve0'], 'token1_symbol': np.nan, 'token1_id': np.nan, 'dailyVolumeToken1': df_most_volume_pairs['dailyVolumeToken1'], 'reserve1': df_most_volume_pairs['reserve1'], 'reserveUSD': df_most_volume_pairs['reserveUSD'], 'totalSupply': df_most_volume_pairs['totalSupply'], 'dailyTxns': df_most_volume_pairs['dailyTxns'], }, index=df_most_volume_pairs.index)

for index, row in tqdm(df_most_volume_pairs.iterrows(), total=df_most_volume_pairs.shape[0]):
  this_id = row['pairAddress']  # Pair address of this row
  params_pair_id = {"id": this_id}
  pair_info_query = """
    query pair($id: String!) 
    {
      pair(id: $id){
      token0 {
        id
        symbol
      }
      token1 {
        id
        symbol
      }
      }
    }
  """
  pair_info = run_query_var(pair_info_query, params_pair_id)
  df_top50_pairs_info.loc[index] = [row['pairAddress'], row['dailyVolumeUSD'], pair_info['data']['pair']['token0']['symbol'], pair_info['data']['pair']['token0']['id'], row['dailyVolumeToken0'], row['reserve0'], pair_info['data']['pair']['token1']['symbol'], pair_info['data']['pair']['token0']['id'], row['dailyVolumeToken1'], row['reserve1'], row['reserveUSD'], row['totalSupply'], row['dailyTxns']]
# Out:
# 100%|██████████| 50/50 [00:10<00:00,  4.78it/s]

# %%
df_top50_pairs_info
# Out:
#                                    pairAddress  \
# 0   0x26b1c843b41ab3ac6146f859d31dcb2031f5992b
# 1   0x9112d1761124d4ec7aca02014d6e215970f87e33
# 2   0x7a809081f991ecfe0ab2727c7e90d2ad7c2e411e
# 3   0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc
# 4   0x0d4a11d5eeaac28ec3f61d100daf4d40471f1852
# 5   0x6033368e4a402605294c91cf5c03d72bd96e7d8d
# 6   0x5fc5b2a2a84e577e8eb3ddd00d6b18cdfc976645
# 7   0xc9919a9eb691f571e41db417f911135b4ac46fe7
# 8   0x55d5c232d921b9eaa6b37b5845e439acd04b4dba
# 9   0x5281e311734869c64ca60ef047fd87759397efe6
# 10  0xf6dcdce0ac3001b2f67f750bc64ea5beb37b5824
# 11  0x9cbfb60a09a9a33a10312da0f39977cbdb7fde23
# 12  0x7ba9b94127d434182287de708643932ec036d365
# 13  0x8c1c499b1796d7f3c2521ac37186b52de024e58c
# 14  0xdd39323c337c33d0285c1d4228a1a46a8502c79f
# 15  0x811beed0119b4afce20d2583eb608c6f7af1954f
# 16  0x8ef79d6c328c25da633559c20c75f638a4863462
# 17  0xa478c2975ab1ea89e8196811f51a7b7ade33eb11
# 18  0x5449bd1a97296125252db2d9cf23d5d6e30ca3c1
# 19  0x3041cbd36888becc7bbcbc0045e3b1f144466f5f
# 20  0x9af0f334f9f451ce9e650278e56fec212f35cec1
# 21  0xccb63225a7b19dcf66717e4d40c9a72b39331d61
# 22  0xec54859519293b8784bc5bf28144166f313618af
# 23  0x25647e01bd0967c1b9599fa3521939871d1d0888
# 24  0xfe903a12359496b932e24c5e9b78f1b9060a6342
# 25  0x80b4d4e9d88d9f78198c56c5a27f3bacb9a685c5
# 26  0xd3d2e2692501a5c9ca623199d38826e513033a17
# 27  0xc5be99a02c6857f9eac67bbce58df5572498f40c
# 28  0x97e1fcb93ae7267dbafad23f7b9afaa08264cfd8
# 29  0x4d5ef58aac27d99935e5b6b4a6778ff292059991
# 30  0x6591c4bcd6d7a1eb4e537da8b78676c1576ba244
# 31  0x4a7d4be868e0b811ea804faf0d3a325c3a29a9ad
# 32  0x271544af1f703ac3deb3f12790de83b3b987aa2b
# 33  0x4028daac072e492d34a3afdbef0ba7e35d8b55c4
# 34  0xb05e19a28e4d13eeae507eaf6572e3a1c5d8f774
# 35  0xae461ca67b15dc8dc81ce7615e0320da1a9ab8d5
# 36  0x9c4fe5ffd9a9fc5678cfbd93aa2d4fd684b67c4c
# 37  0xb8a1a865e4405281311c5bc0f90c240498472d3e
# 38  0x70ec2fa6eccf4010eaf572d1c1a7bcbc72dec983
# 39  0x3fa5db0910afc2a1e6de45039ea217410fb8641d
# 40  0xa5e9c917b4b821e4e0a5bbefce078ab6540d6b5e
# 41  0x6ada49aeccf6e556bb7a35ef0119cc8ca795294a
# 42  0x453a43e2bf3080f7a23c9bb034ccdd869e306102
# 43  0x11181bd3baf5ce2a478e98361985d42625de35d1
# 44  0x1037fa1f40b69c9266c4aeb2abcedc7553614b4c
# 45  0xf66369997ae562bc9eec2ab9541581252f9ca383
# 46  0xcf4236db746dbc1855a4d095aaf58da9b030491e
# 47  0x7b73644935b8e68019ac6356c40661e1bc315860
# 48  0x5083b16da538c5022744526122243cf3bddb3bf2
# 49  0xdb44a4a457c87225b5ba45f27b7828a4cc03c112
#
#                          dailyVolumeUSD token0_symbol  \
# 0   18044577.16616131095138411684391161         sILV2
# 1    12330161.8603183632501027905931409          SHIT
# 2   9356068.767914834418701521183459145          USDC
# 3   7946290.543183526065581561379215337          USDC
# 4   3567514.616175831645067170006679848          WETH
# 5   3406788.640697228554984176713442879          X2Y2
# 6   2117245.547362322563131098884959673          WETH
# 7   2068207.090312683960461532632688075           LSS
# 8   1656077.459784708517237385640827616           HEX
# 9   1242412.424525914084718022581442596          WETH
# 10  1141946.302832015773314469740411698           HEX
# 11  1127677.624600125186797023647220326       SAITAMA
# 12  1020903.380253957921149317802689005         eRSDL
# 13  1000414.578905017001373359548662319           RAD
# 14  972807.8660929728883561858897073178          HATI
# 15  938455.3880912685442083272437158236          SHIB
# 16  923244.5849077709315492435114446155           QOM
# 17  794589.9530639120679491447181043045           DAI
# 18  717412.5609100488321279566232410223           RND
# 19  706022.1662539794276232565442365313          USDC
# 20  662910.1840669022149382039863127992           KOO
# 21  521788.9388986266222824195211770962            MC
# 22  475123.3572190850248976189100219231           DAI
# 23  457092.6792283447659923741637482616          WETH
# 24   401132.014982953442539759006945614           PKF
# 25  355723.2199580434919554878277184594          WETH
# 26  330669.6431795926209296191489907534           UNI
# 27  326027.5825562088718791411121399064          WETH
# 28  309920.7920643432177160316935834347           UFO
# 29  295207.7698447054653156771004847922           DPI
# 30  275128.7817010708823908177053054361          BOND
# 31  262378.7414691136421676783671892933           REQ
# 32  255884.5081831715751729480217166994           FWT
# 33  244395.5344746080005968642410562708         stETH
# 34  211160.2288236968330212216907907167            OP
# 35  209907.6074356897289749202551086153           DAI
# 36  206962.4742935042997756295892629887          PAXG
# 37  195889.7028779762507562626441915362          NOIA
# 38  188541.1277829450381931267738673621          WETH
# 39  182839.8177374157031085069564548097          XCAD
# 40  180105.1666667467330620161780996688         STARL
# 41  175295.3810698716444752551155679943           WOO
# 42  175220.5483793780435738605593329132          WETH
# 43  172912.2322407528369651810952570057          ASTO
# 44  169870.8323037426789500629277238685          GLCH
# 45  168856.2511661062512112983432971573          PERP
# 46  168124.0163762535630664537872659459           BLZ
# 47   166425.424300564791162929556883296          ELON
# 48  160789.5569784155895498163480883066           ALI
# 49  157187.8946207021501732196641805131           RBN
#
#                                      token0_id  \
# 0   0x7e77dcb127f99ece88230a64db8d595f31f1b068
# 1   0x4e4a47cac6a28a62dcc20990ed2cda9bc659469f
# 2   0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3   0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4   0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 5   0x1e4ede388cbc9f4b5c79681b7f94d36a11abebc9
# 6   0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 7   0x3b9be07d622accaed78f479bc0edabfd6397e320
# 8   0x2b591e99afe9f32eaa6214f7b7629768c40eeb39
# 9   0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 10  0x2b591e99afe9f32eaa6214f7b7629768c40eeb39
# 11  0x8b3192f5eebd8579568a2ed41e6feb402f93f73f
# 12  0x5218e472cfcfe0b64a064f055b43b4cdc9efd3a6
# 13  0x31c8eacbffdd875c74b94b077895bd78cf1e64a3
# 14  0x251457b7c5d85251ca1ab384361c821330be2520
# 15  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 16  0xa71d0588eaf47f12b13cf8ec750430d21df04974
# 17  0x6b175474e89094c44da98b954eedeac495271d0f
# 18  0x1c7e83f8c581a967940dbfa7984744646ae46b29
# 19  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 20  0x5e9f7e92e742f73b990dca63c88325ed24666e84
# 21  0x949d48eca67b17269629c7194f4b727d4ef9e5d6
# 22  0x6b175474e89094c44da98b954eedeac495271d0f
# 23  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 24  0x8b39b70e39aa811b69365398e0aace9bee238aeb
# 25  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 26  0x1f9840a85d5af5bf1d1762f925bdaddc4201f984
# 27  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 28  0x249e38ea4102d0cf8264d3701f1a0e39c4f2dc3b
# 29  0x1494ca1f11d487c2bbe4543e90080aeba4ba3c2b
# 30  0x0391d2021f89dc339f60fff84546ea23e337750f
# 31  0x8f8221afbb33998d8584a2b05749ba73c37a938a
# 32  0x4a7397b0b86bb0f9482a3f4f16de942f04e88702
# 33  0xae7ab96520de3a18e5e111b5eaab095312d7fe84
# 34  0x2eecb20df51dc76d05afcf1270c73a2ff1035388
# 35  0x6b175474e89094c44da98b954eedeac495271d0f
# 36  0x45804880de22913dafe09f4980848ece6ecbaf78
# 37  0xa8c8cfb141a3bb59fea1e2ea6b79b5ecbcd7b6ca
# 38  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 39  0x7659ce147d0e714454073a5dd7003544234b6aa0
# 40  0x8e6cd950ad6ba651f6dd608dc70e5886b1aa6b24
# 41  0x4691937a7508860f876c9c0a2a617e7d9e945d4b
# 42  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 43  0x823556202e86763853b40e9cde725f412e294689
# 44  0x038a68ff68c393373ec894015816e33ad41bd564
# 45  0xbc396689893d065f41bc2c6ecbee5e0085233447
# 46  0x5732046a883704404f284ce41ffadd5b007fd668
# 47  0x761d38e5ddf6ccf6cf7c55759d5210750b5d60f3
# 48  0x6b0b3a982b4634ac68dd83a4dbf02311ce324181
# 49  0x6123b0049f904d730db3c36a31167d9d4121fa6b
#
#                      dailyVolumeToken0                            reserve0  \
# 0                75.590458431395684271                1.767872165974808497
# 1     1419137291173.507923209293317101        16350613868.3869050774532976
# 2                       9352341.202544                      7278284.442263
# 3                       7944060.293021                      79053219.45668
# 4              1985.069246836202839412              17150.6216251843007197
# 5          13267781.010060489687022394          12923069.47957958366364951
# 6              2370.283509828503112744                1.405332611560299561
# 7             39890.453065187663700397            19492.596085670694340666
# 8                    31687521.75123634                    9561300.85832576
# 9                693.44156563152035369             1590.131078037393753415
# 10                   21761174.39386819                    6580678.00712234
# 11            205004098504744.69545259           621396432191831.238906482
# 12         50451718.885052442779591628         12265921.026925799452795658
# 13           452539.384559022218196543           939931.639182685426251764
# 14   92419897650656.793742528860750703   66440650727706.597227107208443003
# 15      84646754467.221376030947367188     137381972568.773146419202652462
# 16    9561915390847.339276168274858309   21725602182353.934683799217710177
# 17           794092.120520714100584656          8591150.320398136877379623
# 18      47353916932.972929711078731104      19890659431.580916082411827834
# 19                       705256.279543                      9106086.793727
# 20  265201762695055.421318903211127996  536616583937593.558487380650563307
# 21           509919.986530725327347912         13766263.614604763922039235
# 22           474309.102551927143326741          1924354.109783361057458964
# 23              255.006873482091398925             2284.890572088574137991
# 24          2279121.040471189378786016          5647121.410417897889275038
# 25              197.558150497802706864                 198.708552432583439
# 26             65274.41043465587675697          2059475.388957455041170434
# 27              179.590396793646258473             1155.658011005733238112
# 28     175333730486.137895991584185493    1320884908191.363025577282367675
# 29             3176.699729313654723961            10186.768546395581616137
# 30             76619.54822631853021057           896042.514845790218472498
# 31          2032287.659868379420015882          5640884.275107329944359084
# 32         16717057.462484383845161707         42038340.798716851511800564
# 33              140.586508671714227945              985.272383536476294022
# 34           770596.770739135111604134          2422196.153584783441388664
# 35           209577.482992202191225354         53460420.712851634524630025
# 36              111.298581479856248207             5949.904126067210573583
# 37          2331481.500806029249536184          6010695.810669730844153646
# 38              105.160871954260061968              423.216870970266691826
# 39            45425.990656548471140635           324353.613947102794474884
# 40      39593019392.965130448671374565     510046919467.405569536019879768
# 41          1082770.173670394274701724         11204988.319447557520921235
# 42                97.60687621322496461              302.982886155483129977
# 43           810146.159944736539325196         35049366.252223707538622867
# 44          1200983.066288076153094606          2350863.342554866356863441
# 45           133049.071918208033822172           905377.131401824085082571
# 46          1589632.785341448517043149          2268926.586300006986421068
# 47     380978332182.012031118883591413   16694673860421.965841184492236691
# 48          5024182.695596332998829822         39617613.623383835236199837
# 49           538425.982641995915073539            2362507.3193913073982316
#
#    token1_symbol                                   token1_id  \
# 0           WETH  0x7e77dcb127f99ece88230a64db8d595f31f1b068
# 1           WETH  0x4e4a47cac6a28a62dcc20990ed2cda9bc659469f
# 2            CAW  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3           WETH  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4           USDT  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 5           WETH  0x1e4ede388cbc9f4b5c79681b7f94d36a11abebc9
# 6           GIZA  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 7           WETH  0x3b9be07d622accaed78f479bc0edabfd6397e320
# 8           WETH  0x2b591e99afe9f32eaa6214f7b7629768c40eeb39
# 9           CULT  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 10          USDC  0x2b591e99afe9f32eaa6214f7b7629768c40eeb39
# 11          WETH  0x8b3192f5eebd8579568a2ed41e6feb402f93f73f
# 12          WETH  0x5218e472cfcfe0b64a064f055b43b4cdc9efd3a6
# 13          USDC  0x31c8eacbffdd875c74b94b077895bd78cf1e64a3
# 14          USDC  0x251457b7c5d85251ca1ab384361c821330be2520
# 15          WETH  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 16          WETH  0xa71d0588eaf47f12b13cf8ec750430d21df04974
# 17          WETH  0x6b175474e89094c44da98b954eedeac495271d0f
# 18          WETH  0x1c7e83f8c581a967940dbfa7984744646ae46b29
# 19          USDT  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 20          WETH  0x5e9f7e92e742f73b990dca63c88325ed24666e84
# 21          WETH  0x949d48eca67b17269629c7194f4b727d4ef9e5d6
# 22             O  0x6b175474e89094c44da98b954eedeac495271d0f
# 23         SUPER  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 24          WETH  0x8b39b70e39aa811b69365398e0aace9bee238aeb
# 25           TRU  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 26          WETH  0x1f9840a85d5af5bf1d1762f925bdaddc4201f984
# 27          AMPL  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 28          WETH  0x249e38ea4102d0cf8264d3701f1a0e39c4f2dc3b
# 29          WETH  0x1494ca1f11d487c2bbe4543e90080aeba4ba3c2b
# 30          USDC  0x0391d2021f89dc339f60fff84546ea23e337750f
# 31          WETH  0x8f8221afbb33998d8584a2b05749ba73c37a938a
# 32          WETH  0x4a7397b0b86bb0f9482a3f4f16de942f04e88702
# 33          WETH  0xae7ab96520de3a18e5e111b5eaab095312d7fe84
# 34          WETH  0x2eecb20df51dc76d05afcf1270c73a2ff1035388
# 35          USDC  0x6b175474e89094c44da98b954eedeac495271d0f
# 36          WETH  0x45804880de22913dafe09f4980848ece6ecbaf78
# 37          WETH  0xa8c8cfb141a3bb59fea1e2ea6b79b5ecbcd7b6ca
# 38          ROOK  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 39          USDC  0x7659ce147d0e714454073a5dd7003544234b6aa0
# 40          WETH  0x8e6cd950ad6ba651f6dd608dc70e5886b1aa6b24
# 41          WETH  0x4691937a7508860f876c9c0a2a617e7d9e945d4b
# 42        STRNGR  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 43          USDC  0x823556202e86763853b40e9cde725f412e294689
# 44          WETH  0x038a68ff68c393373ec894015816e33ad41bd564
# 45          WETH  0xbc396689893d065f41bc2c6ecbee5e0085233447
# 46          WETH  0x5732046a883704404f284ce41ffadd5b007fd668
# 47          WETH  0x761d38e5ddf6ccf6cf7c55759d5210750b5d60f3
# 48          USDC  0x6b0b3a982b4634ac68dd83a4dbf02311ce324181
# 49          WETH  0x6123b0049f904d730db3c36a31167d9d4121fa6b
#
#                     dailyVolumeToken1                           reserve1  \
# 0            20391.289551617179340048               0.103575127241738334
# 1            13969.023979241586925419               0.519906171224847849
# 2   70352106872638.631096732439854899  53711361613298.579569450654648315
# 3             4416.753923820066502526           43762.070870754729340122
# 4                      3568632.914985                     31025675.01265
# 5              1890.06115884505521772            1700.778808333284489473
# 6                      29395.18460405                     4879.509395835
# 7               2315.4491801142244733               1.743545235299297085
# 8              921.849962520731810018             262.860789083706771544
# 9      84402864787.057603459657130526    194274555743.182871721195811459
# 10                     1141723.997216                      328934.681051
# 11             625.000632860529770145            1971.111819425798635669
# 12             568.469556179638284252             114.678912348143895411
# 13                      1000185.20555                     1995580.757769
# 14                      972386.174524                      729831.256612
# 15             520.441181634235465487             822.136772437380008014
# 16             515.441684534327388364            1137.136209677640706871
# 17             441.181810416300041517            4755.060737156789330057
# 18             800.698544354827209003               1.220377361665848388
# 19                      707349.331073                     9132369.990284
# 20             369.855778710977314265              653.86451536340931939
# 21             287.275517169842785181            7943.210870859215357369
# 22     14131364602.649493153802788569      58295701886.65165421900029295
# 23         2236795.737443610251705446        20407126.311975629489047856
# 24             223.705435118572743245             513.685997006544624288
# 25         1104909.804949734328581674         1137251.373527926393614571
# 26             183.497196130439292747            5808.820902665764206961
# 27                   309542.351765391                  2009608.963082036
# 28             172.333179235231648018            1283.352551768714664088
# 29             163.946646514987831098             523.973942204222378448
# 30                      275068.789012                     3159246.500619
# 31             144.383692210190203376             382.491227003902476866
# 32             141.740383635366585659             362.978959426626748939
# 33             135.584889522569013659              960.81590363530080552
# 34             117.292184945805359515               436.9729765425902778
# 35                      209957.190812                    53532203.731937
# 36             114.950240905266233305            6106.234746650059278863
# 37             109.247024137382690753              278.97623280714663192
# 38            4812.836424832155435421           19153.541049848769732509
# 39                      182805.140212                     1272249.866925
# 40              99.612747021701430048            1291.093841262717008912
# 41              96.921731491229483868             991.566156808712220401
# 42           16566.521552488930155747           53799.931550808911382281
# 43                      172847.507224                      7457796.83135
# 44              94.662457587815452951             174.442897585919112401
# 45               94.18150666637087389             602.304388703290434552
# 46              92.830825718467465375             134.906787905287079111
# 47              92.497992294085849665            4073.187323721388117374
# 48                      160724.018251                     1347623.135381
# 49              87.385311323564152397             377.750492339415585069
#
#                              reserveUSD                   totalSupply  \
# 0    185.007627282511291050410476253084          0.397489622506046319
# 1   939.5606044999527414057226528192348      76481.596984279553163924
# 2   14562523.79614463010296044124735658      17000.372001445604539439
# 3   158171118.2947124454132655087211276          0.949291097224270471
# 4   61986741.93124518014117041922362383          0.358735792422925442
# 5   6150046.731936887471116457848148126     122495.841175114799947429
# 6   2540.637390630996495380319988943423          0.000000001693876534
# 7   6230.195069012601572355339755270908        134.786530428602600527
# 8   950046.2579647230507226365979986013          0.141939588833336829
# 9   5747440.852724872320382470833962709   13027895.889162734975983901
# 10  658294.8540617761718797970861978751          0.000007647112982819
# 11  7124074.173003478151163110000239229      14313.458893646941440285
# 12  414488.9827418657326611333329020109      21179.822885938282064551
# 13  4117252.487900125806857966340931903          1.198797283990609674
# 14  1460602.248501550373469062332659775        6454.97224367901523102
# 15   2971496.62124627629670831423373769    1125625.850366704550157845
# 16  4111702.928814411972202289726909645  139647708.508189323870899468
# 17  17192573.26610398253434779770749409     120489.530322838968077415
# 18  4442.016832213092521660059518703806      54507.190418790743185676
# 19  18232737.66482572193503387894012748          0.000007420131494547
# 20  2366934.978902323035295376884397494  566951006.881031847765641544
# 21  28785339.38354955009593616336191422     291284.195794547355478078
# 22   3839822.27940769797571362708996319  325808749.640185294185952083
# 23  8291338.796641625957808056278246011      121731.08924170948409475
# 24  1860850.392284447274426869340175987      39649.700799300767846856
# 25  720076.0464424662924287152377555322       4183.981538330340248622
# 26  21051234.21344266850172887786952301      50333.469152680636372157
# 27  4185594.101355138079295993726453647          0.590203775593088159
# 28  4638549.031785302139046530126469253    30089863.56945984556809423
# 29     1893819.372541258790365693020749       1961.016490314040703401
# 30  6310794.011512777604533924737375742          1.387052280056787128
# 31  1382949.410618594943300222064139593      32637.643933661235050835
# 32  1312511.089020321668621330165401321     117479.597850185334658016
# 33  3472772.679174635800967311890497636        797.237011389308801073
# 34  1579373.080354244397046357129373731       32482.71776075702653633
# 35  107058916.9739061487748686360449841         47.521747670730748577
# 36  22127990.35451998785660842686616232       4896.098444029230301699
# 37   1012298.73448035192370141768706705      26810.259894858269386327
# 38  1533505.111369502821816661518875461       1480.452162741184050422
# 39  2541372.574477516575657935596549619          0.028208416759788805
# 40  4666508.245445877740434443746916002    12281269.04080623701388428
# 41  3589386.738844315786306397829727972      56662.652051908738153066
# 42  1095101.241889542410846527700628125       3549.575537270693627411
# 43  14929002.28126741251075667691783659         15.879723038799099906
# 44  631468.5410728325434044197947467048       6928.614924328693002263
# 45  2191524.841947554557436803318265626      17039.817924603670964262
# 46  487600.2879182688873688597128700263      13797.070713936561934792
# 47  14722126.89388334418324871796576074  141957885.507612589027096652
# 48  2695991.987548403830042363986786818           6.70434875091940014
# 49  1370566.916556931344839941905982548      24931.082328533536770817
#
#    dailyTxns
# 0         66
# 1        568
# 2       1130
# 3       2352
# 4        988
# 5        339
# 6         52
# 7          5
# 8       1084
# 9        354
# 10       283
# 11       849
# 12       466
# 13       165
# 14       372
# 15       189
# 16       177
# 17       318
# 18        10
# 19       295
# 20       172
# 21        36
# 22       139
# 23        84
# 24        81
# 25       129
# 26        54
# 27        35
# 28        86
# 29        92
# 30        38
# 31        53
# 32        62
# 33        81
# 34        50
# 35        87
# 36        33
# 37        59
# 38        46
# 39        23
# 40        51
# 41        45
# 42       437
# 43        33
# 44        71
# 45        45
# 46        66
# 47        88
# 48        40
# 49        44

# %%
# Write dataframe to csv
df_top50_pairs_info.to_csv("Top_50_Volume_Pairs_20220605.csv")

# %% [markdown]
# # Compute Directional Volume

# %%
# Firstly, fetch all transaction in each day
directional_volume_pair = [
 "0xc9919a9eb691f571e41db417f911135b4ac46fe7"
]
params_directional_volume_pair = {"directional_volume_pair": directional_volume_pair}

swaps_transaction_query = """
query($directional_volume_pair: [String!]) {
 swaps(first: 5, where: { pair_in: $directional_volume_pair, timestamp_gt: 1654387200}, orderBy: timestamp, orderDirection: asc) {
   transaction {
     id
     timestamp
   }
   amount0In
   amount1In
   amount0Out
   amount1Out
   amountUSD
 }
}
"""
swaps_transaction = run_query_var(swaps_transaction_query, params_directional_volume_pair)

pprint(swaps_transaction)
# Out:
# {'data': {'swaps': [{'amount0In': '874.358028061008428415',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.080380204908462933',
#                      'amountUSD': '140.9912911183920638860407598128405',
#                      'transaction': {'id': '0x6a8031402df1401112a7b5a17654673c708d111912946ac1beb169a13d506f59',
#                                      'timestamp': '1654417560'}},
#                     {'amount0In': '0',
#                      'amount0Out': '384.915147460101858337',
#                      'amount1In': '0.03469375',
#                      'amount1Out': '0',
#                      'amountUSD': '62.32797447381097606245121727947374',
#                      'transaction': {'id': '0xa3a509d48b4c9c6432ffd0c46cac6e6d1fad5395a4cf1dcaa0fb6dd98d1a7b82',
#                                      'timestamp': '1654426696'}},
#                     {'amount0In': '0',
#                      'amount0Out': '19167.809153296665628187',
#                      'amount1In': '1157.658926297668445986',
#                      'amount1Out': '0',
#                      'amountUSD': '2068207.090312683960461532632688075',
#                      'transaction': {'id': '0x7702696cb62039a295ad77b6e5a9684c64c9f2c5cc3cf447c713313f9bf54181',
#                                      'timestamp': '1654432756'}},
#                     {'amount0In': '19463.370736369887785458',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '1157.675179861647564381',
#                      'amountUSD': '1035732.883693670619952829921900157',
#                      'transaction': {'id': '0x9da5620c7803123849f8f65029a6e73dfd5e7922bf8815bbbc495f7313865880',
#                                      'timestamp': '1654432756'}},
#                     {'amount0In': '1298.7012988',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.108601907364179194',
#                      'amountUSD': '197.2975293986977797244059632304813',
#                      'transaction': {'id': '0xf39d57e6cce5ff8df55cb803c2de426cdb90d50832b8df936055a660309ce985',
#                                      'timestamp': '1654496274'}}]}}

# %% [markdown]
# # Pair Daily Aggregated

# %%
# Example: Pair: DAI/WETH: 0xa478c2975ab1ea89e8196811f51a7b7ade33eb11
# First 10 day from given timestamp: 1653001200  (2022/5/20 GMT 0:00:00)
pair_daily_aggregated_query = """
{
 pairDayDatas(first: 1, orderBy: date, orderDirection: asc,
   where: {
     pairAddress: "0xc9919a9eb691f571e41db417f911135b4ac46fe7",
     date: 1654387200
   }
 ) {
     date
     dailyVolumeToken0
     dailyVolumeToken1
     dailyVolumeUSD
     reserveUSD
 }
}
"""
pair_daily_aggregated = run_query(pair_daily_aggregated_query)

pprint(pair_daily_aggregated)
# Out:
# {'data': {'pairDayDatas': [{'dailyVolumeToken0': '39890.453065187663700397',
#                             'dailyVolumeToken1': '2315.4491801142244733',
#                             'dailyVolumeUSD': '2068207.090312683960461532632688075',
#                             'date': 1654387200,
#                             'reserveUSD': '6230.195069012601572355339755270908'}]}}

# %% [markdown]
# The result is consist with: https://v2.info.uniswap.org/pair/0xa478c2975ab1ea89e8196811f51a7b7ade33eb11
# <br>For example, the volume of DAI/ETH at 2022/05/29 (timestamp: 1653782400) is USD $509629

# %% [markdown]
# Next to do: confirm with the calculation from fetching transactions.

# %% [markdown]
# # Token Overview

# %% [markdown]
# Token data can be fetched using the token contract address as an ID. Token data is aggregated across all pairs the token is included in. Any token that is included in some pair in Uniswap can be queried.
# <br>reference: https://docs.uniswap.org/protocol/V2/reference/API/queries

# %%
# Example: The allPairs field gets the first 200 pairs DAI is included in sorted by liquidity in derived USD
token_overview_query = """
{
 token(id: "0x6b175474e89094c44da98b954eedeac495271d0f"){
   name
   symbol
   decimals
   derivedETH
   tradeVolumeUSD
   totalLiquidity
 }
}
"""
token_overview = run_query(token_overview_query)

pprint(token_overview)
# Out:
# {'data': {'token': {'decimals': '18',
#                     'derivedETH': '0.0005489257369435742850409519739633295',
#                     'name': 'Dai Stablecoin',
#                     'symbol': 'DAI',
#                     'totalLiquidity': '71259638.947566970658950017',
#                     'tradeVolumeUSD': '19170068979.52979291004214829078219'}}}

# %% [markdown]
# The allPairs field gets the first 200 pairs DAI is included in sorted by liquidity in derived USD.
# <br>The result of `total liquidity` is consistent with https://v2.info.uniswap.org/token/0x6b175474e89094c44da98b954eedeac495271d0f
# <br><br>TODO: `trade volumn` is not `volume (24hrs). We need to calculate the the daily volume.

# %% [markdown]
# # All Token in Uniswap V2

# %%
# Start from fetching the initial Batch 0: Query 1000 tokens on UNISWAP V2 order by id (asc)
# tradeVolumeUSD: amount of token in USD traded all time across pairs (only for tokens with liquidity above minimum threshold)
# untrackedVolumeUSD: amount of token in USD traded all time across pairs (no minimum liquidity threshold)
get_all_tokens_batch0_query = """
{
   tokens(first: 1000, orderBy: id, orderDirection: asc) {
     id
     name
     symbol
     tradeVolume
     tradeVolumeUSD
     untrackedVolumeUSD
     txCount
     totalLiquidity
     derivedETH
   }
}
"""
get_all_tokens_batch0 = run_query(get_all_tokens_batch0_query)

# %%
# Create a dataframe to store the tokens info, initializa with the first 1000 tokens
df_all_tokens = pd.DataFrame.from_dict(get_all_tokens_batch0['data']['tokens'])

# %%
# Do iteration to fetch all the tokens, skip the first 1000 in batch 0
# Start from the last id which is got by batch 0

tokens_iter_count = 0
tokens_iter = get_all_tokens_batch0['data']['tokens']  # Token info list in each batch
total_tokens_amount = len(tokens_iter)  # Initial the total token amount by 1000 (in batch 0)

# Do loop until 
while len(tokens_iter) == 1000:
  # The last id in the previous query batch
  last_id_gt = str(tokens_iter[-1]['id'])
  params_id_gt = {"id_in": last_id_gt}

  # Query 1000 new tokens from the last id
  query_iter = """
  query tokens($id_in: String!) {
    tokens(first: 1000, orderBy: id, orderDirection: asc
    where: {id_gt: $id_in }) 
    { 
      id
      name
      symbol
      tradeVolume
      tradeVolumeUSD
      untrackedVolumeUSD
      txCount
      totalLiquidity
      derivedETH
    }
  }
  """
  tokens_result_iter = run_query_var(query_iter, params_id_gt)

  # List of token info for this batch
  tokens_iter = tokens_result_iter['data']['tokens']

  # Add list of this batch to the dataframe
  df_all_tokens = df_all_tokens.append(tokens_iter, ignore_index=True)

  # Summary for this batch, and update iterator
  tokens_iter_count = tokens_iter_count + 1
  total_tokens_amount = total_tokens_amount+len(tokens_iter)
  print('Batch: ', tokens_iter_count, '  Length of pair: ', len(tokens_iter), '  Total fected pairs: ', total_tokens_amount)
  print('             Start from id: ', last_id_gt)

print('---------------------------')
print('Amount of fetced pairs: ', total_tokens_amount)
# Out:
# Batch:  1   Length of pair:  1000   Total fected pairs:  2000
#              Start from id:  0x03703a5e60918059baf5481c5d55a553890207a2
# Batch:  2   Length of pair:  1000   Total fected pairs:  3000
#              Start from id:  0x06f3ef6005c1e245a697fd4c9458aae95aaf8f29
# Batch:  3   Length of pair:  1000   Total fected pairs:  4000
#              Start from id:  0x0a92ca117788a18f6b38cf0261122a9ea95b7e4b
# Batch:  4   Length of pair:  1000   Total fected pairs:  5000
#              Start from id:  0x0e596b8a86082e8b0b1ae0aa8447df38c7851941
# Batch:  5   Length of pair:  1000   Total fected pairs:  6000
#              Start from id:  0x1208168aa6f7bf67f79ba922678f3940498c6149
# Batch:  6   Length of pair:  1000   Total fected pairs:  7000
#              Start from id:  0x158009a14f413065a5734b6c3d8261cfa45a0742
# Batch:  7   Length of pair:  1000   Total fected pairs:  8000
#              Start from id:  0x19093953fd8e4ea72d1a7dd5b7b72804e69923dc
# Batch:  8   Length of pair:  1000   Total fected pairs:  9000
#              Start from id:  0x1c89e8507bf2f1c8295560dbf9637941ec866d84
# Batch:  9   Length of pair:  1000   Total fected pairs:  10000
#              Start from id:  0x201ade2546737563fb54aa7bff7948f0101ccf18
# Batch:  10   Length of pair:  1000   Total fected pairs:  11000
#              Start from id:  0x239b0fa917d85c21cf6435464c2c6aa3d45f6720
# Batch:  11   Length of pair:  1000   Total fected pairs:  12000
#              Start from id:  0x2735c5de2b954c433e86baf0c5364a91633991de
# Batch:  12   Length of pair:  1000   Total fected pairs:  13000
#              Start from id:  0x2ae2f9eb6c2cb4bbc325158f69e97250cdd3d868
# Batch:  13   Length of pair:  1000   Total fected pairs:  14000
#              Start from id:  0x2e330f54813a94264b4a87cc4741e47eb403f5e7
# Batch:  14   Length of pair:  1000   Total fected pairs:  15000
#              Start from id:  0x31bb711de2e457066c6281f231fb473fc5c2afd3
# Batch:  15   Length of pair:  1000   Total fected pairs:  16000
#              Start from id:  0x3536e577262b56c6c2b4436d5df0c99c0cc8ce2d
# Batch:  16   Length of pair:  1000   Total fected pairs:  17000
#              Start from id:  0x38894302a6eabea6f2b29b508031d2ed75f0be22
# Batch:  17   Length of pair:  1000   Total fected pairs:  18000
#              Start from id:  0x3c144fc1b34fc1be809fbb2b194f460014e60113
# Batch:  18   Length of pair:  1000   Total fected pairs:  19000
#              Start from id:  0x3fb1c4767ee4a91fb349a6238b1005bdab5b84b3
# Batch:  19   Length of pair:  1000   Total fected pairs:  20000
#              Start from id:  0x436ee7730d974487c832ed2ab50cc07003c26c5d
# Batch:  20   Length of pair:  1000   Total fected pairs:  21000
#              Start from id:  0x47084af59b7445d86ff98a28a8aa5377ea7ab254
# Batch:  21   Length of pair:  1000   Total fected pairs:  22000
#              Start from id:  0x4aa6174f9dd6cc597ffe4d6f3a0b05eb5cdee0a5
# Batch:  22   Length of pair:  1000   Total fected pairs:  23000
#              Start from id:  0x4e3bbfa5764f9a5ff30fea7bac67ae378bac2727
# Batch:  23   Length of pair:  1000   Total fected pairs:  24000
#              Start from id:  0x51fde3ef061d17f5893036497c1d5cb651a9f021
# Batch:  24   Length of pair:  1000   Total fected pairs:  25000
#              Start from id:  0x558f4bf276821f18e02ac77f5e70a5ca4b6bf07b
# Batch:  25   Length of pair:  1000   Total fected pairs:  26000
#              Start from id:  0x594b55aba1467ce2b11e811af99d885007bf42f0
# Batch:  26   Length of pair:  1000   Total fected pairs:  27000
#              Start from id:  0x5cf9242493be1411b93d064ca2e468961bbb5924
# Batch:  27   Length of pair:  1000   Total fected pairs:  28000
#              Start from id:  0x607a09419593c3a60a9d27b1a831f45c1ba0ee31
# Batch:  28   Length of pair:  1000   Total fected pairs:  29000
#              Start from id:  0x642274672a05347e979e4aa0778e81ff9dc0cb0f
# Batch:  29   Length of pair:  1000   Total fected pairs:  30000
#              Start from id:  0x67b66c99d3eb37fa76aa3ed1ff33e8e39f0b9c7a
# Batch:  30   Length of pair:  1000   Total fected pairs:  31000
#              Start from id:  0x6b440f4eed3136959c09925f8b9b8bd4ae6f412b
# Batch:  31   Length of pair:  1000   Total fected pairs:  32000
#              Start from id:  0x6eccfb5adda8ca02cfdcf3ab9961e7fea84882d1
# Batch:  32   Length of pair:  1000   Total fected pairs:  33000
#              Start from id:  0x7277a44d1325d81ac58893002a1b40a41bea43fe
# Batch:  33   Length of pair:  1000   Total fected pairs:  34000
#              Start from id:  0x762f649c3c942a2a33c5ef0c1dc5c931b7f7dc43
# Batch:  34   Length of pair:  1000   Total fected pairs:  35000
#              Start from id:  0x79cdfa04e3c4eb58c4f49dae78b322e5b0d38788
# Batch:  35   Length of pair:  1000   Total fected pairs:  36000
#              Start from id:  0x7d4925187d7889e47fd9805eab0ca715fea1483e
# Batch:  36   Length of pair:  1000   Total fected pairs:  37000
#              Start from id:  0x80d5d166cd194a4d6ed6a878b3e5c467d1c46444
# Batch:  37   Length of pair:  1000   Total fected pairs:  38000
#              Start from id:  0x8477415848c418b82ffa211ebcd15a1d44dfb594
# Batch:  38   Length of pair:  1000   Total fected pairs:  39000
#              Start from id:  0x8808235f3fcffa3d030a4d02e30c566f02ed7e64
# Batch:  39   Length of pair:  1000   Total fected pairs:  40000
#              Start from id:  0x8b83dd7ed23323ec0165ed0611e074bce04f9c02
# Batch:  40   Length of pair:  1000   Total fected pairs:  41000
#              Start from id:  0x8f2a849554b7419b40f68c83f59040d9e2a38242
# Batch:  41   Length of pair:  1000   Total fected pairs:  42000
#              Start from id:  0x92a7698f043cdb0f5f5a352fae2e7c8a08ba004a
# Batch:  42   Length of pair:  1000   Total fected pairs:  43000
#              Start from id:  0x964bf1fade98246021df682e1ce7f80f91dd629d
# Batch:  43   Length of pair:  1000   Total fected pairs:  44000
#              Start from id:  0x99d8a9c45b2eca8864373a26d1459e3dff1e17f3
# Batch:  44   Length of pair:  1000   Total fected pairs:  45000
#              Start from id:  0x9d7f94e954f888aea235e50323db59ef3693cd42
# Batch:  45   Length of pair:  1000   Total fected pairs:  46000
#              Start from id:  0xa0ccabab149bc93788ce04ff3b3b8ab70b365ba7
# Batch:  46   Length of pair:  1000   Total fected pairs:  47000
#              Start from id:  0xa45ac2d8cd60585331eab2de46c10b6cdec24ae1
# Batch:  47   Length of pair:  1000   Total fected pairs:  48000
#              Start from id:  0xa8280309f229a5f177c1cde6a3f53a2a97bbdbac
# Batch:  48   Length of pair:  1000   Total fected pairs:  49000
#              Start from id:  0xabe4ac92af4ec2fd06b52bb9a5e64ee85e4f0257
# Batch:  49   Length of pair:  1000   Total fected pairs:  50000
#              Start from id:  0xaf66b46a25ce3910f2cae49ab172d20da4a70a31
# Batch:  50   Length of pair:  1000   Total fected pairs:  51000
#              Start from id:  0xb2f8a70b09db0f7795a5f079b5021eb84aa59e28
# Batch:  51   Length of pair:  1000   Total fected pairs:  52000
#              Start from id:  0xb6aa337c9005fbf3a10edde47ddde3541adb79cb
# Batch:  52   Length of pair:  1000   Total fected pairs:  53000
#              Start from id:  0xba21bb85adf23025642ec7fe28414519a8f43508
# Batch:  53   Length of pair:  1000   Total fected pairs:  54000
#              Start from id:  0xbdda280ee7bccc68f3be60a369b6b1eaee02493c
# Batch:  54   Length of pair:  1000   Total fected pairs:  55000
#              Start from id:  0xc18e4d26b6a728f333fed06724cd79b55c943959
# Batch:  55   Length of pair:  1000   Total fected pairs:  56000
#              Start from id:  0xc5193772a41b872736b80518d60ebda5ae432e7a
# Batch:  56   Length of pair:  1000   Total fected pairs:  57000
#              Start from id:  0xc87467941c87ff919b3270b2116c206752c68d66
# Batch:  57   Length of pair:  1000   Total fected pairs:  58000
#              Start from id:  0xcc2f10a0a3886657f925a6ee7fd7664497f3d123
# Batch:  58   Length of pair:  1000   Total fected pairs:  59000
#              Start from id:  0xcfd6ae8bf13f42de14867351eaff7a8a3b9fbbe7
# Batch:  59   Length of pair:  1000   Total fected pairs:  60000
#              Start from id:  0xd37cf8ad2ccae81c9c447b3f790cd0a85073953f
# Batch:  60   Length of pair:  1000   Total fected pairs:  61000
#              Start from id:  0xd6f9e4e947a48f23921deae3bca8989a762e9304
# Batch:  61   Length of pair:  1000   Total fected pairs:  62000
#              Start from id:  0xdab05754ba48331fd3e414c80ac906dc0d699346
# Batch:  62   Length of pair:  1000   Total fected pairs:  63000
#              Start from id:  0xde56b09e691e88e0370a334567601afac330f5d0
# Batch:  63   Length of pair:  1000   Total fected pairs:  64000
#              Start from id:  0xe1c65868fff15f139cdf34004c3de742b3b639e5
# Batch:  64   Length of pair:  1000   Total fected pairs:  65000
#              Start from id:  0xe56df913f6b82113a282c13b084304f6d25e9ecd
# Batch:  65   Length of pair:  1000   Total fected pairs:  66000
#              Start from id:  0xe8f3d5e92b401a5892e8ee031e88dbead1c970c8
# Batch:  66   Length of pair:  1000   Total fected pairs:  67000
#              Start from id:  0xecdf8cf60f102967e2645467ac5c040211bac95d
# Batch:  67   Length of pair:  1000   Total fected pairs:  68000
#              Start from id:  0xf062f045b17fe309521c10af10d42b4b8d8386de
# Batch:  68   Length of pair:  1000   Total fected pairs:  69000
#              Start from id:  0xf3c0a81169aac387774a0fc15f11ce2a4bdfbed1
# Batch:  69   Length of pair:  1000   Total fected pairs:  70000
#              Start from id:  0xf739df20ac2bb1ed8c025f9d06077bc8795a2518
# Batch:  70   Length of pair:  1000   Total fected pairs:  71000
#              Start from id:  0xfb19ddcda9a7005b168c7e84911fc5f88066dfc9
# Batch:  71   Length of pair:  274   Total fected pairs:  71274
#              Start from id:  0xfef62a8586480f794b7e6a869a9937f97f88205a
# ---------------------------
# Amount of fetced pairs:  71274

# %%
df_all_tokens
# Out:
#                                                id                    name  \
# 0      0x00000000000045166c45af0fc6e4cf31d9e14b9a               TopBidder
# 1      0x0000000000004946c0e9f43f4dee607b0ef1fa1c   Chi Gastoken by 1inch
# 2      0x000000000000d0151e748d25b766e77efe2a6c83  XDEFI Governance Token
# 3      0x0000000000085d4780b73119b644ae5ecd22b376                 TrueUSD
# 4      0x0000000000095413afc295d19edeb1ad7b71c952                Tokenlon
# ...                                           ...                     ...
# 71269  0xfffed8edc3ddc66de57f7fea41f07f98595f0a5c              TradeStars
# 71270  0xffff49dc8ed20043fb9e5d65ea2f3e071958df8e        Alaskan Malamute
# 71271  0xfffff4ff386013f4b9dac8874f856dec0e802467               Moon Doge
# 71272  0xffffffff2ba8f66d4e51811c5190992176930278               Furucombo
# 71273  0xfffffffff15abf397da76f1dcc1a1604f45126db        FalconSwap Token
#
#       symbol                    tradeVolume  \
# 0        BID     36520506.79045913892332785
# 1        CHI                       43580282
# 2       XDEX    63890993.176575438849139776
# 3       TUSD   184555032.957792364526045589
# 4        LON   142714234.348646246093382695
# ...      ...                            ...
# 71269    TSX                              0
# 71270   MALA          21789078739.712294975
# 71271   MOGE  19150445234.85529503422301082
# 71272  COMBO   130417880.769097013663764675
# 71273    FSW   752720751.025832969210737608
#
#                             tradeVolumeUSD  \
# 0      23362640.36887859622558915387398381
# 1      19360715.70503782693540014871432548
# 2      18713723.91429208465798213093796374
# 3      176239741.7006048194469590153693985
# 4      518202509.2165818130891579209118188
# ...                                    ...
# 71269                                    0
# 71270                                    0
# 71271                                    0
# 71272  185309346.3696076804844877325321709
# 71273  184288263.6807535561408728082182559
#
#                         untrackedVolumeUSD txCount  \
# 0      23466279.70596361174072586983085042    2706
# 1      65455773.59876190292325552554250769   75957
# 2      18977868.34193645649430618371779554    4400
# 3      185840599.5609657622640178364773038   47058
# 4      520054187.7708393702893219636096705   57980
# ...                                    ...     ...
# 71269                                    0       2
# 71270  5393.769723343128401960611013309801       7
# 71271  1173.552612430322387524868188060823       8
# 71272  185516831.2283832158632967962866492   23842
# 71273  184240571.1418818081113586269371114   71185
#
#                     totalLiquidity  \
# 0       2252392.839917663338975365
# 1                            23374
# 2       7459590.572861402421977784
# 3         47430.468955485871691916
# 4       1935283.541694594656834851
# ...                            ...
# 71269          0.00000000000013239
# 71270                  0.000002959
# 71271         0.000000000180785101
# 71272   2061453.687712022160325331
# 71273  16571716.146026465548545299
#
#                                           derivedETH
# 0              0.00010395165265860908001061772755218
# 1                                                  0
# 2           0.00001160462895444170070268104491209126
# 3            0.0005483537645577140176002674018884014
# 4             0.000434962232487259996007679151188112
# ...                                              ...
# 71269       0.00006042752473751793942140645063826573
# 71270  0.0000000001145657316661034133153092260898952
# 71271   0.000000005531429274141346415488077195033898
# 71272       0.00002902950409227019807739813744618048
# 71273        0.0000101398768132463306293516501686329
#
# [71274 rows x 9 columns]

# %%
# Write dataframe to csv
df_all_tokens.to_csv("All_Tokens_Info_V2_20220610.csv")

# %% [markdown]
# # Get top 200 popular tokens (order by the total trade volume USD)

# %%
# Get the top 200 popular tokens order by the total trade volume USD
get_popular_tokens_query = """
{
   tokens(first: 200, orderBy: tradeVolumeUSD, orderDirection: desc) {
     id
     name
     symbol
     tradeVolumeUSD
   }
}
"""
get_popular_tokens = run_query(get_popular_tokens_query)

# %%
# Create a dataframe to store the popular tokens
df_popular_tokens = pd.DataFrame.from_dict(get_popular_tokens['data']['tokens'])
df_popular_tokens
# Out:
#                                              id  \
# 0    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1    0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2    0xdac17f958d2ee523a2206206994597c13d831ec7
# 3    0x6b175474e89094c44da98b954eedeac495271d0f
# 4    0x05934eba98486693aaec2d00b0e9ce918e37dc3f
# ..                                          ...
# 195  0xeec2be5c91ae7f8a338e1e5f3b5de49d07afdc81
# 196  0x0d8775f648430679a709e98d2b0cb6250d2887ef
# 197  0x3155ba85d5f96b2d030a4966af206230e46849cb
# 198  0x7bef710a5759d197ec0bf621c3df802c2d60d848
# 199  0xee573a945b01b788b9287ce062a0cfc15be9fd86
#
#                                     name  symbol  \
# 0                          Wrapped Ether    WETH
# 1                                 USD//C    USDC
# 2                             Tether USD    USDT
# 3                         Dai Stablecoin     DAI
# 4    You don't blacklist delta.financial  SCAMMY
# ..                                   ...     ...
# 195               Dopex Governance Token     DPX
# 196                Basic Attention Token     BAT
# 197                   THORChain ETH.RUNE    RUNE
# 198                          SPLYT SHOPX   SHOPX
# 199                              Exeedme     XED
#
#                           tradeVolumeUSD
# 0     387545039528.004554724840496930448
# 1    57024192803.24888387524429033930168
# 2    46596921351.57798248473591458094727
# 3     19170069015.5647184759042331426974
# 4    11029715648.72159798743878461135205
# ..                                   ...
# 195  287878518.4337276001149145019920483
# 196  287655138.7316011364479310256153892
# 197  287355918.9337234532037635607585532
# 198  286422097.6157676736985608599418268
# 199  286262160.5812835995520532049278452
#
# [200 rows x 4 columns]

# %%
# Write dataframe to csv
df_popular_tokens.to_csv("Popular_Tokens_V2_20220605.csv")

# %% [markdown]
# # Token Daily Aggregated

# %%
token_address_lower = str.lower('0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2')
print(token_address_lower)
# Out:
# 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2

# %%
# Example of WETH: 0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2    lower: 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
token_daily_aggregated_query = """
{
 tokenDayDatas(orderBy: date, orderDirection: desc,
  where: {
    token: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"
  }
 ) {
    id
    date
    priceUSD
    totalLiquidityToken
    totalLiquidityUSD
    totalLiquidityETH
    dailyVolumeETH
    dailyVolumeToken
    dailyVolumeUSD
 }
}
"""
token_daily_aggregated= run_query(token_daily_aggregated_query)

pprint(token_daily_aggregated)
# Out:
# {'data': {'tokenDayDatas': [{'dailyVolumeETH': '299863.6118280715907828300597220015',
#                              'dailyVolumeToken': '62193.703571700040825615',
#                              'dailyVolumeUSD': '111358618.0086406708825746276440674',
#                              'date': 1654387200,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19148',
#                              'priceUSD': '1820.991499255286792995784432639022',
#                              'totalLiquidityETH': '344758.186848516584138967',
#                              'totalLiquidityToken': '344758.186848516584138967',
#                              'totalLiquidityUSD': '627801727.549814512357176365853776'},
#                             {'dailyVolumeETH': '23781.19905333587039978189993302351',
#                              'dailyVolumeToken': '29865.287292324909820506',
#                              'dailyVolumeUSD': '52942529.95620032390325585129382752',
#                              'date': 1654300800,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19147',
#                              'priceUSD': '1799.169055450366597727794520471468',
#                              'totalLiquidityETH': '345389.643715419578619411',
#                              'totalLiquidityToken': '345389.643715419578619411',
#                              'totalLiquidityUSD': '621414359.0458100909237125357002781'},
#                             {'dailyVolumeETH': '27368.08284564499502460326093075074',
#                              'dailyVolumeToken': '36116.409698772373946957',
#                              'dailyVolumeUSD': '64306610.57611965842092167691194795',
#                              'date': 1654214400,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19146',
#                              'priceUSD': '1773.662068443828439956164625016943',
#                              'totalLiquidityETH': '345800.812574448360918275',
#                              'totalLiquidityToken': '345800.812574448360918275',
#                              'totalLiquidityUSD': '613333784.5003527189660095070909682'},
#                             {'dailyVolumeETH': '275568.4638984604747025730926984904',
#                              'dailyVolumeToken': '34257.242819287300312331',
#                              'dailyVolumeUSD': '62338065.96643994519920457507067718',
#                              'date': 1654128000,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19145',
#                              'priceUSD': '1838.365604652960009869612793730031',
#                              'totalLiquidityETH': '343825.652285312144521635',
#                              'totalLiquidityToken': '343825.652285312144521635',
#                              'totalLiquidityUSD': '632077253.1586862422016942923370766'},
#                             {'dailyVolumeETH': '34412.09803371055370364681041352234',
#                              'dailyVolumeToken': '43803.417736487049312112',
#                              'dailyVolumeUSD': '82393163.32937788713396196558889604',
#                              'date': 1654041600,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19144',
#                              'priceUSD': '1821.715671919287824651620977197333',
#                              'totalLiquidityETH': '343608.778666151955888966',
#                              'totalLiquidityToken': '343608.778666151955888966',
#                              'totalLiquidityUSD': '625957497.1051748619814372402967176'},
#                             {'dailyVolumeETH': '30351.29032516856159101000868257015',
#                              'dailyVolumeToken': '41710.722943297685491415',
#                              'dailyVolumeUSD': '82027036.676299670837449454722523',
#                              'date': 1653955200,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19143',
#                              'priceUSD': '1944.542298193335919419224100498071',
#                              'totalLiquidityETH': '348051.978135341850448574',
#                              'totalLiquidityToken': '348051.978135341850448574',
#                              'totalLiquidityUSD': '676801793.4540343460853184172790506'},
#                             {'dailyVolumeETH': '45983.52887173305310484437063763273',
#                              'dailyVolumeToken': '58691.794475001982547374',
#                              'dailyVolumeUSD': '112483243.0883973945161934223276491',
#                              'date': 1653868800,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19142',
#                              'priceUSD': '1995.245135812025070249983100516474',
#                              'totalLiquidityETH': '347271.53185805663009731',
#                              'totalLiquidityToken': '347271.53185805663009731',
#                              'totalLiquidityUSD': '692891834.7457781918090100334605647'},
#                             {'dailyVolumeETH': '23313.43659279893061193939106548469',
#                              'dailyVolumeToken': '27476.855917661160313187',
#                              'dailyVolumeUSD': '49241386.48201820772987192030926785',
#                              'date': 1653782400,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19141',
#                              'priceUSD': '1814.18607032396308070069854452749',
#                              'totalLiquidityETH': '351031.438470121192804528',
#                              'totalLiquidityToken': '351031.438470121192804528',
#                              'totalLiquidityUSD': '636836345.9182772054273370981385938'},
#                             {'dailyVolumeETH': '35736.54719164089674436280127741965',
#                              'dailyVolumeToken': '44805.058165604259781832',
#                              'dailyVolumeUSD': '79376161.84358294599411284478332433',
#                              'date': 1653696000,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19140',
#                              'priceUSD': '1796.372763236689084055040756349164',
#                              'totalLiquidityETH': '351147.968911799603933924',
#                              'totalLiquidityToken': '351147.968911799603933924',
#                              'totalLiquidityUSD': '630792647.2190404489506105001580734'},
#                             {'dailyVolumeETH': '53642.34576072297381418988047192096',
#                              'dailyVolumeToken': '70204.132082038020058575',
#                              'dailyVolumeUSD': '123505078.4514534295605618081465782',
#                              'date': 1653609600,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19139',
#                              'priceUSD': '1719.177008251781129161515462082772',
#                              'totalLiquidityETH': '352062.8139293130325313',
#                              'totalLiquidityToken': '352062.8139293130325313',
#                              'totalLiquidityUSD': '605258295.1676998755894699499494984'},
#                             {'dailyVolumeETH': '57552.01395013436165493160113393308',
#                              'dailyVolumeToken': '74791.933168241503489193',
#                              'dailyVolumeUSD': '138561394.5103722915924984124378438',
#                              'date': 1653523200,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19138',
#                              'priceUSD': '1795.10062787656196621041616231296',
#                              'totalLiquidityETH': '350960.252935242858380095',
#                              'totalLiquidityToken': '350960.252935242858380095',
#                              'totalLiquidityUSD': '630008970.4037714548500021989957002'},
#                             {'dailyVolumeETH': '31325.04206224667216039904650939421',
#                              'dailyVolumeToken': '41252.015826206174954474',
#                              'dailyVolumeUSD': '81319168.4025762419712872460067224',
#                              'date': 1653436800,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19137',
#                              'priceUSD': '1944.225696478652084511617520480357',
#                              'totalLiquidityETH': '348125.869240115420175058',
#                              'totalLiquidityToken': '348125.869240115420175058',
#                              'totalLiquidityUSD': '676835260.585599566894384618193392'},
#                             {'dailyVolumeETH': '119706.5417527379483628530102530199',
#                              'dailyVolumeToken': '44136.603205307544509489',
#                              'dailyVolumeUSD': '86718192.46765749925905949265457814',
#                              'date': 1653350400,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19136',
#                              'priceUSD': '1980.258278381704163866194915168802',
#                              'totalLiquidityETH': '348068.874486844352847866',
#                              'totalLiquidityToken': '348068.874486844352847866',
#                              'totalLiquidityUSD': '689266270.1495758705283879885588519'},
#                             {'dailyVolumeETH': '35327.85919324093997752255826357536',
#                              'dailyVolumeToken': '46551.058724227163130955',
#                              'dailyVolumeUSD': '94760273.91828759782523044706970298',
#                              'date': 1653264000,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19135',
#                              'priceUSD': '1970.137228068780324584139130315506',
#                              'totalLiquidityETH': '348049.924604711735866485',
#                              'totalLiquidityToken': '348049.924604711735866485',
#                              'totalLiquidityUSD': '685706113.690274761824862161388053'},
#                             {'dailyVolumeETH': '28086.39181696877102308236844567344',
#                              'dailyVolumeToken': '36401.186137512004322807',
#                              'dailyVolumeUSD': '73004987.83677579929926145051535003',
#                              'date': 1653177600,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19134',
#                              'priceUSD': '2048.004396941847293149433117722139',
#                              'totalLiquidityETH': '347590.144970562477371385',
#                              'totalLiquidityToken': '347590.144970562477371385',
#                              'totalLiquidityUSD': '711866145.2333660814151903176605141'},
#                             {'dailyVolumeETH': '29181.63376304555987107031430556869',
#                              'dailyVolumeToken': '36490.675883592536056169',
#                              'dailyVolumeUSD': '71896125.73318185931563990770694699',
#                              'date': 1653091200,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19133',
#                              'priceUSD': '1975.997809082013387744824341389874',
#                              'totalLiquidityETH': '349081.02285695273767117',
#                              'totalLiquidityToken': '349081.02285695273767117',
#                              'totalLiquidityUSD': '689783336.3574468473367108359229985'},
#                             {'dailyVolumeETH': '124882.561374024997143479723754134',
#                              'dailyVolumeToken': '75005.924847481700714197',
#                              'dailyVolumeUSD': '149016209.132693868253568295317584',
#                              'date': 1653004800,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19132',
#                              'priceUSD': '1963.21595919525308119300155215297',
#                              'totalLiquidityETH': '348382.609678244443592091',
#                              'totalLiquidityToken': '348382.609678244443592091',
#                              'totalLiquidityUSD': '683950299.226420124736804368073759'},
#                             {'dailyVolumeETH': '57517.863750009527247313398658937',
#                              'dailyVolumeToken': '76637.230270031012893718',
#                              'dailyVolumeUSD': '150998190.2875094846495197614913181',
#                              'date': 1652918400,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19131',
#                              'priceUSD': '2020.366360868832872292247843410911',
#                              'totalLiquidityETH': '347639.516245655985593511',
#                              'totalLiquidityToken': '347639.516245655985593511',
#                              'totalLiquidityUSD': '702359184.3314374888477751050843661'},
#                             {'dailyVolumeETH': '47876.03200798870569097326795809164',
#                              'dailyVolumeToken': '62583.693289931700522193',
#                              'dailyVolumeUSD': '125271783.5825564731541931057710603',
#                              'date': 1652832000,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19130',
#                              'priceUSD': '1914.040257796105611660714275426571',
#                              'totalLiquidityETH': '360301.523177502762585905',
#                              'totalLiquidityToken': '360301.523177502762585905',
#                              'totalLiquidityUSD': '689631620.3069969088096484488615385'},
#                             {'dailyVolumeETH': '45834.34786900942199860087327029896',
#                              'dailyVolumeToken': '56811.48285859375032765',
#                              'dailyVolumeUSD': '117312677.2453171145311186415216427',
#                              'date': 1652745600,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19129',
#                              'priceUSD': '2094.297023605576974676750393823712',
#                              'totalLiquidityETH': '358593.601125044439454784',
#                              'totalLiquidityToken': '358593.601125044439454784',
#                              'totalLiquidityUSD': '751001511.5201860484006036423526232'},
#                             {'dailyVolumeETH': '47256.67311330907362664657294566388',
#                              'dailyVolumeToken': '58047.558622008506799905',
#                              'dailyVolumeUSD': '118063453.4188185449229688661659317',
#                              'date': 1652659200,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19128',
#                              'priceUSD': '2022.745767679807517827421478852466',
#                              'totalLiquidityETH': '359194.252735594579887333',
#                              'totalLiquidityToken': '359194.252735594579887333',
#                              'totalLiquidityUSD': '726558654.4958350600653062113350691'},
#                             {'dailyVolumeETH': '43759.310419741744360039988931355',
#                              'dailyVolumeToken': '55521.105944028543776417',
#                              'dailyVolumeUSD': '114973451.4307641084511523810827272',
#                              'date': 1652572800,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19127',
#                              'priceUSD': '2143.783054476509777277875707265584',
#                              'totalLiquidityETH': '357870.494706973077254265',
#                              'totalLiquidityToken': '357870.494706973077254265',
#                              'totalLiquidityUSD': '767196702.2499343683790690944389282'},
#                             {'dailyVolumeETH': '51818.39474694411031728976306961044',
#                              'dailyVolumeToken': '65443.792587796465682153',
#                              'dailyVolumeUSD': '131967433.7289846870470769602098524',
#                              'date': 1652486400,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19126',
#                              'priceUSD': '2059.773445249114476271351975428932',
#                              'totalLiquidityETH': '358119.812598258284778736',
#                              'totalLiquidityToken': '358119.812598258284778736',
#                              'totalLiquidityUSD': '737645680.2074816977962979431796099'},
#                             {'dailyVolumeETH': '79291.23851468917095519417281252228',
#                              'dailyVolumeToken': '101233.977506969081334296',
#                              'dailyVolumeUSD': '209812653.136825306795044247857433',
#                              'date': 1652400000,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19125',
#                              'priceUSD': '2005.649606744198396733265868467265',
#                              'totalLiquidityETH': '360661.171885127367915405',
#                              'totalLiquidityToken': '360661.171885127367915405',
#                              'totalLiquidityUSD': '723359937.5593074486002016904635457'},
#                             {'dailyVolumeETH': '191052.6189504907515072521360450345',
#                              'dailyVolumeToken': '284820.965419328956802991',
#                              'dailyVolumeUSD': '539886528.5685501997458808024280227',
#                              'date': 1652313600,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19124',
#                              'priceUSD': '1955.9761587859424106433500082682',
#                              'totalLiquidityETH': '359193.639975045655773803',
#                              'totalLiquidityToken': '359193.639975045655773803',
#                              'totalLiquidityUSD': '702574196.1787305329447806627955976'},
#                             {'dailyVolumeETH': '150603.9829367660032989963409730035',
#                              'dailyVolumeToken': '196750.158356706149875104',
#                              'dailyVolumeUSD': '441173592.8751452999150259779201578',
#                              'date': 1652227200,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19123',
#                              'priceUSD': '2073.963763224427516982518742347665',
#                              'totalLiquidityETH': '366115.023207147889398286',
#                              'totalLiquidityToken': '366115.023207147889398286',
#                              'totalLiquidityUSD': '759309291.3036950507823544647285912'},
#                             {'dailyVolumeETH': '65648.57707895976569711225602956421',
#                              'dailyVolumeToken': '93695.615020420641621309',
#                              'dailyVolumeUSD': '219401691.4944006952039610803925843',
#                              'date': 1652140800,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19122',
#                              'priceUSD': '2341.644261987015185525827722998587',
#                              'totalLiquidityETH': '375892.209789807746390637',
#                              'totalLiquidityToken': '375892.209789807746390637',
#                              'totalLiquidityUSD': '880205836.1799226448123790438691264'},
#                             {'dailyVolumeETH': '84292.49466104510227321291869231039',
#                              'dailyVolumeToken': '113211.154347025006792167',
#                              'dailyVolumeUSD': '268248903.6731334042623773906528542',
#                              'date': 1652054400,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19121',
#                              'priceUSD': '2234.862553222406633541369088060353',
#                              'totalLiquidityETH': '379905.245766212263113883',
#                              'totalLiquidityToken': '379905.245766212263113883',
#                              'totalLiquidityUSD': '849036007.5356630262581700221755664'},
#                             {'dailyVolumeETH': '38471.15032597777068797154984885454',
#                              'dailyVolumeToken': '55432.774146081844930013',
#                              'dailyVolumeUSD': '141049532.0483885220459954694843878',
#                              'date': 1651968000,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19120',
#                              'priceUSD': '2516.740621659108150797956297386422',
#                              'totalLiquidityETH': '384102.965930917712625477',
#                              'totalLiquidityToken': '384102.965930917712625477',
#                              'totalLiquidityUSD': '966687537.2580850827636801072814049'},
#                             {'dailyVolumeETH': '30859.08568656882339436959350164283',
#                              'dailyVolumeToken': '47123.833043878982031072',
#                              'dailyVolumeUSD': '125592751.3155902520604479161929765',
#                              'date': 1651881600,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19119',
#                              'priceUSD': '2639.042057204531470671944790753034',
#                              'totalLiquidityETH': '382277.329127837021189469',
#                              'totalLiquidityToken': '382277.329127837021189469',
#                              'totalLiquidityUSD': '1008845949.084180772691668440292469'},
#                             {'dailyVolumeETH': '46849.48966877605449750670909600142',
#                              'dailyVolumeToken': '63280.10353254320314642',
#                              'dailyVolumeUSD': '170935884.1301735851672327795673619',
#                              'date': 1651795200,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19118',
#                              'priceUSD': '2696.237197798392066480906423245829',
#                              'totalLiquidityETH': '382296.794806954720162375',
#                              'totalLiquidityToken': '382296.794806954720162375',
#                              'totalLiquidityUSD': '1030762838.757610478811472989270723'},
#                             {'dailyVolumeETH': '41638.89538460741701421758048967281',
#                              'dailyVolumeToken': '57460.809797676686598521',
#                              'dailyVolumeUSD': '162545994.0983577788013622054327725',
#                              'date': 1651708800,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19117',
#                              'priceUSD': '2743.551717986615117789064276792838',
#                              'totalLiquidityETH': '382423.158260856055004477',
#                              'totalLiquidityToken': '382423.158260856055004477',
#                              'totalLiquidityUSD': '1049197712.844438832930179782067345'},
#                             {'dailyVolumeETH': '43701.67331178484212883725511508754',
#                              'dailyVolumeToken': '64767.02077986790822607',
#                              'dailyVolumeUSD': '185791176.1406274644291547893211493',
#                              'date': 1651622400,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19116',
#                              'priceUSD': '2934.692231034892757076391107680019',
#                              'totalLiquidityETH': '382924.422439202138980661',
#                              'totalLiquidityToken': '382924.422439202138980661',
#                              'totalLiquidityUSD': '1123765327.605849875955916544241886'},
#                             {'dailyVolumeETH': '35931.04217763025768916566446299437',
#                              'dailyVolumeToken': '49491.059387369466921012',
#                              'dailyVolumeUSD': '139436703.6014094314909242511052178',
#                              'date': 1651536000,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19115',
#                              'priceUSD': '2782.763814821502580704136645737208',
#                              'totalLiquidityETH': '383930.094103644633813414',
#                              'totalLiquidityToken': '383930.094103644633813414',
#                              'totalLiquidityUSD': '1068386773.292636615607375409741582'},
#                             {'dailyVolumeETH': '38949.19203988858543246900438055368',
#                              'dailyVolumeToken': '56597.040911729761654285',
#                              'dailyVolumeUSD': '160155981.6201526191219268169533577',
#                              'date': 1651449600,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19114',
#                              'priceUSD': '2861.066037808258123030305219455855',
#                              'totalLiquidityETH': '381949.045811132268875551',
#                              'totalLiquidityToken': '381949.045811132268875551',
#                              'totalLiquidityUSD': '1092781443.143501069855112975561732'},
#                             {'dailyVolumeETH': '42497.32511866993634155715098761567',
#                              'dailyVolumeToken': '56677.158330743779257778',
#                              'dailyVolumeUSD': '157295958.2397841752580516692958272',
#                              'date': 1651363200,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19113',
#                              'priceUSD': '2827.757451829965321336867353853344',
#                              'totalLiquidityETH': '384875.167836896387687412',
#                              'totalLiquidityToken': '384875.167836896387687412',
#                              'totalLiquidityUSD': '1088333623.875092355346394407310612'},
#                             {'dailyVolumeETH': '72240.14784434877992275276600190141',
#                              'dailyVolumeToken': '84900.724300134579121935',
#                              'dailyVolumeUSD': '239544209.2712857736533125746634115',
#                              'date': 1651276800,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19112',
#                              'priceUSD': '2726.16863633987504235660920105071',
#                              'totalLiquidityETH': '386748.0122113234537231',
#                              'totalLiquidityToken': '386748.0122113234537231',
#                              'totalLiquidityUSD': '1054340301.057301000622770620043954'},
#                             {'dailyVolumeETH': '75553.25313413067530540437959770023',
#                              'dailyVolumeToken': '89503.241551457201351083',
#                              'dailyVolumeUSD': '257092696.4930874496541856149166904',
#                              'date': 1651190400,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19111',
#                              'priceUSD': '2813.154624875884097019295156761415',
#                              'totalLiquidityETH': '390651.459179076821498644',
#                              'totalLiquidityToken': '390651.459179076821498644',
#                              'totalLiquidityUSD': '1098962959.104132605022468722565762'},
#                             {'dailyVolumeETH': '54419.53334376428365086392229578269',
#                              'dailyVolumeToken': '72321.078614396851938392',
#                              'dailyVolumeUSD': '210978873.0721798691610422665394701',
#                              'date': 1651104000,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19110',
#                              'priceUSD': '2932.654173106270276876373329693737',
#                              'totalLiquidityETH': '390310.410871803752243281',
#                              'totalLiquidityToken': '390310.410871803752243281',
#                              'totalLiquidityUSD': '1144645455.250018237484393755620195'},
#                             {'dailyVolumeETH': '46930.82450553260326059878894186248',
#                              'dailyVolumeToken': '59716.083566468493191366',
#                              'dailyVolumeUSD': '170893081.1358663432260995991067141',
#                              'date': 1651017600,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19109',
#                              'priceUSD': '2888.564237942407502680409109550943',
#                              'totalLiquidityETH': '392212.174530364336980403',
#                              'totalLiquidityToken': '392212.174530364336980403',
#                              'totalLiquidityUSD': '1132930061.034036390301822090038343'},
#                             {'dailyVolumeETH': '44844.01419968372075641119269569047',
#                              'dailyVolumeToken': '64860.886078868666965578',
#                              'dailyVolumeUSD': '189513587.9339526787060558569672905',
#                              'date': 1650931200,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19108',
#                              'priceUSD': '2805.832666612508915422804264188115',
#                              'totalLiquidityETH': '393577.263568491113337739',
#                              'totalLiquidityToken': '393577.263568491113337739',
#                              'totalLiquidityUSD': '1104311942.956433676977148042124062'},
#                             {'dailyVolumeETH': '57093.74950159776458276132094871018',
#                              'dailyVolumeToken': '74277.992723217762225057',
#                              'dailyVolumeUSD': '215063986.4674565499634300752887248',
#                              'date': 1650844800,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19107',
#                              'priceUSD': '3011.167261247645498734621267939102',
#                              'totalLiquidityETH': '392228.76017740914683943',
#                              'totalLiquidityToken': '392228.76017740914683943',
#                              'totalLiquidityUSD': '1181066401.565968661697029885543746'},
#                             {'dailyVolumeETH': '33082.13533850850055869499931254895',
#                              'dailyVolumeToken': '48517.231657980204961873',
#                              'dailyVolumeUSD': '142776730.2394971122860924877239529',
#                              'date': 1650758400,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19106',
#                              'priceUSD': '2923.761060462993461499883150146461',
#                              'totalLiquidityETH': '395642.937872727925556674',
#                              'totalLiquidityToken': '395642.937872727925556674',
#                              'totalLiquidityUSD': '1156765415.599461238040859782196295'},
#                             {'dailyVolumeETH': '42487.44450758377872356461943726842',
#                              'dailyVolumeToken': '53328.147903836021153082',
#                              'dailyVolumeUSD': '157725164.8221448714175450681129226',
#                              'date': 1650672000,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19105',
#                              'priceUSD': '2935.377081267128816076981190897854',
#                              'totalLiquidityETH': '396560.139876209440766777',
#                              'totalLiquidityToken': '396560.139876209440766777',
#                              'totalLiquidityUSD': '1164053545.936712010251078158348278'},
#                             {'dailyVolumeETH': '49170.23521333312929875455905115767',
#                              'dailyVolumeToken': '65398.623838775794498047',
#                              'dailyVolumeUSD': '195078054.7400886197598269153278385',
#                              'date': 1650585600,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19104',
#                              'priceUSD': '2961.439699092169771669537583062439',
#                              'totalLiquidityETH': '396142.833212555489462698',
#                              'totalLiquidityToken': '396142.833212555489462698',
#                              'totalLiquidityUSD': '1173153112.786509926220934985733113'},
#                             {'dailyVolumeETH': '82466.38145040768500891611914439303',
#                              'dailyVolumeToken': '101772.995848366542741663',
#                              'dailyVolumeUSD': '314046383.3251554836312492243107986',
#                              'date': 1650499200,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19103',
#                              'priceUSD': '2983.871356991993204092433202470816',
#                              'totalLiquidityETH': '395822.124996711518908649',
#                              'totalLiquidityToken': '395822.124996711518908649',
#                              'totalLiquidityUSD': '1181082301.241391953492933587486191'},
#                             {'dailyVolumeETH': '61277.1531080003809850954377497355',
#                              'dailyVolumeToken': '83339.140805539763276445',
#                              'dailyVolumeUSD': '257918782.2204649064193142843412122',
#                              'date': 1650412800,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19102',
#                              'priceUSD': '3075.091932272520976153869614468361',
#                              'totalLiquidityETH': '398984.434746320725912492',
#                              'totalLiquidityToken': '398984.434746320725912492',
#                              'totalLiquidityUSD': '1226913816.390722958565154705002538'},
#                             {'dailyVolumeETH': '53018.16818468938195382231655562613',
#                              'dailyVolumeToken': '74018.069161776557661507',
#                              'dailyVolumeUSD': '227668924.5380961911967213317405912',
#                              'date': 1650326400,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19101',
#                              'priceUSD': '3102.660324421708836396212109901481',
#                              'totalLiquidityETH': '399671.887960727239698888',
#                              'totalLiquidityToken': '399671.887960727239698888',
#                              'totalLiquidityUSD': '1240046109.562466843611973044483851'},
#                             {'dailyVolumeETH': '53797.01868420966763463999899036226',
#                              'dailyVolumeToken': '76539.529795909501802476',
#                              'dailyVolumeUSD': '226736679.7343988167397721310105515',
#                              'date': 1650240000,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19100',
#                              'priceUSD': '3063.811095443655794976045182855804',
#                              'totalLiquidityETH': '398949.888316343650946591',
#                              'totalLiquidityToken': '398949.888316343650946591',
#                              'totalLiquidityUSD': '1222307094.349620977459564640556742'},
#                             {'dailyVolumeETH': '47735.89603419667034570142860295638',
#                              'dailyVolumeToken': '68581.668775907480385633',
#                              'dailyVolumeUSD': '208889173.5707672981520310852038362',
#                              'date': 1650153600,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19099',
#                              'priceUSD': '2986.388218327270054025058209274477',
#                              'totalLiquidityETH': '400721.841312491824954232',
#                              'totalLiquidityToken': '400721.841312491824954232',
#                              'totalLiquidityUSD': '1196710985.722035500919996836226368'},
#                             {'dailyVolumeETH': '33191.63391290741625602828159373073',
#                              'dailyVolumeToken': '53137.803263870686030502',
#                              'dailyVolumeUSD': '161396554.7853835709915905950613414',
#                              'date': 1650067200,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19098',
#                              'priceUSD': '3068.076662380148741988876194976267',
#                              'totalLiquidityETH': '411019.316926897855786228',
#                              'totalLiquidityToken': '411019.316926897855786228',
#                              'totalLiquidityUSD': '1261038774.050845347658455214908085'},
#                             {'dailyVolumeETH': '35737.62044363919320692514571237059',
#                              'dailyVolumeToken': '60921.041847286423069735',
#                              'dailyVolumeUSD': '184503174.8425048786797907816015589',
#                              'date': 1649980800,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19097',
#                              'priceUSD': '3036.352177161506913081371066377677',
#                              'totalLiquidityETH': '410986.276198061731110054',
#                              'totalLiquidityToken': '410986.276198061731110054',
#                              'totalLiquidityUSD': '1247899074.517485145223957807823406'},
#                             {'dailyVolumeETH': '37567.05978566914613316576260230356',
#                              'dailyVolumeToken': '85729.226346629430257082',
#                              'dailyVolumeUSD': '264014656.9608027260496097620051026',
#                              'date': 1649894400,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19096',
#                              'priceUSD': '3021.918210066472312619418763356154',
#                              'totalLiquidityETH': '399317.838839951101168444',
#                              'totalLiquidityToken': '399317.838839951101168444',
#                              'totalLiquidityUSD': '1206705848.794837088348353110547147'},
#                             {'dailyVolumeETH': '41719.26786601811626085515173376647',
#                              'dailyVolumeToken': '58653.9065255242410544',
#                              'dailyVolumeUSD': '179606471.6026175593134517245351995',
#                              'date': 1649808000,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19095',
#                              'priceUSD': '3118.725313953898607254603812179408',
#                              'totalLiquidityETH': '400145.815058150199312822',
#                              'totalLiquidityToken': '400145.815058150199312822',
#                              'totalLiquidityUSD': '1247944882.694568129235620925926001'},
#                             {'dailyVolumeETH': '47351.64924295055612190111196745923',
#                              'dailyVolumeToken': '68275.768729028471247188',
#                              'dailyVolumeUSD': '205908796.5156200347504688474677362',
#                              'date': 1649721600,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19094',
#                              'priceUSD': '3025.517483371247631504491834908755',
#                              'totalLiquidityETH': '405087.571507947882014818',
#                              'totalLiquidityToken': '405087.571507947882014818',
#                              'totalLiquidityUSD': '1225599529.893696791962885245181339'},
#                             {'dailyVolumeETH': '53153.77274898177351316063134335193',
#                              'dailyVolumeToken': '81402.287331683033370488',
#                              'dailyVolumeUSD': '250095650.9371702396240352010323974',
#                              'date': 1649635200,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19093',
#                              'priceUSD': '2983.243636854206863356235480192866',
#                              'totalLiquidityETH': '404331.259784215153451217',
#                              'totalLiquidityToken': '404331.259784215153451217',
#                              'totalLiquidityUSD': '1206218657.932505126965256175337856'},
#                             {'dailyVolumeETH': '33034.28559438055283399090803648543',
#                              'dailyVolumeToken': '54587.52293932876779447',
#                              'dailyVolumeUSD': '177924539.7452205744486248200048474',
#                              'date': 1649548800,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19092',
#                              'priceUSD': '3207.270117159647876359781074263204',
#                              'totalLiquidityETH': '405946.732684557246166224',
#                              'totalLiquidityToken': '405946.732684557246166224',
#                              'totalLiquidityUSD': '1301980824.897776176793024343857943'},
#                             {'dailyVolumeETH': '82747.72501435049724632301710611262',
#                              'dailyVolumeToken': '59182.063607055704190985',
#                              'dailyVolumeUSD': '190356263.738827582087646953637713',
#                              'date': 1649462400,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19091',
#                              'priceUSD': '3258.254297737687737686200833238937',
#                              'totalLiquidityETH': '404668.318477855560009073',
#                              'totalLiquidityToken': '404668.318477855560009073',
#                              'totalLiquidityUSD': '1318512287.838756234116111751237546'},
#                             {'dailyVolumeETH': '45584.65378659833376487670595296916',
#                              'dailyVolumeToken': '74215.25918217974479053',
#                              'dailyVolumeUSD': '241412435.3094676431982733718083874',
#                              'date': 1649376000,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19090',
#                              'priceUSD': '3184.33485754308200164079134746097',
#                              'totalLiquidityETH': '411563.421081095396576718',
#                              'totalLiquidityToken': '411563.421081095396576718',
#                              'totalLiquidityUSD': '1310555747.8382133815843347524643'},
#                             {'dailyVolumeETH': '51127.97984169723261413944426367361',
#                              'dailyVolumeToken': '70516.205196071232336868',
#                              'dailyVolumeUSD': '226539563.2367844707456248649724051',
#                              'date': 1649289600,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19089',
#                              'priceUSD': '3237.418998192298941257443224834401',
#                              'totalLiquidityETH': '408218.376956299227415431',
#                              'totalLiquidityToken': '408218.376956299227415431',
#                              'totalLiquidityUSD': '1321573928.969548496297966957869538'},
#                             {'dailyVolumeETH': '72407.55206113460517732364815081768',
#                              'dailyVolumeToken': '102015.963857062280267721',
#                              'dailyVolumeUSD': '335891413.8536079177824507249498516',
#                              'date': 1649203200,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19088',
#                              'priceUSD': '3170.620270865699844122660646636127',
#                              'totalLiquidityETH': '409015.626021767148526227',
#                              'totalLiquidityToken': '409015.626021767148526227',
#                              'totalLiquidityUSD': '1296833234.96543914602813223507688'},
#                             {'dailyVolumeETH': '60828.2277003355263821377757106988',
#                              'dailyVolumeToken': '87000.741740153213707736',
#                              'dailyVolumeUSD': '303679885.8421614137765703626395768',
#                              'date': 1649116800,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19087',
#                              'priceUSD': '3410.459697316193423627358171732438',
#                              'totalLiquidityETH': '410682.788044147542443192',
#                              'totalLiquidityToken': '410682.788044147542443192',
#                              'totalLiquidityUSD': '1400617097.006013847000610917664331'},
#                             {'dailyVolumeETH': '1492739659399092.714499040705925818',
#                              'dailyVolumeToken': '129069.086910959031444032',
#                              'dailyVolumeUSD': '448908898.3021922773431174600790912',
#                              'date': 1649030400,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19086',
#                              'priceUSD': '3527.611570409300095374851299797365',
#                              'totalLiquidityETH': '409245.525736362391906332',
#                              'totalLiquidityToken': '409245.525736362391906332',
#                              'totalLiquidityUSD': '1443659251.72582897611727540868146'},
#                             {'dailyVolumeETH': '58776.50621543387652187896675157631',
#                              'dailyVolumeToken': '93958.979036345478403281',
#                              'dailyVolumeUSD': '327875307.2385699915334769701880888',
#                              'date': 1648944000,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19085',
#                              'priceUSD': '3524.207837609367019417676970186401',
#                              'totalLiquidityETH': '409204.44518214332898125',
#                              'totalLiquidityToken': '409204.44518214332898125',
#                              'totalLiquidityUSD': '1442121512.895502105546097341318775'},
#                             {'dailyVolumeETH': '62281.41312769473554256458366551537',
#                              'dailyVolumeToken': '98518.122668905753558098',
#                              'dailyVolumeUSD': '342798180.4544690169331254250824998',
#                              'date': 1648857600,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19084',
#                              'priceUSD': '3449.766411386532602608703835947073',
#                              'totalLiquidityETH': '407599.711524983486089681',
#                              'totalLiquidityToken': '407599.711524983486089681',
#                              'totalLiquidityUSD': '1406123794.109728194960176010326344'},
#                             {'dailyVolumeETH': '53215.41602636089273069865226462091',
#                              'dailyVolumeToken': '86574.188422135399141613',
#                              'dailyVolumeUSD': '289789584.8935329512164020303779295',
#                              'date': 1648771200,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19083',
#                              'priceUSD': '3448.177477610706116135124296533148',
#                              'totalLiquidityETH': '407911.882699153296403645',
#                              'totalLiquidityToken': '407911.882699153296403645',
#                              'totalLiquidityUSD': '1406552566.773000645237920102036167'},
#                             {'dailyVolumeETH': '62926.25233196941117997823803311124',
#                              'dailyVolumeToken': '87076.548962113755245657',
#                              'dailyVolumeUSD': '292715136.8289200827759740658894752',
#                              'date': 1648684800,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19082',
#                              'priceUSD': '3276.826995162410192228444662114832',
#                              'totalLiquidityETH': '410776.19884081000207882',
#                              'totalLiquidityToken': '410776.19884081000207882',
#                              'totalLiquidityUSD': '1346042537.331768163894489253568045'},
#                             {'dailyVolumeETH': '62642.74792991566474217631041985244',
# ...
#                              'totalLiquidityETH': '416984.108382204784496304',
#                              'totalLiquidityToken': '416984.108382204784496304',
#                              'totalLiquidityUSD': '1192679024.444575979799326747671803'},
#                             {'dailyVolumeETH': '40430.73973770348712354637166002204',
#                              'dailyVolumeToken': '53837.654089855452450243',
#                              'dailyVolumeUSD': '158918062.4765878892205875041848817',
#                              'date': 1647648000,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19070',
#                              'priceUSD': '2947.583036062544331095438163722431',
#                              'totalLiquidityETH': '416178.839020809886916446',
#                              'totalLiquidityToken': '416178.839020809886916446',
#                              'totalLiquidityUSD': '1226721685.86594370075862717264171'},
#                             {'dailyVolumeETH': '71903.07142726117961917124943602213',
#                              'dailyVolumeToken': '90681.130621549634052875',
#                              'dailyVolumeUSD': '257851336.4407973956330040193374928',
#                              'date': 1647561600,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19069',
#                              'priceUSD': '2945.431117343209702767825559937932',
#                              'totalLiquidityETH': '414747.533683274079054125',
#                              'totalLiquidityToken': '414747.533683274079054125',
#                              'totalLiquidityUSD': '1221610291.552066472644662918547352'},
#                             {'dailyVolumeETH': '69405.47970343544693914661504126214',
#                              'dailyVolumeToken': '77723.584217852472046913',
#                              'dailyVolumeUSD': '217259301.7571146007086610043987386',
#                              'date': 1647475200,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19068',
#                              'priceUSD': '2816.362887188031824317348975946861',
#                              'totalLiquidityETH': '421445.864452987628625632',
#                              'totalLiquidityToken': '421445.864452987628625632',
#                              'totalLiquidityUSD': '1186944491.604272148275466221280691'},
#                             {'dailyVolumeETH': '47673.8736766093900269311998563522',
#                              'dailyVolumeToken': '66120.744191521351148557',
#                              'dailyVolumeUSD': '177820877.5141893090822926868856241',
#                              'date': 1647388800,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19067',
#                              'priceUSD': '2770.01953290493567152125897090889',
#                              'totalLiquidityETH': '424109.696444732242469477',
#                              'totalLiquidityToken': '424109.696444732242469477',
#                              'totalLiquidityUSD': '1174792143.246291263101502274000478'},
#                             {'dailyVolumeETH': '453787.2997208473749545729309499055',
#                              'dailyVolumeToken': '71521.693844091783407017',
#                              'dailyVolumeUSD': '183910542.3476864312976406190085576',
#                              'date': 1647302400,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19066',
#                              'priceUSD': '2620.195983170528366312591022136621',
#                              'totalLiquidityETH': '427547.985027327305286219',
#                              'totalLiquidityToken': '427547.985027327305286219',
#                              'totalLiquidityUSD': '1120259512.981256209944115941428064'},
#                             {'dailyVolumeETH': '46963.65617359330346980085465977511',
#                              'dailyVolumeToken': '55397.240531470445420782',
#                              'dailyVolumeUSD': '141763484.4658685748034882186974529',
#                              'date': 1647216000,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19065',
#                              'priceUSD': '2588.383994613482083720315562292949',
#                              'totalLiquidityETH': '429178.591063410167792245',
#                              'totalLiquidityToken': '429178.591063410167792245',
#                              'totalLiquidityUSD': '1110878995.939295693704031348293032'},
#                             {'dailyVolumeETH': '88815.93564203676709303160341428199',
#                              'dailyVolumeToken': '61371.445238691027855134',
#                              'dailyVolumeUSD': '157634305.2611042525953170658964124',
#                              'date': 1647129600,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19064',
#                              'priceUSD': '2515.200579730148814563680612271439',
#                              'totalLiquidityETH': '431702.161597097409299032',
#                              'totalLiquidityToken': '431702.161597097409299032',
#                              'totalLiquidityUSD': '1085817527.119777790123024428549644'},
#                             {'dailyVolumeETH': '36769.53789679526652381833983632875',
#                              'dailyVolumeToken': '45364.937361926121079555',
#                              'dailyVolumeUSD': '117231471.9119611989580362835668878',
#                              'date': 1647043200,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19063',
#                              'priceUSD': '2569.691817759491934944807662729427',
#                              'totalLiquidityETH': '431925.089267384449700315',
#                              'totalLiquidityToken': '431925.089267384449700315',
#                              'totalLiquidityUSD': '1109914367.77543596718684215071169'},
#                             {'dailyVolumeETH': '50221.40608012777306646577409986248',
#                              'dailyVolumeToken': '65036.662608682042950801',
#                              'dailyVolumeUSD': '167876817.8933118032448502002275473',
#                              'date': 1646956800,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19062',
#                              'priceUSD': '2562.827890648807533660093195895556',
#                              'totalLiquidityETH': '431495.439656784279703595',
#                              'totalLiquidityToken': '431495.439656784279703595',
#                              'totalLiquidityUSD': '1105848547.440176271727229978269626'},
#                             {'dailyVolumeETH': '2396432597695732612.043546895005833',
#                              'dailyVolumeToken': '53716.885123730285512417',
#                              'dailyVolumeUSD': '140568750.2897844411407795131092146',
#                              'date': 1646870400,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19061',
#                              'priceUSD': '2610.714807892141661407885857053243',
#                              'totalLiquidityETH': '432145.603197928402590521',
#                              'totalLiquidityToken': '432145.603197928402590521',
#                              'totalLiquidityUSD': '1128208925.434313328776043169122809'},
#                             {'dailyVolumeETH': '51615.24610489886725745976481388954',
#                              'dailyVolumeToken': '66506.320719838716552709',
#                              'dailyVolumeUSD': '179790899.4840249447178100625444912',
#                              'date': 1646784000,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19060',
#                              'priceUSD': '2726.691017956163817307251713582721',
#                              'totalLiquidityETH': '431393.023708535744738632',
#                              'totalLiquidityToken': '431393.023708535744738632',
#                              'totalLiquidityUSD': '1176275482.955014841711104166201051'},
#                             {'dailyVolumeETH': '51724.37550063994872988216245944945',
#                              'dailyVolumeToken': '69041.981779638889381972',
#                              'dailyVolumeUSD': '176778790.6537284568709444320015694',
#                              'date': 1646697600,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19059',
#                              'priceUSD': '2579.156035066504124169005933868335',
#                              'totalLiquidityETH': '434665.022975562836952171',
#                              'totalLiquidityToken': '434665.022975562836952171',
#                              'totalLiquidityUSD': '1121068917.23974356510680348900833'},
#                             {'dailyVolumeETH': '59340.06642611129095437241431618109',
#                              'dailyVolumeToken': '77614.801006223724852802',
#                              'dailyVolumeUSD': '196645300.6044338171992994787966163',
#                              'date': 1646611200,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19058',
#                              'priceUSD': '2492.304338564104790103594510834604',
#                              'totalLiquidityETH': '437022.093851855313223363',
#                              'totalLiquidityToken': '437022.093851855313223363',
#                              'totalLiquidityUSD': '1089192060.555348383017870590461441'},
#                             {'dailyVolumeETH': '45196.67716687795298007703630110973',
#                              'dailyVolumeToken': '57969.422328542695680666',
#                              'dailyVolumeUSD': '152344892.4890319230642526502125037',
#                              'date': 1646524800,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19057',
#                              'priceUSD': '2551.10412783427727817999307613995',
#                              'totalLiquidityETH': '437632.203739242785267966',
#                              'totalLiquidityToken': '437632.203739242785267966',
#                              'totalLiquidityUSD': '1116445321.432393705131570522739111'},
#                             {'dailyVolumeETH': '198254816.1910144004286590225602689',
#                              'dailyVolumeToken': '57565.725985357258627728',
#                              'dailyVolumeUSD': '152170008.7379146956779264726816696',
#                              'date': 1646438400,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19056',
#                              'priceUSD': '2664.193521339960406354005410626146',
#                              'totalLiquidityETH': '436862.556713039150916751',
#                              'totalLiquidityToken': '436862.556713039150916751',
#                              'totalLiquidityUSD': '1163886393.310889934392763748586212'},
#                             {'dailyVolumeETH': '60756.22498921313731481803374010681',
#                              'dailyVolumeToken': '79660.399267628339540942',
#                              'dailyVolumeUSD': '214906648.5417446883950254987645793',
#                              'date': 1646352000,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19055',
#                              'priceUSD': '2616.684164757733076032677855462189',
#                              'totalLiquidityETH': '437831.534808566879362528',
#                              'totalLiquidityToken': '437831.534808566879362528',
#                              'totalLiquidityUSD': '1145666843.965151160417429280868944'},
#                             {'dailyVolumeETH': '50298.19597958229259948225749331704',
#                              'dailyVolumeToken': '65187.254645203704853018',
#                              'dailyVolumeUSD': '187699527.2407972216725910372428267',
#                              'date': 1646265600,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19054',
#                              'priceUSD': '2838.887005369340907861306871796618',
#                              'totalLiquidityETH': '435011.45723491635936686',
#                              'totalLiquidityToken': '435011.45723491635936686',
#                              'totalLiquidityUSD': '1234948373.130984811413702959318688'},
#                             {'dailyVolumeETH': '50651.25112280831838986040885330094',
#                              'dailyVolumeToken': '66237.108964131341965646',
#                              'dailyVolumeUSD': '196722202.7192280547186268981474668',
#                              'date': 1646179200,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19053',
#                              'priceUSD': '2955.820541972655690335340965458842',
#                              'totalLiquidityETH': '434839.027556635744085857',
#                              'totalLiquidityToken': '434839.027556635744085857',
#                              'totalLiquidityUSD': '1285306130.103317627756643281251156'},
#                             {'dailyVolumeETH': '59647.00694794202684680569639478596',
#                              'dailyVolumeToken': '70581.816797417603260727',
#                              'dailyVolumeUSD': '207530902.3141951247018829703663061',
#                              'date': 1646092800,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19052',
#                              'priceUSD': '2971.195971297871998317403002248157',
#                              'totalLiquidityETH': '433804.764265154554313265',
#                              'totalLiquidityToken': '433804.764265154554313265',
#                              'totalLiquidityUSD': '1288918967.914450279479145163294721'},
#                             {'dailyVolumeETH': '52280.94004527818834351659303146932',
#                              'dailyVolumeToken': '66887.313779195932389132',
#                              'dailyVolumeUSD': '181869043.9779808987761658581729565',
#                              'date': 1646006400,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19051',
#                              'priceUSD': '2917.548911648414150359093333510423',
#                              'totalLiquidityETH': '436053.181244591160267399',
#                              'totalLiquidityToken': '436053.181244591160267399',
#                              'totalLiquidityUSD': '1272206484.360985617306467730975733'},
#                             {'dailyVolumeETH': '47813.8130552438936358309083485612',
#                              'dailyVolumeToken': '61895.421693636281782262',
#                              'dailyVolumeUSD': '167997744.6604838204259850975000079',
#                              'date': 1645920000,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19050',
#                              'priceUSD': '2619.376803151089610093503111217635',
#                              'totalLiquidityETH': '440633.48918835631296998',
#                              'totalLiquidityToken': '440633.48918835631296998',
#                              'totalLiquidityUSD': '1154185140.271506965967782221387406'},
#                             {'dailyVolumeETH': '70277.08416508716804463879565494217',
#                              'dailyVolumeToken': '59294.609497792465057356',
#                              'dailyVolumeUSD': '165638912.1884735240404272137403269',
#                              'date': 1645833600,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19049',
#                              'priceUSD': '2775.267080477271900643574419613055',
#                              'totalLiquidityETH': '438699.097593944793915105',
#                              'totalLiquidityToken': '438699.097593944793915105',
#                              'totalLiquidityUSD': '1217507163.787560946009258198649165'}]}}

# %% [markdown]
# EXAMPLE: 2022/06/01 timestamp: 1654041600
# <br>DAI
# <br>
# {'dailyVolumeETH': '13052405201.72978201978725444517328',
#                              'dailyVolumeToken': '4134944.732638395018173245',
#                              **'dailyVolumeUSD': '4136483.377571504628199639668034694'**,
#                              'date': 1654041600,
#                              'id': '0x6b175474e89094c44da98b954eedeac495271d0f-19144',
#                              'priceUSD': '1.000484172329567020191753518876482',
#                              'totalLiquidityETH': '36227.35302188222791706482919363885',
#                              'totalLiquidityToken': '65963489.599730641577233643',
#                              **'totalLiquidityUSD': '65995427.29615651307026032696281615'**},

# %% [markdown]
# ETH
# <br>
# {'dailyVolumeETH': '34412.09803371055370364681041352234',
#                              'dailyVolumeToken': '43803.417736487049312112',
#                              **'dailyVolumeUSD': '82393163.32937788713396196558889604'**,
#                              'date': 1654041600,
#                              'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2-19144',
#                              'priceUSD': '1821.715671919287824651620977197333',
#                              'totalLiquidityETH': '343608.778666151955888966',
#                              'totalLiquidityToken': '343608.778666151955888966',
#                              **'totalLiquidityUSD': '625957497.1051748619814372402967176'**},

# %% [markdown]
# The result is consistent with https://v2.info.uniswap.org/token/0x6b175474e89094c44da98b954eedeac495271d0f
# <br> Note: it is daily aggregated, not 24hrs. This is what we need.

# %% [markdown]
# TODO: MANUALLY COMPUTE THE VOLUME from transactions (**directional**)

# %% [markdown]
# # Get Transactions (Delete, this method get union, not intersection of pairs).

# %%
# UNI/ETH: 0xd3d2e2692501a5c9ca623199d38826e513033a17
# ETH/DAI: 0xa478c2975ab1ea89e8196811f51a7b7ade33eb11
allPairs = [
 "0xd3d2e2692501a5c9ca623199d38826e513033a17",
 "0xa478c2975ab1ea89e8196811f51a7b7ade33eb11"
]

params_all_pair = {"allPairs": allPairs}

get_transactions_query = """
query($allPairs: [String!]) {
 swaps(first: 30, where: { pair_in: $allPairs }, orderBy: timestamp, orderDirection: desc) {
   transaction {
     id
     timestamp
   }
   amount0In
   amount0Out
   amount1In
   amount1Out
   amountUSD
   to
 }
}
"""
get_transactions = run_query_var(get_transactions_query, params_all_pair)

pprint(get_transactions)
# Out:
# {'data': {'swaps': [{'amount0In': '0',
#                      'amount0Out': '36.007498224129839742',
#                      'amount1In': '0.019825',
#                      'amount1Out': '0',
#                      'amountUSD': '36.03492556586208485191520893313049',
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0xf7ac34f2bf88f65b3ce558716d60e4d2cc7fe4cf505fd3017500d7262e72aac7',
#                                      'timestamp': '1654461033'}},
#                     {'amount0In': '0',
#                      'amount0Out': '354.931347289669836673',
#                      'amount1In': '0.195409138876524511',
#                      'amount1Out': '0',
#                      'amountUSD': '355.1312871180965740396489984356085',
#                      'to': '0xec54859519293b8784bc5bf28144166f313618af',
#                      'transaction': {'id': '0x53980dfd18ecad4c60345322cb84e2b2c34f25b152126977550c126b37ab788c',
#                                      'timestamp': '1654460845'}},
#                     {'amount0In': '4790.44345909039409058',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '2.622949364890621723',
#                      'amountUSD': '4779.796132172058047501561207637444',
#                      'to': '0xdef1c0ded9bec7f1a1670819833240f027b25eff',
#                      'transaction': {'id': '0x61a4daf7b14902db1ad8729b983691b22269e6b80721dbfb22e61ec4f03f4798',
#                                      'timestamp': '1654460577'}},
#                     {'amount0In': '0',
#                      'amount0Out': '295.396180421857909533',
#                      'amount1In': '0.162799972215088971',
#                      'amount1Out': '0',
#                      'amountUSD': '295.8075933225466267969736572721116',
#                      'to': '0xec54859519293b8784bc5bf28144166f313618af',
#                      'transaction': {'id': '0x500f68039ea2362292d22c892efeb66babca1708ff5c0d31648c335a982bf058',
#                                      'timestamp': '1654460355'}},
#                     {'amount0In': '344.173755842433073767',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.188547151530116733',
#                      'amountUSD': '343.6097077357542043446845381683437',
#                      'to': '0xe016669dfdbf5518e7f661d7ec7d8a10cea4b4ac',
#                      'transaction': {'id': '0x1744c81190f414f6ee65ecde28b49a70fe63f78f4b407d487d4f38cca023ebea',
#                                      'timestamp': '1654460167'}},
#                     {'amount0In': '0',
#                      'amount0Out': '100.20066813402564913',
#                      'amount1In': '0.055224875663822134',
#                      'amount1Out': '0',
#                      'amountUSD': '100.3456102800553137327752033067317',
#                      'to': '0x08555ed358364e1ca9c4f8a9fb45221566296ad7',
#                      'transaction': {'id': '0xfb6ae7b9bb34e28a20323874f146e1958c245710761b465a6d358074840bdb11',
#                                      'timestamp': '1654460154'}},
#                     {'amount0In': '19.486843547227178464',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.055224875663822134',
#                      'amountUSD': '100.4959393574177639252901403679348',
#                      'to': '0xa478c2975ab1ea89e8196811f51a7b7ade33eb11',
#                      'transaction': {'id': '0xfb6ae7b9bb34e28a20323874f146e1958c245710761b465a6d358074840bdb11',
#                                      'timestamp': '1654460154'}},
#                     {'amount0In': '511.974095096108694644',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.280493740889818944',
#                      'amountUSD': '511.183631859790313156716485711525',
#                      'to': '0x4c6ac1f246513327d469a0a03e2ae1357bfe5664',
#                      'transaction': {'id': '0x8cd31562d81e6e2201f67cc659d412e85e568cef25b06ed281e1f13bfcc6865d',
#                                      'timestamp': '1654460108'}},
#                     {'amount0In': '0',
#                      'amount0Out': '1633.106211130993182035',
#                      'amount1In': '0.9',
#                      'amount1Out': '0',
#                      'amountUSD': '1635.229595851159318080285560501264',
#                      'to': '0xec54859519293b8784bc5bf28144166f313618af',
#                      'transaction': {'id': '0x25cc506da1de3f0dbe21e69e8e205e385aa14898d3fc9c27efabe2190af54f95',
#                                      'timestamp': '1654459735'}},
#                     {'amount0In': '2579.443450378635761502',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '1.4131624163025771',
#                      'amountUSD': '2575.379428218202116506220317353884',
#                      'to': '0x68b3465833fb72a70ecdf485e0e4c7bd8665fc45',
#                      'transaction': {'id': '0x44a700fe5f430f13f222d41712a77d5b6021a8d06b260168d0a596a41f51a299',
#                                      'timestamp': '1654459674'}},
#                     {'amount0In': '5423.326515543471985384',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '2.973956829673856239',
#                      'amountUSD': '5419.036204374726470346151201371885',
#                      'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#                      'transaction': {'id': '0xb2396e88ae4f7fb6aa7f503907661e646cabc0b6b5ae3a3309cd5228cea97019',
#                                      'timestamp': '1654459602'}},
#                     {'amount0In': '0',
#                      'amount0Out': '3101.167802894943939978',
#                      'amount1In': '1.711274066970850362',
#                      'amount1Out': '0',
#                      'amountUSD': '3109.808986977248085562615925722108',
#                      'to': '0xd80f4c37f876aa0a0c20d1e6c87cb8527e22595e',
#                      'transaction': {'id': '0xee2b8c2da10356d1e1975d3e97997960aab9a1c9a2f2499a9cde642df3751e43',
#                                      'timestamp': '1654458533'}},
#                     {'amount0In': '0',
#                      'amount0Out': '5588.384873763332005413',
#                      'amount1In': '15.889431700031935081',
#                      'amount1Out': '0',
#                      'amountUSD': '28907.98343324602142573239504897496',
#                      'to': '0x56178a0d5f301baf6cf3e1cd53d9863437345bf9',
#                      'transaction': {'id': '0xb2eac8f574d33a471572ec31d8c9140a259d010b15e92dbce81fc6bd5098d581',
#                                      'timestamp': '1654458451'}},
#                     {'amount0In': '0',
#                      'amount0Out': '0.179698812663128759',
#                      'amount1In': '0.000099125',
#                      'amount1Out': '0',
#                      'amountUSD': '0.1801104854328935488681575762290525',
#                      'to': '0x74de5d4fcbf63e00296fd95d33236b9794016631',
#                      'transaction': {'id': '0xc7a2f4232994423f33ca3fc6bdf33cdecc322098e524608cb6f50503f2388ab6',
#                                      'timestamp': '1654458159'}},
#                     {'amount0In': '400',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '1.127652748381061972',
#                      'amountUSD': '2052.027169674744101822091655894599',
#                      'to': '0x68b3465833fb72a70ecdf485e0e4c7bd8665fc45',
#                      'transaction': {'id': '0x985963acff2eea2d2a4a2176f1656bc62e21e04defa906d0f1cc7a463c7a0afb',
#                                      'timestamp': '1654458133'}},
#                     {'amount0In': '0',
#                      'amount0Out': '2321.551080111886928844',
#                      'amount1In': '6.568905330541213949',
#                      'amount1Out': '0',
#                      'amountUSD': '11956.45470158517373797526136444951',
#                      'to': '0xf07704777d6bc182bf2c67fbda48913169b84983',
#                      'transaction': {'id': '0x35734b2c1815d10677da2a9bac5adf9e05f204c4f27023b5d22df91d661d6d56',
#                                      'timestamp': '1654457411'}},
#                     {'amount0In': '0',
#                      'amount0Out': '1427.186499674152484595',
#                      'amount1In': '4.045645604404394773',
#                      'amount1Out': '0',
#                      'amountUSD': '7363.719824493645102357471557977053',
#                      'to': '0x56178a0d5f301baf6cf3e1cd53d9863437345bf9',
#                      'transaction': {'id': '0x2d2e6f6617c73fa5bcebc2f9eab4d0b648c586a0a505e754256731cf8f29a4f6',
#                                      'timestamp': '1654457411'}},
#                     {'amount0In': '4498.581744658173547971',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '2.467917664867550194',
#                      'amountUSD': '4496.457268820059224508137376425842',
#                      'to': '0x7a250d5630b4cf539739df2c5dacb4c659f2488d',
#                      'transaction': {'id': '0x68b1540f54fa6437b8b9506a70ab28564b8fe3e6f80a3dd4fdfb51760ca809a3',
#                                      'timestamp': '1654457090'}},
#                     {'amount0In': '820.508320060053064492',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.450407360587974794',
#                      'amountUSD': '820.794883971669035524916729825174',
#                      'to': '0x68b3465833fb72a70ecdf485e0e4c7bd8665fc45',
#                      'transaction': {'id': '0x6daa626ae906d521933cd28a3657e4592ff88a7e2d2a2f25e588e5231f0048db',
#                                      'timestamp': '1654456672'}},
#                     {'amount0In': '0',
#                      'amount0Out': '144.851798968071409121',
#                      'amount1In': '0.08',
#                      'amount1Out': '0',
#                      'amountUSD': '145.390703823863726704797752623962',
#                      'to': '0x231b7589426ffe1b75405526fc32ac09d44364c4',
#                      'transaction': {'id': '0x6a3a332dc059dbc65603ab627693729d3949efc7f9a208a5a3f202323338b8e2',
#                                      'timestamp': '1654455913'}},
#                     {'amount0In': '0',
#                      'amount0Out': '3780.147959097369407708',
#                      'amount1In': '10.664377448553036983',
#                      'amount1Out': '0',
#                      'amountUSD': '19408.82787374653352173517032133226',
#                      'to': '0x56178a0d5f301baf6cf3e1cd53d9863437345bf9',
#                      'transaction': {'id': '0xcb080182d04ff296ed8b0f3f82e8d29fcdf31ce20371206f0caf7621a2936602',
#                                      'timestamp': '1654455541'}},
#                     {'amount0In': '0',
#                      'amount0Out': '4067.179386823836201838',
#                      'amount1In': '2.245155753691552653',
#                      'amount1Out': '0',
#                      'amountUSD': '4080.420420551814997193197857184352',
#                      'to': '0xf22a82c4420676149af48cdc0af6abbc70bd9409',
#                      'transaction': {'id': '0x001e5de1a06a83a1461bef72e0d8591100eb556e0aa4fd3a5f0e98475352d1e0',
#                                      'timestamp': '1654454694'}},
#                     {'amount0In': '0',
#                      'amount0Out': '3780.102561034651548662',
#                      'amount1In': '2.084782068750701639',
#                      'amount1Out': '0',
#                      'amountUSD': '3789.233685163546762838340167148754',
#                      'to': '0xf22a82c4420676149af48cdc0af6abbc70bd9409',
#                      'transaction': {'id': '0x66f580b6f7e1bd119211551d4b2ac057abc0dc77a3befaae07c0914608813acd',
#                                      'timestamp': '1654454370'}},
#                     {'amount0In': '0',
#                      'amount0Out': '665.953932076181053935',
#                      'amount1In': '0.36709388630369201',
#                      'amount1Out': '0',
#                      'amountUSD': '667.2748565329330533013844473625625',
#                      'to': '0xec54859519293b8784bc5bf28144166f313618af',
#                      'transaction': {'id': '0x84c0bd32adc1e01c176e782f22643d441083cb8350a669f9e75953c8e1c6107c',
#                                      'timestamp': '1654454074'}},
#                     {'amount0In': '11457.370083054',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '6.285678882705540186',
#                      'amountUSD': '11453.55214651518701266947690000856',
#                      'to': '0x220bda5c8994804ac96ebe4df184d25e5c2196d4',
#                      'transaction': {'id': '0x0fadefba469ef31caab660601976aafcd4bdb1c48a45b6567c8bea21d2cdd6a3',
#                                      'timestamp': '1654453650'}},
#                     {'amount0In': '15634.3925659346665472',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '8.61059945473771008',
#                      'amountUSD': '15682.61374748045098164033276048188',
#                      'to': '0xb23dc3f00856288cd7b6bde5d06159f01b75aa4c',
#                      'transaction': {'id': '0x875a4cc9299ceb18248b6bf0c2d8091ef906ef06e7882742e810c66f8b41ba92',
#                                      'timestamp': '1654453611'}},
#                     {'amount0In': '3216.979820378501785941',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '1.767883575265491615',
#                      'amountUSD': '3222.359276135075844697839571752378',
#                      'to': '0x56178a0d5f301baf6cf3e1cd53d9863437345bf9',
#                      'transaction': {'id': '0x79bd8135acd2cfccdd29716d3980de1eeaa6f5f1ef3f611f4dbbba895893aab5',
#                                      'timestamp': '1654453611'}},
#                     {'amount0In': '0',
#                      'amount0Out': '18329.204090476288251263',
#                      'amount1In': '10.152404341728688841',
#                      'amount1Out': '0',
#                      'amountUSD': '18466.80267288425495533845165943563',
#                      'to': '0xf22a82c4420676149af48cdc0af6abbc70bd9409',
#                      'transaction': {'id': '0x1f1a7d7b7903c4478c39d9c290e34f6ce9aed93bcf6ab11976b3aa3a08f9c938',
#                                      'timestamp': '1654453609'}},
#                     {'amount0In': '0',
#                      'amount0Out': '30508.825808645610933011',
#                      'amount1In': '16.802906802',
#                      'amount1Out': '0',
#                      'amountUSD': '30615.48510077665132896010841456656',
#                      'to': '0x220bda5c8994804ac96ebe4df184d25e5c2196d4',
#                      'transaction': {'id': '0x09139e059b8ed203fd574e156f80ce5a5d716f9b7172900678aeead0d78d5ee4',
#                                      'timestamp': '1654453178'}},
#                     {'amount0In': '500',
#                      'amount0Out': '0',
#                      'amount1In': '0',
#                      'amount1Out': '0.272777263984895498',
#                      'amountUSD': '497.8631699147114669940486514637154',
#                      'to': '0x974bfcc7b25f979950b58ce0cf8d9c621a9c771e',
#                      'transaction': {'id': '0x84ffd094ed0c4930ac7dfcb1129d9a8a7b869e4629d9732f1c38d5f1bcd2f9ab',
#                                      'timestamp': '1654453080'}}]}}

# %% [markdown]
# # TODO

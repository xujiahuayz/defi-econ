# %%
# Load packages
import pandas as pd
import plotly.graph_objects as go
import environ.process.paneleventstudy as es

# %%
# Preliminaries
df = pd.read_stata('https://github.com/scunning1975/mixtape/raw/master/baker.dta')  # from scott cunningham's Mixtape
col_bareminimum = ['id', 'year', 'treat', 'y']  # the sort of data one starts working with in a panel event study setup
df = df[col_bareminimum].reset_index(drop=True)  # reset index
df.head(20)
# Out:
#      id    year  treat           y
# 0   1.0  1980.0    0.0    1.304093
# 1   1.0  1981.0    0.0    2.123511
# 2   1.0  1982.0    0.0    3.631350
# 3   1.0  1983.0    0.0    4.147669
# 4   1.0  1984.0    0.0    5.160839
# 5   1.0  1985.0    0.0    6.674791
# 6   1.0  1986.0    1.0   17.439356
# 7   1.0  1987.0    1.0   28.549910
# 8   1.0  1988.0    1.0   39.314747
# 9   1.0  1989.0    1.0   50.054157
# 10  1.0  1990.0    1.0   61.278870
# 11  1.0  1991.0    1.0   72.516876
# 12  1.0  1992.0    1.0   83.287231
# 13  1.0  1993.0    1.0   93.911530
# 14  1.0  1994.0    1.0  104.589211
# 15  1.0  1995.0    1.0  116.368408
# 16  1.0  1996.0    1.0  128.140823
# 17  1.0  1997.0    1.0  137.801559
# 18  1.0  1998.0    1.0  149.304550
# 19  1.0  1999.0    1.0  160.659348

# %%
# Check if input data is a balanced panel
check_balancepanel = es.balancepanel(
    data=df,
    group='id',
    event='treat',
    calendartime='year'
)
if check_balancepanel:
    print('Panel is balanced! Proceed.')
elif not check_balancepanel:
    raise NotImplementedError('Panel is not balanced! Pls fix tqvm.')
# Out:
# Checking if the largest calendartime is the same for all groups (ONLY for datetime/int)
# Every group has the same maximum calendartime value
# Panel is balanced! Proceed.

# %%
# Flag control groups (generate new column: control_group)
df = es.identifycontrols(
    data=df,
    group='id',
    event='treat'
) 
df.tail(60)
# Out:
# Identifying control groups: never-treated, or last-treated
# Generates new indicator column: control_group
# Finding never-treated groups
# No never-treated groups exist, proceeding to find last-treated groups
#            id    year  treat          y  control_group
# 29940   999.0  1980.0    0.0   6.119809              1
# 29941   999.0  1981.0    0.0   6.700324              1
# 29942   999.0  1982.0    0.0   7.909371              1
# 29943   999.0  1983.0    0.0   8.723755              1
# 29944   999.0  1984.0    0.0   9.559460              1
# 29945   999.0  1985.0    0.0  10.973372              1
# 29946   999.0  1986.0    0.0  11.693465              1
# 29947   999.0  1987.0    0.0  12.935276              1
# 29948   999.0  1988.0    0.0  13.669438              1
# 29949   999.0  1989.0    0.0  14.822352              1
# 29950   999.0  1990.0    0.0  15.549471              1
# 29951   999.0  1991.0    0.0  16.814754              1
# 29952   999.0  1992.0    0.0  17.819540              1
# 29953   999.0  1993.0    0.0  18.703033              1
# 29954   999.0  1994.0    0.0  19.876335              1
# 29955   999.0  1995.0    0.0  20.504427              1
# 29956   999.0  1996.0    0.0  21.390776              1
# 29957   999.0  1997.0    0.0  23.185663              1
# 29958   999.0  1998.0    0.0  23.901649              1
# 29959   999.0  1999.0    0.0  24.725082              1
# 29960   999.0  2000.0    0.0  25.682421              1
# 29961   999.0  2001.0    0.0  26.657524              1
# 29962   999.0  2002.0    0.0  27.861328              1
# 29963   999.0  2003.0    0.0  28.688221              1
# 29964   999.0  2004.0    1.0  33.664452              1
# 29965   999.0  2005.0    1.0  38.967655              1
# 29966   999.0  2006.0    1.0  43.622398              1
# 29967   999.0  2007.0    1.0  48.338825              1
# 29968   999.0  2008.0    1.0  53.404789              1
# 29969   999.0  2009.0    1.0  58.847652              1
# 29970  1000.0  1980.0    0.0   5.664930              1
# 29971  1000.0  1981.0    0.0   6.977693              1
# 29972  1000.0  1982.0    0.0   7.459760              1
# 29973  1000.0  1983.0    0.0   8.670273              1
# 29974  1000.0  1984.0    0.0   9.857766              1
# 29975  1000.0  1985.0    0.0  11.094162              1
# 29976  1000.0  1986.0    0.0  11.361883              1
# 29977  1000.0  1987.0    0.0  12.775704              1
# 29978  1000.0  1988.0    0.0  13.906816              1
# 29979  1000.0  1989.0    0.0  15.102684              1
# 29980  1000.0  1990.0    0.0  15.830532              1
# 29981  1000.0  1991.0    0.0  16.760887              1
# 29982  1000.0  1992.0    0.0  17.589407              1
# 29983  1000.0  1993.0    0.0  18.671410              1
# 29984  1000.0  1994.0    0.0  19.744101              1
# 29985  1000.0  1995.0    0.0  21.275421              1
# 29986  1000.0  1996.0    0.0  22.344030              1
# 29987  1000.0  1997.0    0.0  22.764954              1
# 29988  1000.0  1998.0    0.0  23.971224              1
# 29989  1000.0  1999.0    0.0  24.755575              1
# 29990  1000.0  2000.0    0.0  25.791355              1
# 29991  1000.0  2001.0    0.0  26.775213              1
# 29992  1000.0  2002.0    0.0  28.304686              1
# 29993  1000.0  2003.0    0.0  28.794245              1
# 29994  1000.0  2004.0    1.0  33.674152              1
# 29995  1000.0  2005.0    1.0  39.012615              1
# 29996  1000.0  2006.0    1.0  43.599167              1
# 29997  1000.0  2007.0    1.0  48.928181              1
# 29998  1000.0  2008.0    1.0  53.819950              1
# 29999  1000.0  2009.0    1.0  58.302917              1

# %%
# Generates relative time column called 'reltime'
df = es.genreltime(
    data=df,
    group='id',
    event='treat',
    calendartime='year',
    reltime='reltime',
    check_balance=True
)  
df.head(60)
# Out:
# Generating relative time columns from event column; time0 = when treatment is applied
# To generalise, calendartime's format will be ignored
# PLEASE ensure that calendartime is ascending without gaps, i.e., T-k, T-k+1, ..., T, ..., T+k
# Input dataframe must be a BALANCED PANEL
# Relative time will be stored in reltime
# NOT checking min and max of calendartime by groups
# Quick check indicates panel is balanced
# All groups without events have reltime filled with 0
#      id    year  treat           y  control_group  reltime
# 0   1.0  1980.0    0.0    1.304093              0       -6
# 1   1.0  1981.0    0.0    2.123511              0       -5
# 2   1.0  1982.0    0.0    3.631350              0       -4
# 3   1.0  1983.0    0.0    4.147669              0       -3
# 4   1.0  1984.0    0.0    5.160839              0       -2
# 5   1.0  1985.0    0.0    6.674791              0       -1
# 6   1.0  1986.0    1.0   17.439356              0        0
# 7   1.0  1987.0    1.0   28.549910              0        1
# 8   1.0  1988.0    1.0   39.314747              0        2
# 9   1.0  1989.0    1.0   50.054157              0        3
# 10  1.0  1990.0    1.0   61.278870              0        4
# 11  1.0  1991.0    1.0   72.516876              0        5
# 12  1.0  1992.0    1.0   83.287231              0        6
# 13  1.0  1993.0    1.0   93.911530              0        7
# 14  1.0  1994.0    1.0  104.589211              0        8
# 15  1.0  1995.0    1.0  116.368408              0        9
# 16  1.0  1996.0    1.0  128.140823              0       10
# 17  1.0  1997.0    1.0  137.801559              0       11
# 18  1.0  1998.0    1.0  149.304550              0       12
# 19  1.0  1999.0    1.0  160.659348              0       13
# 20  1.0  2000.0    1.0  171.741776              0       14
# 21  1.0  2001.0    1.0  183.885910              0       15
# 22  1.0  2002.0    1.0  192.792908              0       16
# 23  1.0  2003.0    1.0  204.044724              0       17
# 24  1.0  2004.0    1.0  216.183838              0       18
# 25  1.0  2005.0    1.0  227.138306              0       19
# 26  1.0  2006.0    1.0  238.394150              0       20
# 27  1.0  2007.0    1.0  247.892365              0       21
# 28  1.0  2008.0    1.0  260.076599              0       22
# 29  1.0  2009.0    1.0  271.144257              0       23
# 30  2.0  1980.0    0.0    2.074750              0       -6
# 31  2.0  1981.0    0.0    3.214949              0       -5
# 32  2.0  1982.0    0.0    3.640276              0       -4
# 33  2.0  1983.0    0.0    4.774337              0       -3
# 34  2.0  1984.0    0.0    5.728327              0       -2
# 35  2.0  1985.0    0.0    7.056790              0       -1
# 36  2.0  1986.0    1.0   17.752865              0        0
# 37  2.0  1987.0    1.0   28.536259              0        1
# 38  2.0  1988.0    1.0   39.885017              0        2
# 39  2.0  1989.0    1.0   50.843113              0        3
# 40  2.0  1990.0    1.0   62.315689              0        4
# 41  2.0  1991.0    1.0   73.297295              0        5
# 42  2.0  1992.0    1.0   83.941483              0        6
# 43  2.0  1993.0    1.0   95.427315              0        7
# 44  2.0  1994.0    1.0  105.429024              0        8
# 45  2.0  1995.0    1.0  117.483879              0        9
# 46  2.0  1996.0    1.0  127.859840              0       10
# 47  2.0  1997.0    1.0  138.686523              0       11
# 48  2.0  1998.0    1.0  149.706345              0       12
# 49  2.0  1999.0    1.0  161.417755              0       13
# 50  2.0  2000.0    1.0  170.952667              0       14
# 51  2.0  2001.0    1.0  182.305878              0       15
# 52  2.0  2002.0    1.0  193.780594              0       16
# 53  2.0  2003.0    1.0  203.964905              0       17
# 54  2.0  2004.0    1.0  214.876984              0       18
# 55  2.0  2005.0    1.0  226.616608              0       19
# 56  2.0  2006.0    1.0  237.005875              0       20
# 57  2.0  2007.0    1.0  249.400986              0       21
# 58  2.0  2008.0    1.0  260.653534              0       22
# 59  2.0  2009.0    1.0  271.670990              0       23

# %%
# Generates cohort column called 'cohort'
df = es.gencohort(
    data=df,
    group='id',
    event='treat',
    calendartime='year',
    cohort='cohort',
    check_balance=True
) 
df.head(60)
# Out:
# Generating cohort indicators
# To generalise, calendartime's format will be ignored
# PLEASE ensure that calendartime is ascending without gaps, i.e., T-k, T-k+1, ..., T, ..., T+k
# Input dataframe must be a BALANCED PANEL
# Cohort indicators will be stored in cohort
# NOT checking min and max of calendartime by groups
# Quick check indicates panel is balanced
# All groups without events have cohort filled with -1
#      id    year  treat           y  control_group  reltime  cohort
# 0   1.0  1980.0    0.0    1.304093              0       -6       6
# 1   1.0  1981.0    0.0    2.123511              0       -5       6
# 2   1.0  1982.0    0.0    3.631350              0       -4       6
# 3   1.0  1983.0    0.0    4.147669              0       -3       6
# 4   1.0  1984.0    0.0    5.160839              0       -2       6
# 5   1.0  1985.0    0.0    6.674791              0       -1       6
# 6   1.0  1986.0    1.0   17.439356              0        0       6
# 7   1.0  1987.0    1.0   28.549910              0        1       6
# 8   1.0  1988.0    1.0   39.314747              0        2       6
# 9   1.0  1989.0    1.0   50.054157              0        3       6
# 10  1.0  1990.0    1.0   61.278870              0        4       6
# 11  1.0  1991.0    1.0   72.516876              0        5       6
# 12  1.0  1992.0    1.0   83.287231              0        6       6
# 13  1.0  1993.0    1.0   93.911530              0        7       6
# 14  1.0  1994.0    1.0  104.589211              0        8       6
# 15  1.0  1995.0    1.0  116.368408              0        9       6
# 16  1.0  1996.0    1.0  128.140823              0       10       6
# 17  1.0  1997.0    1.0  137.801559              0       11       6
# 18  1.0  1998.0    1.0  149.304550              0       12       6
# 19  1.0  1999.0    1.0  160.659348              0       13       6
# 20  1.0  2000.0    1.0  171.741776              0       14       6
# 21  1.0  2001.0    1.0  183.885910              0       15       6
# 22  1.0  2002.0    1.0  192.792908              0       16       6
# 23  1.0  2003.0    1.0  204.044724              0       17       6
# 24  1.0  2004.0    1.0  216.183838              0       18       6
# 25  1.0  2005.0    1.0  227.138306              0       19       6
# 26  1.0  2006.0    1.0  238.394150              0       20       6
# 27  1.0  2007.0    1.0  247.892365              0       21       6
# 28  1.0  2008.0    1.0  260.076599              0       22       6
# 29  1.0  2009.0    1.0  271.144257              0       23       6
# 30  2.0  1980.0    0.0    2.074750              0       -6       6
# 31  2.0  1981.0    0.0    3.214949              0       -5       6
# 32  2.0  1982.0    0.0    3.640276              0       -4       6
# 33  2.0  1983.0    0.0    4.774337              0       -3       6
# 34  2.0  1984.0    0.0    5.728327              0       -2       6
# 35  2.0  1985.0    0.0    7.056790              0       -1       6
# 36  2.0  1986.0    1.0   17.752865              0        0       6
# 37  2.0  1987.0    1.0   28.536259              0        1       6
# 38  2.0  1988.0    1.0   39.885017              0        2       6
# 39  2.0  1989.0    1.0   50.843113              0        3       6
# 40  2.0  1990.0    1.0   62.315689              0        4       6
# 41  2.0  1991.0    1.0   73.297295              0        5       6
# 42  2.0  1992.0    1.0   83.941483              0        6       6
# 43  2.0  1993.0    1.0   95.427315              0        7       6
# 44  2.0  1994.0    1.0  105.429024              0        8       6
# 45  2.0  1995.0    1.0  117.483879              0        9       6
# 46  2.0  1996.0    1.0  127.859840              0       10       6
# 47  2.0  1997.0    1.0  138.686523              0       11       6
# 48  2.0  1998.0    1.0  149.706345              0       12       6
# 49  2.0  1999.0    1.0  161.417755              0       13       6
# 50  2.0  2000.0    1.0  170.952667              0       14       6
# 51  2.0  2001.0    1.0  182.305878              0       15       6
# 52  2.0  2002.0    1.0  193.780594              0       16       6
# 53  2.0  2003.0    1.0  203.964905              0       17       6
# 54  2.0  2004.0    1.0  214.876984              0       18       6
# 55  2.0  2005.0    1.0  226.616608              0       19       6
# 56  2.0  2006.0    1.0  237.005875              0       20       6
# 57  2.0  2007.0    1.0  249.400986              0       21       6
# 58  2.0  2008.0    1.0  260.653534              0       22       6
# 59  2.0  2009.0    1.0  271.670990              0       23       6

# %%
# Generates a new column called 'ct' containing the numerics version of calendar time 'year'
df = es.gencalendartime_numerics(
    data=df,
    group='id',
    event='treat',
    calendartime='year',
    calendartime_numerics='ct'
)  
df.head(60)
# Out:
# Generating numerics calendar time from 0 to T (end of time)
# Intended to make calling PanelOLS dependencies later easier by bypassing the datetime requirement
# PLEASE ensure that calendartime is ascending without gaps, i.e., T-k, T-k+1, ..., T, ..., T+k
# Input dataframe must be a BALANCED PANEL
# NOT checking min and max of calendartime by groups
# Quick check indicates panel is balanced
#      id    year  treat           y  control_group  reltime  cohort  ct
# 0   1.0  1980.0    0.0    1.304093              0       -6       6   0
# 1   1.0  1981.0    0.0    2.123511              0       -5       6   1
# 2   1.0  1982.0    0.0    3.631350              0       -4       6   2
# 3   1.0  1983.0    0.0    4.147669              0       -3       6   3
# 4   1.0  1984.0    0.0    5.160839              0       -2       6   4
# 5   1.0  1985.0    0.0    6.674791              0       -1       6   5
# 6   1.0  1986.0    1.0   17.439356              0        0       6   6
# 7   1.0  1987.0    1.0   28.549910              0        1       6   7
# 8   1.0  1988.0    1.0   39.314747              0        2       6   8
# 9   1.0  1989.0    1.0   50.054157              0        3       6   9
# 10  1.0  1990.0    1.0   61.278870              0        4       6  10
# 11  1.0  1991.0    1.0   72.516876              0        5       6  11
# 12  1.0  1992.0    1.0   83.287231              0        6       6  12
# 13  1.0  1993.0    1.0   93.911530              0        7       6  13
# 14  1.0  1994.0    1.0  104.589211              0        8       6  14
# 15  1.0  1995.0    1.0  116.368408              0        9       6  15
# 16  1.0  1996.0    1.0  128.140823              0       10       6  16
# 17  1.0  1997.0    1.0  137.801559              0       11       6  17
# 18  1.0  1998.0    1.0  149.304550              0       12       6  18
# 19  1.0  1999.0    1.0  160.659348              0       13       6  19
# 20  1.0  2000.0    1.0  171.741776              0       14       6  20
# 21  1.0  2001.0    1.0  183.885910              0       15       6  21
# 22  1.0  2002.0    1.0  192.792908              0       16       6  22
# 23  1.0  2003.0    1.0  204.044724              0       17       6  23
# 24  1.0  2004.0    1.0  216.183838              0       18       6  24
# 25  1.0  2005.0    1.0  227.138306              0       19       6  25
# 26  1.0  2006.0    1.0  238.394150              0       20       6  26
# 27  1.0  2007.0    1.0  247.892365              0       21       6  27
# 28  1.0  2008.0    1.0  260.076599              0       22       6  28
# 29  1.0  2009.0    1.0  271.144257              0       23       6  29
# 30  2.0  1980.0    0.0    2.074750              0       -6       6   0
# 31  2.0  1981.0    0.0    3.214949              0       -5       6   1
# 32  2.0  1982.0    0.0    3.640276              0       -4       6   2
# 33  2.0  1983.0    0.0    4.774337              0       -3       6   3
# 34  2.0  1984.0    0.0    5.728327              0       -2       6   4
# 35  2.0  1985.0    0.0    7.056790              0       -1       6   5
# 36  2.0  1986.0    1.0   17.752865              0        0       6   6
# 37  2.0  1987.0    1.0   28.536259              0        1       6   7
# 38  2.0  1988.0    1.0   39.885017              0        2       6   8
# 39  2.0  1989.0    1.0   50.843113              0        3       6   9
# 40  2.0  1990.0    1.0   62.315689              0        4       6  10
# 41  2.0  1991.0    1.0   73.297295              0        5       6  11
# 42  2.0  1992.0    1.0   83.941483              0        6       6  12
# 43  2.0  1993.0    1.0   95.427315              0        7       6  13
# 44  2.0  1994.0    1.0  105.429024              0        8       6  14
# 45  2.0  1995.0    1.0  117.483879              0        9       6  15
# 46  2.0  1996.0    1.0  127.859840              0       10       6  16
# 47  2.0  1997.0    1.0  138.686523              0       11       6  17
# 48  2.0  1998.0    1.0  149.706345              0       12       6  18
# 49  2.0  1999.0    1.0  161.417755              0       13       6  19
# 50  2.0  2000.0    1.0  170.952667              0       14       6  20
# 51  2.0  2001.0    1.0  182.305878              0       15       6  21
# 52  2.0  2002.0    1.0  193.780594              0       16       6  22
# 53  2.0  2003.0    1.0  203.964905              0       17       6  23
# 54  2.0  2004.0    1.0  214.876984              0       18       6  24
# 55  2.0  2005.0    1.0  226.616608              0       19       6  25
# 56  2.0  2006.0    1.0  237.005875              0       20       6  26
# 57  2.0  2007.0    1.0  249.400986              0       21       6  27
# 58  2.0  2008.0    1.0  260.653534              0       22       6  28
# 59  2.0  2009.0    1.0  271.670990              0       23       6  29

# %%
# Estimate naive TWFE event study regression model
est_twfe = es.naivetwfe_eventstudy(
    data=df,
    outcome='y',
    event='treat',
    group='id',
    reltime='reltime',
    calendartime='ct',
    covariates=[],
    vcov_type='robust',
    check_balance=True
)
est_twfe.head(60)
# Out:
# Estimates a naive event study regression using dynamic TWFE
# Ensure that reltime is int, with -1 = one period before treatment onset
# Returns a dataframe containing the lead-lag coefficients and CIs
# NOT checking min and max of calendartime by groups
# Quick check indicates panel is balanced
# Estimating equation: y ~ 1 + C(reltime) + EntityEffects + TimeEffects
# /home/javaxu/git-projects/defi-econ/environ/process/paneleventstudy/naivetwfe_eventstudy.py:49: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# C(reltime)[T.18], C(reltime)[T.19], C(reltime)[T.20], C(reltime)[T.21], C(reltime)[T.22], C(reltime)[T.23]
#
#   res = mod.fit(cov_type=vcov_type)
#         parameter       lower       upper
# index
# -24    267.327706  266.433398  268.222014
# -23    253.322726  252.434152  254.211301
# -22    239.338570  238.454412  240.222727
# -21    225.284789  224.395103  226.174475
# -20    211.358086  210.457078  212.259093
# -19    197.283219  196.652848  197.913591
# -18    203.032623  202.232504  203.832742
# -17    188.846821  188.059537  189.634104
# -16    174.655554  173.878371  175.432736
# -15    160.415275  159.634177  161.196373
# -14    146.253858  145.461477  147.046239
# -13    131.984358  131.469992  132.498723
# -12    136.531462  135.817850  137.245074
# -11    122.438593  121.743535  123.133650
# -10    108.348278  107.669812  109.026744
# -9      94.233955   93.562443   94.905468
# -8      80.168113   79.496419   80.839808
# -7      66.004718   65.642785   66.366650
# -6      68.439789   67.864674   69.014904
# -5      54.769629   54.212914   55.326344
# -4      41.094236   40.550739   41.637733
# -3      27.378880   26.832567   27.925194
# -2      13.776852   13.216477   14.337227
# 0       11.916961   11.399165   12.434757
# 1        6.243051    5.738312    6.747790
# 2        0.565852    0.078473    1.053231
# 3       -5.148600   -5.626348   -4.670852
# 4      -10.763367  -11.234585  -10.292148
# 5      -16.513874  -16.778033  -16.249716
# 6       -4.461883   -4.824937   -4.098830
# 7       -8.534634   -8.894306   -8.174963
# 8      -12.654020  -13.004330  -12.303711
# 9      -16.772238  -17.121021  -16.423454
# 10     -20.745193  -21.094177  -20.396209
# 11     -24.986885  -25.259420  -24.714350
# 12      -8.665967   -8.988572   -8.343361
# 13     -10.866369  -11.180319  -10.552420
# 14     -12.990066  -13.285642  -12.694489
# 15     -15.254232  -15.543261  -14.965203
# 16     -17.383518  -17.667532  -17.099504
# 17     -19.643542  -19.884004  -19.403080

# %%
# Plot the estimated TWFE event study lead lag coefficients
fig_twfe = es.eventstudyplot(
    input=est_twfe,
    big_title='Naive TWFE Event Study Plot (With 95% CIs)',
    name_output='eventstudyplot_twfe'
)
fig_twfe.show('svg')
# Out:
# Takes output from est_ functions to plot event study estimates and their CIs
# Requires 3 columns: parameter, lower, and upper; indexed to relative time
# Output = plotly graph objects figure
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Plot the estimated TWFE event study lead lag coefficients
# ----> 2 fig_twfe = es.eventstudyplot(
#       3     input=est_twfe,
#       4     big_title='Naive TWFE Event Study Plot (With 95% CIs)',
#       5     name_output='eventstudyplot_twfe'
#       6 )
#       7 fig_twfe.show('svg')
#
# File ~/git-projects/defi-econ/environ/process/paneleventstudy/eventstudyplot.py:51, in eventstudyplot(input, big_title, path_output, name_output)
#      49 # Save output
#      50 fig.write_html(path_output + name_output + '.html')
# ---> 51 fig.write_image(path_output + name_output + '.png', height=768, width=1366)
#      52 # fig.show()
#      53 return fig
#
# File ~/git-projects/defi-econ/venv/lib/python3.10/site-packages/plotly/basedatatypes.py:3821, in BaseFigure.write_image(self, *args, **kwargs)
#    3761 """
#    3762 Convert a figure to a static image and write it to a file or writeable
#    3763 object
#    (...)
#    3817 None
#    3818 """
#    3819 import plotly.io as pio
# -> 3821 return pio.write_image(self, *args, **kwargs)
#
# File ~/git-projects/defi-econ/venv/lib/python3.10/site-packages/plotly/io/_kaleido.py:267, in write_image(fig, file, format, scale, width, height, validate, engine)
#     251             raise ValueError(
#     252                 """
#     253 Cannot infer image type from output path '{file}'.
#    (...)
#     261                 )
#     262             )
#     264     # Request image
#     265     # -------------
#     266     # Do this first so we don't create a file if image conversion fails
# --> 267     img_data = to_image(
#     268         fig,
#     269         format=format,
#     270         scale=scale,
#     271         width=width,
#     272         height=height,
#     273         validate=validate,
#     274         engine=engine,
#     275     )
#     277     # Open file
#     278     # ---------
#     279     if path is None:
#     280         # We previously failed to make sense of `file` as a pathlib object.
#     281         # Attempt to write to `file` as an open file descriptor.
#
# File ~/git-projects/defi-econ/venv/lib/python3.10/site-packages/plotly/io/_kaleido.py:133, in to_image(fig, format, width, height, scale, validate, engine)
#     131     # Raise informative error message if Kaleido is not installed
#     132     if scope is None:
# --> 133         raise ValueError(
#     134             """
#     135 Image export using the "kaleido" engine requires the kaleido package,
#     136 which can be installed using pip:
#     137     $ pip install -U kaleido
#     138 """
#     139         )
#     141     # Validate figure
#     142     # ---------------
#     143     fig_dict = validate_coerce_fig_to_dict(fig, validate)
#
# ValueError:
# Image export using the "kaleido" engine requires the kaleido package,
# which can be installed using pip:
#     $ pip install -U kaleido

# %%
# Estimate interaction-weighted event study regression model
est_iw = es.interactionweighted_eventstudy(
    data=df,
    outcome='y',
    event='treat',
    group='id',
    cohort='cohort',
    reltime='reltime',
    calendartime='ct',
    covariates=[],
    vcov_type='robust',
    check_balance=True
)
est_iw.head(60)
# Out:
# NOT checking min and max of calendartime by groups
# /home/javaxu/git-projects/defi-econ/environ/process/paneleventstudy/interactionweighted_eventstudy.py:88: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/javaxu/git-projects/defi-econ/environ/process/paneleventstudy/interactionweighted_eventstudy.py:88: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/javaxu/git-projects/defi-econ/environ/process/paneleventstudy/interactionweighted_eventstudy.py:88: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/javaxu/git-projects/defi-econ/environ/process/paneleventstudy/interactionweighted_eventstudy.py:201: AbsorbingEffectWarning:
#
#
# Variables have been fully absorbed and have removed from the regression:
#
# C(cohort)[T.12], C(cohort)[T.18], C(cohort)[T.24], C(reltime)[T.-24]:C(cohort)[6], C(reltime)[T.-23]:C(cohort)[6], C(reltime)[T.-22]:C(cohort)[6], C(reltime)[T.-21]:C(cohort)[6], C(reltime)[T.-20]:C(cohort)[6], C(reltime)[T.-19]:C(cohort)[6], C(reltime)[T.-18]:C(cohort)[6], C(reltime)[T.-17]:C(cohort)[6], C(reltime)[T.-16]:C(cohort)[6], C(reltime)[T.-15]:C(cohort)[6], C(reltime)[T.-14]:C(cohort)[6], C(reltime)[T.-13]:C(cohort)[6], C(reltime)[T.-12]:C(cohort)[6], C(reltime)[T.-11]:C(cohort)[6], C(reltime)[T.-10]:C(cohort)[6], C(reltime)[T.-9]:C(cohort)[6], C(reltime)[T.-8]:C(cohort)[6], C(reltime)[T.-7]:C(cohort)[6], C(reltime)[T.-24]:C(cohort)[12], C(reltime)[T.-23]:C(cohort)[12], C(reltime)[T.-22]:C(cohort)[12], C(reltime)[T.-21]:C(cohort)[12], C(reltime)[T.-20]:C(cohort)[12], C(reltime)[T.-19]:C(cohort)[12], C(reltime)[T.-18]:C(cohort)[12], C(reltime)[T.-17]:C(cohort)[12], C(reltime)[T.-16]:C(cohort)[12], C(reltime)[T.-15]:C(cohort)[12], C(reltime)[T.-14]:C(cohort)[12], C(reltime)[T.-13]:C(cohort)[12], C(reltime)[T.18]:C(cohort)[12], C(reltime)[T.19]:C(cohort)[12], C(reltime)[T.20]:C(cohort)[12], C(reltime)[T.21]:C(cohort)[12], C(reltime)[T.22]:C(cohort)[12], C(reltime)[T.23]:C(cohort)[12], C(reltime)[T.-24]:C(cohort)[18], C(reltime)[T.-23]:C(cohort)[18], C(reltime)[T.-22]:C(cohort)[18], C(reltime)[T.-21]:C(cohort)[18], C(reltime)[T.-20]:C(cohort)[18], C(reltime)[T.-19]:C(cohort)[18], C(reltime)[T.12]:C(cohort)[18], C(reltime)[T.13]:C(cohort)[18], C(reltime)[T.14]:C(cohort)[18], C(reltime)[T.15]:C(cohort)[18], C(reltime)[T.16]:C(cohort)[18], C(reltime)[T.17]:C(cohort)[18], C(reltime)[T.18]:C(cohort)[18], C(reltime)[T.19]:C(cohort)[18], C(reltime)[T.20]:C(cohort)[18], C(reltime)[T.21]:C(cohort)[18], C(reltime)[T.22]:C(cohort)[18], C(reltime)[T.23]:C(cohort)[18], C(reltime)[T.-24]:C(cohort)[24], C(reltime)[T.-23]:C(cohort)[24], C(reltime)[T.-22]:C(cohort)[24], C(reltime)[T.-21]:C(cohort)[24], C(reltime)[T.-20]:C(cohort)[24], C(reltime)[T.-19]:C(cohort)[24], C(reltime)[T.-18]:C(cohort)[24], C(reltime)[T.-17]:C(cohort)[24], C(reltime)[T.-16]:C(cohort)[24], C(reltime)[T.-15]:C(cohort)[24], C(reltime)[T.-14]:C(cohort)[24], C(reltime)[T.-13]:C(cohort)[24], C(reltime)[T.-12]:C(cohort)[24], C(reltime)[T.-11]:C(cohort)[24], C(reltime)[T.-10]:C(cohort)[24], C(reltime)[T.-9]:C(cohort)[24], C(reltime)[T.-8]:C(cohort)[24], C(reltime)[T.-7]:C(cohort)[24], C(reltime)[T.-6]:C(cohort)[24], C(reltime)[T.-5]:C(cohort)[24], C(reltime)[T.-4]:C(cohort)[24], C(reltime)[T.-3]:C(cohort)[24], C(reltime)[T.-2]:C(cohort)[24], C(reltime)[T.0]:C(cohort)[24], C(reltime)[T.1]:C(cohort)[24], C(reltime)[T.2]:C(cohort)[24], C(reltime)[T.3]:C(cohort)[24], C(reltime)[T.4]:C(cohort)[24], C(reltime)[T.5]:C(cohort)[24], C(reltime)[T.6]:C(cohort)[24], C(reltime)[T.7]:C(cohort)[24], C(reltime)[T.8]:C(cohort)[24], C(reltime)[T.9]:C(cohort)[24], C(reltime)[T.10]:C(cohort)[24], C(reltime)[T.11]:C(cohort)[24], C(reltime)[T.12]:C(cohort)[24], C(reltime)[T.13]:C(cohort)[24], C(reltime)[T.14]:C(cohort)[24], C(reltime)[T.15]:C(cohort)[24], C(reltime)[T.16]:C(cohort)[24], C(reltime)[T.17]:C(cohort)[24], C(reltime)[T.18]:C(cohort)[24], C(reltime)[T.19]:C(cohort)[24], C(reltime)[T.20]:C(cohort)[24], C(reltime)[T.21]:C(cohort)[24], C(reltime)[T.22]:C(cohort)[24], C(reltime)[T.23]:C(cohort)[24]
#           parameter       lower       upper
# reltime
# -18       -0.038471   -0.100628    0.023685
# -17        0.021377   -0.042925    0.085679
# -16       -0.016810   -0.080300    0.046681
# -15        0.044857   -0.015783    0.105498
# -14        0.010992   -0.054050    0.076034
# -13        0.030953   -0.032878    0.094785
# -12       -0.025326   -0.087852    0.037199
# -11       -0.005296   -0.069256    0.058663
# -10       -0.021340   -0.083758    0.041078
# -9         0.022398   -0.040546    0.085341
# -8        -0.007887   -0.071824    0.056050
# -7         0.014394   -0.050553    0.079342
# -6        -0.003082   -0.066381    0.060217
# -5         0.005412   -0.058151    0.068975
# -4        -0.004578   -0.067514    0.058359
# -3        -0.002657   -0.065409    0.060095
# -2         0.023945   -0.039798    0.087687
#  0         8.010576    7.946654    8.074499
#  1        16.004048   15.939834   16.068262
#  2        23.997172   23.932955   24.061388
#  3        31.993026   31.926699   32.059353
#  4        40.002651   39.935434   40.069867
#  5        48.014538   47.943820   48.085256
#  6        54.650388   54.578519   54.722256
#  7        61.327497   61.253023   61.401971
#  8        67.984103   67.909374   68.058832
#  9        74.651529   74.570802   74.732255
#  10       81.387131   81.305021   81.469241
#  11       87.996638   87.907994   88.085282
#  12      114.948988  114.860283  115.037694
#  13      121.929768  121.839048  122.020489
#  14      129.022805  128.928022  129.117589
#  15      135.992993  135.889243  136.096744
#  16      143.002551  142.894981  143.110121
#  17      150.031431  149.919737  150.143124
#  18      185.982132  185.878492  186.085772
#  19      191.957045  191.837516  192.076575
#  20      197.957764  197.844787  198.070740
#  21      203.989732  203.863666  204.115798
#  22      209.916456  209.776567  210.056345
#  23      215.993442  215.855264  216.131619

# %%
# Plot the estimated interaction-weighted event study coefficients
fig_iw = es.eventstudyplot(
    input=est_iw,
    big_title='Sun & Abraham (2021) Interaction-Weighted Event Study Plot (With 95% CIs)',
    name_output='eventstudyplot_iw'
)
fig_iw.show('svg')
# Out:
# Takes output from est_ functions to plot event study estimates and their CIs
# Requires 3 columns: parameter, lower, and upper; indexed to relative time
# Output = plotly graph objects figure

# %%
# Plot both the TWFE and interaction-weighted event study coefficients
option_ci = 1 # option to plot CIs as well
fig = go.Figure()
# TWFE
fig.add_trace(
    go.Scatter(
        x=est_twfe.index,
        y=est_twfe['parameter'],
        name='TWFE Estimates',
        mode='lines',
        line=dict(color='red', width=2)
    )
)
if option_ci == 1:
    fig.add_trace(
            go.Scatter(
                x=est_twfe.index,
                y=est_twfe['lower'],
                name='TWFE CIs',
                mode='lines',
                line=dict(color='red', width=1, dash='dash')
            )
        )
    fig.add_trace(
            go.Scatter(
                x=est_twfe.index,
                y=est_twfe['upper'],
                name='TWFE CIs',
                mode='lines',
                line=dict(color='red', width=1, dash='dash')
            )
        )
# IW
fig.add_trace(
    go.Scatter(
        x=est_iw.index,
        y=est_iw['parameter'],
        name='Interaction-Weighted Estimates',
        mode='lines',
        line=dict(color='black', width=2)
    )
)
if option_ci == 1:
    fig.add_trace(
            go.Scatter(
                x=est_iw.index,
                y=est_iw['lower'],
                name='IW CIs',
                mode='lines',
                line=dict(color='black', width=1, dash='dash')
            )
        )
    fig.add_trace(
            go.Scatter(
                x=est_iw.index,
                y=est_iw['upper'],
                name='IW CIs',
                mode='lines',
                line=dict(color='black', width=1, dash='dash')
            )
        )
# Overall layout
fig.update_layout(
    title='TWFE v IW Event Study Estimates: Data from https://github.com/scunning1975/mixtape/baker.dta',
    plot_bgcolor='white',
    font=dict(color='black')
)
fig.show('svg')  # display final plot
